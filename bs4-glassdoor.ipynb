# %%
import requests
from bs4 import BeautifulSoup

headers_param = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.113 Safari/537.36"}
glassdor = requests.get("https://www.glassdoor.com/List/Best-Jobs-in-America-2019-LST_KQ0,25.htm",headers=headers_param)

jobs = glassdor.content

soup = BeautifulSoup(jobs,"html.parser")

all_jobs = soup.find_all("p",{"class":"h2 m-0 entryWinner pb-std pb-md-0"})

for job in all_jobs:
    print(job.a.text)

all_data = soup.find_all("div",{"class":"col-6 col-lg-4 dataPoint"})

for data in all_data:
    print(data.text)
# Out:
# Data Scientist
# Nursing Manager
# Marketing Manager
# Occupational Therapist
# Product Manager
# Devops Engineer
# Program Manager
# Data Engineer
# HR Manager
# Software Engineer
# Mechanical Engineer
# Physician Assistant
# Sales Manager
# Sales Engineer
# Operations Manager
# Strategy Manager
# Security Engineer
# Construction Manager
# Speech Language Pathologist
# Project Manager
# Product Designer
# Java Developer
# Executive Assistant
# Electrical Engineer
# Finance Manager
# Business Analyst
# Solutions Architect
# Recruiter
# Business Development Manager
# Dental Hygienist
# Data Analyst
# Nurse Practitioner
# Applications Engineer
# QA Manager
# Risk Manager
# Communications Manager
# Physical Therapist
# Facilities Manager
# Systems Engineer
# Customer Success Manager
# Radiologic Technologist
# Restaurant Manager
# Software Engineering Manager
# Software Developer
# Safety Manager
# UX Designer
# Office Manager
# Brand Manager
# Software Development Manager
# Systems Administrator
#  $108,000 Median Base Salary
#  4.3/5 Job Satisfaction
#  6,510 Job Openings
#  $83,000 Median Base Salary
#  4/5 Job Satisfaction
#  13,931 Job Openings
#  $82,000 Median Base Salary
#  4.2/5 Job Satisfaction
#  7,395 Job Openings
#  $74,000 Median Base Salary
#  4/5 Job Satisfaction
#  17,701 Job Openings
#  $115,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  11,884 Job Openings
#  $106,000 Median Base Salary
#  4.1/5 Job Satisfaction
#  4,657 Job Openings
#  $87,000 Median Base Salary
#  3.9/5 Job Satisfaction
#  14,753 Job Openings
#  $100,000 Median Base Salary
#  3.9/5 Job Satisfaction
#  4,739 Job Openings
#  $85,000 Median Base Salary
#  4.2/5 Job Satisfaction
#  3,908 Job Openings
#  $104,000 Median Base Salary
#  3.6/5 Job Satisfaction
#  49,007 Job Openings
#  $75,000 Median Base Salary
#  3.9/5 Job Satisfaction
#  5,949 Job Openings
#  $105,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  9,819 Job Openings
#  $65,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  21,695 Job Openings
#  $90,000 Median Base Salary
#  4.1/5 Job Satisfaction
#  3,145 Job Openings
#  $68,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  18,311 Job Openings
#  $140,000 Median Base Salary
#  4/5 Job Satisfaction
#  2,783 Job Openings
#  $102,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  4,683 Job Openings
#  $75,000 Median Base Salary
#  4.3/5 Job Satisfaction
#  3,334 Job Openings
#  $72,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  29,467 Job Openings
#  $75,000 Median Base Salary
#  3.6/5 Job Satisfaction
#  30,107 Job Openings
#  $100,000 Median Base Salary
#  4.5/5 Job Satisfaction
#  2,158 Job Openings
#  $85,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  6,636 Job Openings
#  $60,000 Median Base Salary
#  4.1/5 Job Satisfaction
#  4,858 Job Openings
#  $77,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  7,191 Job Openings
#  $118,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  3,747 Job Openings
#  $72,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  13,340 Job Openings
#  $127,900 Median Base Salary
#  3.6/5 Job Satisfaction
#  6,969 Job Openings
#  $48,000 Median Base Salary
#  4.1/5 Job Satisfaction
#  9,782 Job Openings
#  $80,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  6,348 Job Openings
#  $67,250 Median Base Salary
#  4.5/5 Job Satisfaction
#  2,805 Job Openings
#  $60,000 Median Base Salary
#  3.9/5 Job Satisfaction
#  5,456 Job Openings
#  $102,000 Median Base Salary
#  3.5/5 Job Satisfaction
#  18,997 Job Openings
#  $77,000 Median Base Salary
#  4/5 Job Satisfaction
#  2,591 Job Openings
#  $91,250 Median Base Salary
#  4.1/5 Job Satisfaction
#  1,923 Job Openings
#  $100,500 Median Base Salary
#  3.7/5 Job Satisfaction
#  3,924 Job Openings
#  $80,000 Median Base Salary
#  4.2/5 Job Satisfaction
#  2,009 Job Openings
#  $70,000 Median Base Salary
#  3.6/5 Job Satisfaction
#  34,899 Job Openings
#  $65,000 Median Base Salary
#  4/5 Job Satisfaction
#  3,472 Job Openings
#  $90,000 Median Base Salary
#  3.5/5 Job Satisfaction
#  16,793 Job Openings
#  $65,000 Median Base Salary
#  4.2/5 Job Satisfaction
#  2,601 Job Openings
#  $48,000 Median Base Salary
#  4/5 Job Satisfaction
#  6,115 Job Openings
#  $49,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  21,754 Job Openings
#  $153,000 Median Base Salary
#  4/5 Job Satisfaction
#  1,445 Job Openings
#  $80,000 Median Base Salary
#  3.5/5 Job Satisfaction
#  11,833 Job Openings
#  $71,000 Median Base Salary
#  4.1/5 Job Satisfaction
#  2,180 Job Openings
#  $89,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  3,333 Job Openings
#  $42,000 Median Base Salary
#  3.9/5 Job Satisfaction
#  18,681 Job Openings
#  $85,000 Median Base Salary
#  4.3/5 Job Satisfaction
#  1,500 Job Openings
#  $140,000 Median Base Salary
#  4.2/5 Job Satisfaction
#  1,178 Job Openings
#  $68,000 Median Base Salary
#  3.6/5 Job Satisfaction
#  8,278 Job Openings

# %%
import requests
from bs4 import BeautifulSoup

headers_param = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.113 Safari/537.36"}
glassdor = requests.get("https://www.glassdoor.com/List/Best-Jobs-in-America-2019-LST_KQ0,25.htm",headers=headers_param)

jobs = glassdor.content

soup = BeautifulSoup(jobs,"html.parser")

all_jobs = soup.find_all("p",{"class":"h2 m-0 entryWinner pb-std pb-md-0"})

for job in all_jobs:
    print(job.a.text)

all_data = soup.find_all("div",{"class":"col-6 col-lg-4 dataPoint"})

for data in all_data:
    print(data.text)
# Out:
# Data Scientist
# Nursing Manager
# Marketing Manager
# Occupational Therapist
# Product Manager
# Devops Engineer
# Program Manager
# Data Engineer
# HR Manager
# Software Engineer
# Mechanical Engineer
# Physician Assistant
# Sales Manager
# Sales Engineer
# Operations Manager
# Strategy Manager
# Security Engineer
# Construction Manager
# Speech Language Pathologist
# Project Manager
# Product Designer
# Java Developer
# Executive Assistant
# Electrical Engineer
# Finance Manager
# Business Analyst
# Solutions Architect
# Recruiter
# Business Development Manager
# Dental Hygienist
# Data Analyst
# Nurse Practitioner
# Applications Engineer
# QA Manager
# Risk Manager
# Communications Manager
# Physical Therapist
# Facilities Manager
# Systems Engineer
# Customer Success Manager
# Radiologic Technologist
# Restaurant Manager
# Software Engineering Manager
# Software Developer
# Safety Manager
# UX Designer
# Office Manager
# Brand Manager
# Software Development Manager
# Systems Administrator
#  $108,000 Median Base Salary
#  4.3/5 Job Satisfaction
#  6,510 Job Openings
#  $83,000 Median Base Salary
#  4/5 Job Satisfaction
#  13,931 Job Openings
#  $82,000 Median Base Salary
#  4.2/5 Job Satisfaction
#  7,395 Job Openings
#  $74,000 Median Base Salary
#  4/5 Job Satisfaction
#  17,701 Job Openings
#  $115,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  11,884 Job Openings
#  $106,000 Median Base Salary
#  4.1/5 Job Satisfaction
#  4,657 Job Openings
#  $87,000 Median Base Salary
#  3.9/5 Job Satisfaction
#  14,753 Job Openings
#  $100,000 Median Base Salary
#  3.9/5 Job Satisfaction
#  4,739 Job Openings
#  $85,000 Median Base Salary
#  4.2/5 Job Satisfaction
#  3,908 Job Openings
#  $104,000 Median Base Salary
#  3.6/5 Job Satisfaction
#  49,007 Job Openings
#  $75,000 Median Base Salary
#  3.9/5 Job Satisfaction
#  5,949 Job Openings
#  $105,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  9,819 Job Openings
#  $65,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  21,695 Job Openings
#  $90,000 Median Base Salary
#  4.1/5 Job Satisfaction
#  3,145 Job Openings
#  $68,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  18,311 Job Openings
#  $140,000 Median Base Salary
#  4/5 Job Satisfaction
#  2,783 Job Openings
#  $102,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  4,683 Job Openings
#  $75,000 Median Base Salary
#  4.3/5 Job Satisfaction
#  3,334 Job Openings
#  $72,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  29,467 Job Openings
#  $75,000 Median Base Salary
#  3.6/5 Job Satisfaction
#  30,107 Job Openings
#  $100,000 Median Base Salary
#  4.5/5 Job Satisfaction
#  2,158 Job Openings
#  $85,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  6,636 Job Openings
#  $60,000 Median Base Salary
#  4.1/5 Job Satisfaction
#  4,858 Job Openings
#  $77,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  7,191 Job Openings
#  $118,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  3,747 Job Openings
#  $72,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  13,340 Job Openings
#  $127,900 Median Base Salary
#  3.6/5 Job Satisfaction
#  6,969 Job Openings
#  $48,000 Median Base Salary
#  4.1/5 Job Satisfaction
#  9,782 Job Openings
#  $80,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  6,348 Job Openings
#  $67,250 Median Base Salary
#  4.5/5 Job Satisfaction
#  2,805 Job Openings
#  $60,000 Median Base Salary
#  3.9/5 Job Satisfaction
#  5,456 Job Openings
#  $102,000 Median Base Salary
#  3.5/5 Job Satisfaction
#  18,997 Job Openings
#  $77,000 Median Base Salary
#  4/5 Job Satisfaction
#  2,591 Job Openings
#  $91,250 Median Base Salary
#  4.1/5 Job Satisfaction
#  1,923 Job Openings
#  $100,500 Median Base Salary
#  3.7/5 Job Satisfaction
#  3,924 Job Openings
#  $80,000 Median Base Salary
#  4.2/5 Job Satisfaction
#  2,009 Job Openings
#  $70,000 Median Base Salary
#  3.6/5 Job Satisfaction
#  34,899 Job Openings
#  $65,000 Median Base Salary
#  4/5 Job Satisfaction
#  3,472 Job Openings
#  $90,000 Median Base Salary
#  3.5/5 Job Satisfaction
#  16,793 Job Openings
#  $65,000 Median Base Salary
#  4.2/5 Job Satisfaction
#  2,601 Job Openings
#  $48,000 Median Base Salary
#  4/5 Job Satisfaction
#  6,115 Job Openings
#  $49,000 Median Base Salary
#  3.8/5 Job Satisfaction
#  21,754 Job Openings
#  $153,000 Median Base Salary
#  4/5 Job Satisfaction
#  1,445 Job Openings
#  $80,000 Median Base Salary
#  3.5/5 Job Satisfaction
#  11,833 Job Openings
#  $71,000 Median Base Salary
#  4.1/5 Job Satisfaction
#  2,180 Job Openings
#  $89,000 Median Base Salary
#  3.7/5 Job Satisfaction
#  3,333 Job Openings
#  $42,000 Median Base Salary
#  3.9/5 Job Satisfaction
#  18,681 Job Openings
#  $85,000 Median Base Salary
#  4.3/5 Job Satisfaction
#  1,500 Job Openings
#  $140,000 Median Base Salary
#  4.2/5 Job Satisfaction
#  1,178 Job Openings
#  $68,000 Median Base Salary
#  3.6/5 Job Satisfaction
#  8,278 Job Openings
