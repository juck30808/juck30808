# %% [markdown]
# ## 樣式表

# %%
# plt.style.use('bmh')
# plt.style.use('classic')
# plt.style.use("dark_background")

# %%
# plt.plot(x, y, 
#          color='color', 
#          linestyle='linestyle',    # 實solid(-) 虛dashed(--) 線點dashdot(-.) 點線dotted(:) 星號star(*)
#          marker='marker',          # 點point(.) 圓circle(o)  正方square(s)   加號plus(+)   鑽石diamond(D)
#                                      三角triangle(v^<>) 五邊形pentagon(p)  六邊形hexagonl(h) 打叉(x) 不畫線None
#          linewidth='linewidth')    # 線的寬度 linewidth (lw)

# %% [markdown]
# ## 基本繪圖

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure() 
data = np.linspace(-15,15,100)    # 建立一個矩陣從 -15 到 15(100個等差數值)


#######
plt.title("Sine curve y=sin(x)")

plt.xlim(-15, 15)    # Max
plt.ylim(-1.5, 1.5)  # Min

plt.xlabel("x")
plt.ylabel("sin(x)")
#######

plt.plot(data, np.sin(data), '.') #定義 x,y 和 sytle

# %%
fig = plt.figure()
plt.plot(data, np.sin(data), '.', 
         data, np.cos(data), '--')   #定義第二條線

#fig.savefig('output/Pandas-Matplotlib.png')

# %% [markdown]
# ## 繪製誤差圖 plt.errorbar(x,y..)

# %%
x = np.linspace(-5,5,5)
y = np.random.randint(-5,5,5)

fig = plt.figure()
plt.errorbar(x, y,
             yerr=2, fmt='o', color='SteelBlue',       # style
             ecolor='LightSteelBlue', elinewidth=2)    # ecolor->誤差的顏色  elinewidth->誤差的寬度
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Line chart 直線圖

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

x1,y1 = [2,4,8], [4,8,24]
x2,y2 = [3,6,9], [18,15,38]

#######
plt.title("Title")
plt.xlabel("x")
plt.ylabel("y label")
#######

plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()       #Show at same time

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(0, 4 * np.pi, 0.2)
y = np.sin(x)


plt.plot(x, y,
    linewidth=0.5, linestyle='--', color='r', marker='o', markersize=10,markerfacecolor=(1, 0, 0, 0.1))

#######
plt.title('Plot of sin(x) vs x from 0 to 4 pi')
plt.xlabel('x (0 to 4 pi)')
plt.ylabel('sin(x)')
plt.legend(['sin(x)']) # list containing one string
#######

plt.xticks(np.arange(0, 4*np.pi + np.pi/2, np.pi/2),
           ['0','pi/2','pi','3pi/2','2pi','5pi/2','3pi','7pi/2','4pi'])
plt.grid(True)
plt.show()

# %% [markdown]
# ## Bar charts 直方圖

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

x1,y1 = [2,4,8],[4,8,24]
x2,y2 = [3,6,9],[18,15,38]
x3,y3 = [5,6,9],[15,15,38]

plt.bar(x1,y1)
plt.bar(x2,y2)
plt.bar(x3,y3)

plt.show()       #Show at same time

# %%
x= [2,4,8,3,6,9,3,6,9,15,15,4,8,24,8,3,6,9]
y= [3,4,8,9,15,20,25,30]

plt.hist(x,y,histtype="bar")  
#plt.hist(x,y,histtype="step") 
plt.show()

# %%
data = pd.Series([34,76,12,89,45], index= list('ABCDE'))  #Series
data
# Out:
# A    34
# B    76
# C    12
# D    89
# E    45
# dtype: int64

# %%
frame1 = pd.read_csv('input/ex6.csv')
frame1.head(3)
# Out:
#    year  gender  income
# 0  2015  female      55
# 1  2015    male      65
# 2  2016  female      67

# %% [markdown]
# To create stacked bar plot, we add the argument **stacked = True**:

# %%
#旋轉x軸 #更改顏色 #transperancy(alpha)

data.plot.bar()   
data.plot.bar(rot = 0, color = 'r', alpha = 0.7 )  

frame1.plot(kind = 'bar', rot =0)  #外定義
frame1.plot.bar(rot = 0)
frame1.plot.bar(stacked = True, rot =0)  #stacked 堆積圖
# Out:
# <AxesSubplot:>

# %%
data.plot.barh(color = 'g', alpha = 0.7 )

frame1.plot.barh()
frame1.plot.barh(stacked = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bar hist charts 分佈圖

# %%
mu=100
sigma=15
x=mu+sigma*np.random.randn(10000)

n,bins,patches=plt.hist(x,50,density=True, facecolor='blue',alpha=0.80)

plt.xlabel('Smart graphs')
plt.ylabel('Probabilities')
plt.axis([40,160,0,0.03])
plt.grid(True)

plt.show()

# %%
x = np.random.randn(1000)
fig = plt.figure()


plt.hist(x, 
         bins=20, color='SteelBlue', edgecolor="LightSteelBlue")  

#bins 定義有幾個直方圖 color->直方圖顏色 edgecolor->邊界顏色
# Out:
# (array([  5.,  11.,  16.,  28.,  46.,  65.,  84., 116., 126., 132., 102.,
#         100.,  72.,  40.,  20.,  15.,  11.,   5.,   4.,   2.]),
#  array([-2.91877494, -2.59884894, -2.27892295, -1.95899695, -1.63907095,
#         -1.31914495, -0.99921896, -0.67929296, -0.35936696, -0.03944096,
#          0.28048504,  0.60041103,  0.92033703,  1.24026303,  1.56018903,
#          1.88011502,  2.20004102,  2.51996702,  2.83989302,  3.15981902,
#          3.47974501]),
#  <BarContainer object of 20 artists>)

# %%
counts, bin_edges = np.histogram(x, bins=20)
print('counts:', counts)
print('bin_edges:', bin_edges)
# Out:
# counts: [  5  11  16  28  46  65  84 116 126 132 102 100  72  40  20  15  11   5
#    4   2]
# bin_edges: [-2.91877494 -2.59884894 -2.27892295 -1.95899695 -1.63907095 -1.31914495
#  -0.99921896 -0.67929296 -0.35936696 -0.03944096  0.28048504  0.60041103
#   0.92033703  1.24026303  1.56018903  1.88011502  2.20004102  2.51996702
#   2.83989302  3.15981902  3.47974501]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

mu = 80
sigma = 7
x = np.random.normal(mu, sigma, size=200)

fig, ax = plt.subplots()

ax.hist(x, 20)
ax.set_title("New Historgram")
ax.set_xlabel('bin range')
ax.set_ylabel('frequency')

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Pie chart 圓餅圖

# %%
fig = plt.figure()

labels    = ["A","B","C","D","E","F"]
word_size = [20, 35, 45 , 32, 11, 50]
explode   = [0 , 0, .1, 0, 0, 0]       #凸出率

plt.pie(word_size, explode= explode, labels = labels, 
        autopct= "%3.1f%%") # autopct-->項目百分比的格式
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9ff0cb0f70>,
# ...
#  [Text(1.0422211767359784, 0.3518167403110212, 'A'),
#   Text(0.37715676485049143, 1.0333212350123804, 'B'),
#   Text(-0.977662759306726, 0.695827226446881, 'C'),
#   Text(-0.8856900828023644, -0.6523442934720446, 'D'),
#   Text(-0.257225239222396, -1.069502303086338, 'E'),
#   Text(0.7553479605186184, -0.7996558375578608, 'F')],
#  [Text(0.5684842782196246, 0.19190004016964793, '10.4%'),
#   Text(0.20572187173663167, 0.5636297645522075, '18.1%'),
#   Text(-0.5703032762622567, 0.40589921542734725, '23.3%'),
#   Text(-0.4831036815285623, -0.35582416007566064, '16.6%'),
#   Text(-0.1403046759394887, -0.583364892592548, '5.7%'),
#   Text(0.4120079784647009, -0.4361759113951968, '25.9%')])

# %%
food = ['pizza','ice cream','burgers']
sales = [10,20,30]
color = ['red','blue','yellow']

plt.pie(sales,labels=food,colors=color)  
#plt.hist(x,y,histtype="step") 
plt.show()

# %%
labels='India','US','UK','Germany'
sizes=[38,32,20,10]
explode=(0.1,0.2,0,0)

plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## scatter 散佈圖

# %%
import matplotlib.pyplot as plt

x,y = [2,4,8,3,6,9], [3,4,8,9,1,9]

plt.scatter(x,y)  
plt.show()       #Show at same time

# %%
N=50
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
area=np.pi * (15 * np.random.rand(N))**2

plt.scatter(x,y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ## Performance : legend , annotate

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

data = np.linspace(0,10, 1000)  #產生 0~10區間的 等間隔序列
fig, ax = plt.subplots()

plt.plot(data, np.sin(data), '.', 
         color='SteelBlue', label='Sine')

plt.plot(data, np.cos(data), '-', 
         color='RosyBrown', label='Cosine')

ax.axis('equal')
leg = ax.legend(loc='upper right',    #loc:位置
                shadow=True)          #shadow:陰影


#### 標注 annotate #####
# s->標示的文字內容， xy->要標示的數據位置， xytext->顯示的文字位置，arrowprops->箭頭的參數

ax.annotate(s = "first node", 
            xy = (4.44,-1), 
            xytext = (5,-2), 
            arrowprops = dict(arrowstyle='->', connectionstyle="arc3,rad=.2"))

ax.annotate(s = "second node", 
            xy = (8,1), 
            xytext = (5,1.5), 
            arrowprops = dict(arrowstyle='->', connectionstyle="arc3,rad=-.2"))
# Out:
# /var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/ipykernel_8250/3303247793.py:22: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(s = "first node",
# /var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/ipykernel_8250/3303247793.py:27: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(s = "second node",
# Text(5, 1.5, 'second node')

# %% [markdown]
# ## 字型 Font
# #預設字型無法使用中文，將下載的字型放入該位置

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/matplotlibrc'

# %% [markdown]
# ## subplots

# %%
fig , ax = plt.subplots(2, 3, 
                        sharex=True, sharey=True)  #sharex:共享x軸  # sharey:共享y軸


for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),   #在各個子網格寫上文字
                      fontsize=18, 
                      ha='center')

# %%
data = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)
print(data)

plt.subplot(data[:,0])   #all row, 0 column
plt.subplot(data[0, 1:]) #0 row, 1之後的所有column
plt.subplot(data[1, 1])  #1 row, 1 column
plt.subplot(data[1, 2])  #1 row, 2 column
# Out:
# GridSpec(2, 3)
# <AxesSubplot:>

# %% [markdown]
# ## Project

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('input/iris.csv')
df.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df['Sepal Length'].plot(color = 'darkgreen')
# Out:
# <AxesSubplot:>

# %%
pd.plotting.andrews_curves(df,'class')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Scatter Matrix

# %%
pd.plotting.scatter_matrix(df, figsize = (10, 10))
# Out:
# array([[<AxesSubplot:xlabel='Sepal Length', ylabel='Sepal Length'>,
#         <AxesSubplot:xlabel='Sepal Width', ylabel='Sepal Length'>,
#         <AxesSubplot:xlabel='Petal Length', ylabel='Sepal Length'>,
#         <AxesSubplot:xlabel='Petal Width', ylabel='Sepal Length'>],
#        [<AxesSubplot:xlabel='Sepal Length', ylabel='Sepal Width'>,
#         <AxesSubplot:xlabel='Sepal Width', ylabel='Sepal Width'>,
#         <AxesSubplot:xlabel='Petal Length', ylabel='Sepal Width'>,
#         <AxesSubplot:xlabel='Petal Width', ylabel='Sepal Width'>],
#        [<AxesSubplot:xlabel='Sepal Length', ylabel='Petal Length'>,
#         <AxesSubplot:xlabel='Sepal Width', ylabel='Petal Length'>,
#         <AxesSubplot:xlabel='Petal Length', ylabel='Petal Length'>,
#         <AxesSubplot:xlabel='Petal Width', ylabel='Petal Length'>],
#        [<AxesSubplot:xlabel='Sepal Length', ylabel='Petal Width'>,
#         <AxesSubplot:xlabel='Sepal Width', ylabel='Petal Width'>,
# ...

# %% [markdown]
# ## Autocorrelation Plot (plot_acf)

# %%
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf
df = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv')
df.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
plot_acf(df['Temp'], lags=30)

# %%
# lag plot
from pandas.plotting import lag_plot
lag_plot(df['Temp'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
# lag plot
lag_plot(df['Temp'], lag = 3)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 3)'>

# %% [markdown]
# ## Bootstrap Plot

# %%
import pandas as pd
import numpy as np
s = pd.Series(np.random.uniform(size=500))
pd.plotting.bootstrap_plot(s)
