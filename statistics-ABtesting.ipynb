# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example1.
# 某校有學生 1000 位，數學段考成績呈常態分布，平均成績 70 分，標準差 10 分，
# - ○1 此次段考成績不及格的學生約有幾位？
# - ○2 成績超過 90 分的有幾位？
# - ○3 某生成績 80 分，他在全校大約排第幾名？

# %%
# X = 100
N = 1000
# P = X/N
# P

mean = 70
std = 10

# %%
# ○1 此次段考成績不及格的學生約有幾位？
N*(1-0.68)/2
# Out:
# 159.99999999999997

# %%
# ○2 成績超過 90 分的有幾位？
N*(1-0.95)/2
# Out:
# 25.00000000000002

# %%
# ○3 某生成績 80 分，他在全校大約排第幾名？
u = (80-mean)/std
N*(1-0.68)/2
# Out:
# 159.99999999999997

# %% [markdown]
# ### Example2.
# 有一民調中心想調查市長甲候選人的支持度，隨機抽取的一個 1000 人的樣本，其中有 570 位市民支持甲候選人，試求 95%的信賴區間。

# %%
import math
N = 1000
X = 570
P = 570/1000
P

STD = math.sqrt(P*(1-P)/N)
STD    #一個標準差
STD*2  #兩個標準差 (抽樣誤差 Margin of error)
# Out:
# 0.031311339798865204

# %%
#信賴區間
print(P-STD*2, P+STD*2)

# 1.我們有 95%的信心，甲候選人的支持率落在53.9% ~ 60.1%
# 2.在 95%的信心水準下，誤差不超過 3.1%, 甲候選人的支持率為 57%
# Out:
# 0.5386886602011347 0.6013113397988652

# %% [markdown]
# 事實上我們這節一開始介紹的例子，2008 總統大選，最後的選舉結果，馬蕭配的得票率為 58%,
# 所以我們覺得 TVBS 民調中心還滿準的，因此善加利用你學會的知識，也可以幫助你判斷一些統計資料！

# %% [markdown]
# ### Example3.
# Overview of A/B Testing

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X = 100
N = 1000
P = X/N
P
# Out:
# 0.1

# %%
#95%信心水準
STD = math.sqrt(P*(1-P)/N)
STD    #一個標準差 (68% - 抽樣誤差 Margin of error)
STD*2  #兩個標準差 (95% - 抽樣誤差 Margin of error)
#STD*3  #三個標準差 (99% - 抽樣誤差 Margin of error)
# Out:
# 0.031311339798865204

# %%
# Check Normal Distribution
print((N*P)>5 , N*(1-P)>5)
# Out:
# True True

# %%
#m = Z * sqrt(P-(1-P)/N)

# %% [markdown]
# ### Example4.
# Overview of A/B Testing Quiz

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = 2000
X = 300
P = X/N
P
# Out:
# 0.15

# %%
#99%信心水準
STD = math.sqrt(P*(1-P)/N)
STD    #一個標準差 (68% - 抽樣誤差 Margin of error)
STD*2  #兩個標準差 (95% - 抽樣誤差 Margin of error)
STD*3  #三個標準差 (99% - 抽樣誤差 Margin of error)
# Out:
# 0.02395307913400697

# %%
z = (x-u)/std

# %%
print( P-STD*3, P+STD*3)
# Out:
# 0.12604692086599303 0.17395307913400695
