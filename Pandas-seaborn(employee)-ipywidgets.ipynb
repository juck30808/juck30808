# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('input/employee.csv')
# data.shape
# data.describe()
# data.describe(include='object')
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
data.head(3).style.format({'DailyRate': '${:5}',
                            'MonthlyIncome': '${:5}'} )
# Out:
# <style type="text/css">
# </style>
# <table id="T_d6905_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age</th>
#       <th class="col_heading level0 col1" >Attrition</th>
#       <th class="col_heading level0 col2" >BusinessTravel</th>
#       <th class="col_heading level0 col3" >DailyRate</th>
#       <th class="col_heading level0 col4" >Department</th>
#       <th class="col_heading level0 col5" >DistanceFromHome</th>
#       <th class="col_heading level0 col6" >Education</th>
#       <th class="col_heading level0 col7" >EducationField</th>
#       <th class="col_heading level0 col8" >EmployeeCount</th>
#       <th class="col_heading level0 col9" >EmployeeNumber</th>
#       <th class="col_heading level0 col10" >EnvironmentSatisfaction</th>
#       <th class="col_heading level0 col11" >Gender</th>
#       <th class="col_heading level0 col12" >HourlyRate</th>
#       <th class="col_heading level0 col13" >JobInvolvement</th>
#       <th class="col_heading level0 col14" >JobLevel</th>
#       <th class="col_heading level0 col15" >JobRole</th>
#       <th class="col_heading level0 col16" >JobSatisfaction</th>
#       <th class="col_heading level0 col17" >MaritalStatus</th>
#       <th class="col_heading level0 col18" >MonthlyIncome</th>
#       <th class="col_heading level0 col19" >MonthlyRate</th>
#       <th class="col_heading level0 col20" >NumCompaniesWorked</th>
#       <th class="col_heading level0 col21" >Over18</th>
#       <th class="col_heading level0 col22" >OverTime</th>
#       <th class="col_heading level0 col23" >PercentSalaryHike</th>
#       <th class="col_heading level0 col24" >PerformanceRating</th>
#       <th class="col_heading level0 col25" >RelationshipSatisfaction</th>
#       <th class="col_heading level0 col26" >StandardHours</th>
#       <th class="col_heading level0 col27" >StockOptionLevel</th>
#       <th class="col_heading level0 col28" >TotalWorkingYears</th>
#       <th class="col_heading level0 col29" >TrainingTimesLastYear</th>
#       <th class="col_heading level0 col30" >WorkLifeBalance</th>
#       <th class="col_heading level0 col31" >YearsAtCompany</th>
#       <th class="col_heading level0 col32" >YearsInCurrentRole</th>
#       <th class="col_heading level0 col33" >YearsSinceLastPromotion</th>
#       <th class="col_heading level0 col34" >YearsWithCurrManager</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6905_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6905_row0_col0" class="data row0 col0" >41</td>
#       <td id="T_d6905_row0_col1" class="data row0 col1" >Yes</td>
#       <td id="T_d6905_row0_col2" class="data row0 col2" >Travel_Rarely</td>
#       <td id="T_d6905_row0_col3" class="data row0 col3" >$ 1102</td>
#       <td id="T_d6905_row0_col4" class="data row0 col4" >Sales</td>
#       <td id="T_d6905_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_d6905_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_d6905_row0_col7" class="data row0 col7" >Life Sciences</td>
#       <td id="T_d6905_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_d6905_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_d6905_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_d6905_row0_col11" class="data row0 col11" >Female</td>
#       <td id="T_d6905_row0_col12" class="data row0 col12" >94</td>
#       <td id="T_d6905_row0_col13" class="data row0 col13" >3</td>
#       <td id="T_d6905_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_d6905_row0_col15" class="data row0 col15" >Sales Executive</td>
">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age</th>
#       <th class="col_heading level0 col1" >Attrition</th>
#       <th class="col_heading level0 col2" >BusinessTravel</th>
#       <th class="col_heading level0 col3" >DailyRate</th>
#       <th class="col_heading level0 col4" >Department</th>
#       <th class="col_heading level0 col5" >DistanceFromHome</th>
#       <th class="col_heading level0 col6" >Education</th>
#       <th class="col_heading level0 col7" >EducationField</th>
#       <th class="col_heading level0 col8" >EmployeeCount</th>
#       <th class="col_heading level0 col9" >EmployeeNumber</th>
#       <th class="col_heading level0 col10" >EnvironmentSatisfaction</th>
#       <th class="col_heading level0 col11" >Gender</th>
#       <th class="col_heading level0 col12" >HourlyRate</th>
#       <th class="col_heading level0 col13" >JobInvolvement</th>
#       <th class="col_heading level0 col14" >JobLevel</th>
#       <th class="col_heading level0 col15" >JobRole</th>
#       <th class="col_heading level0 col16" >JobSatisfaction</th>
#       <th class="col_heading level0 col17" >MaritalStatus</th>
#       <th class="col_heading level0 col18" >MonthlyIncome</th>
#       <th class="col_heading level0 col19" >MonthlyRate</th>
#       <th class="col_heading level0 col20" >NumCompaniesWorked</th>
#       <th class="col_heading level0 col21" >Over18</th>
#       <th class="col_heading level0 col22" >OverTime</th>
#       <th class="col_heading level0 col23" >PercentSalaryHike</th>
#       <th class="col_heading level0 col24" >PerformanceRating</th>
#       <th class="col_heading level0 col25" >RelationshipSatisfaction</th>
#       <th class="col_heading level0 col26" >StandardHours</th>
#       <th class="col_heading level0 col27" >StockOptionLevel</th>
#       <th class="col_heading level0 col28" >TotalWorkingYears</th>
#       <th class="col_heading level0 col29" >TrainingTimesLastYear</th>
#       <th class="col_heading level0 col30" >WorkLifeBalance</th>
#       <th class="col_heading level0 col31" >YearsAtCompany</th>
#       <th class="col_heading level0 col32" >YearsInCurrentRole</th>
#       <th class="col_heading level0 col33" >YearsSinceLastPromotion</th>
#       <th class="col_heading level0 col34" >YearsWithCurrManager</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9112_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9112_row0_col0" class="data row0 col0" >41</td>
#       <td id="T_e9112_row0_col1" class="data row0 col1" >Yes</td>
#       <td id="T_e9112_row0_col2" class="data row0 col2" >Travel_Rarely</td>
#       <td id="T_e9112_row0_col3" class="data row0 col3" >1102</td>
#       <td id="T_e9112_row0_col4" class="data row0 col4" >Sales</td>
#       <td id="T_e9112_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_e9112_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_e9112_row0_col7" class="data row0 col7" >Life Sciences</td>
#       <td id="T_e9112_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_e9112_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_e9112_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_e9112_row0_col11" class="data row0 col11" >Female</td>
#       <td id="T_e9112_row0_col12" class="data row0 col12" >94</td>
#       <td id="T_e9112_row0_col13" class="data row0 col13" >3</td>
#       <td id="T_e9112_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_e9112_row0_col15" class="data row0 col15" >Sales Executive</td>
#       <td id="T_e9112_row0_col16" class="data row0 col16" >4</td>
#       <td id="T_e9112_row0_col17" class="data row0 col17" >Single</td>
#       <td id="T_e9112_row0_col18" class="data row0 col18" >5993</td>
#       <td id="T_e9112_row0_col19" class="data row0 col19" >19479</td>
#       <td id="T_e9112_row0_col20" class="data row0 col20" >8</td>
#       <td id="T_e9112_row0_col21" class="data row0 col21" >Y</td>
#       <td id="T_e9112_row0_col22" class="data row0 col22" >Yes</td>
#       <td id="T_e9112_row0_col23" class="data row0 col23" >11</td>
#       <td id="T_e9112_row0_col24" class="data row0 col24" >3</td>
#       <td id="T_e9112_row0_col25" class="data row0 col25" >1</td>
#       <td id="T_e9112_row0_col26" class="data row0 col26" >80</td>
#       <td id="T_e9112_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_e9112_row0_col28" class="data row0 col28" >8</td>
#       <td id="T_e9112_row0_col29" class="data row0 col29" >0</td>
#       <td id="T_e9112_row0_col30" class="data row0 col30" >1</td>
#       <td id="T_e9112_row0_col31" class="data row0 col31" >6</td>
#       <td id="T_e9112_row0_col32" class="data row0 col32" >4</td>
#       <td id="T_e9112_row0_col33" class="data row0 col33" >0</td>
#       <td id="T_e9112_row0_col34" class="data row0 col34" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e9112_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9112_row1_col0" class="data row1 col0" >49</td>
#       <td id="T_e9112_row1_col1" class="data row1 col1" >No</td>
#       <td id="T_e9112_row1_col2" class="data row1 col2" >Travel_Frequently</td>
#       <td id="T_e9112_row1_col3" class="data row1 col3" >279</td>
#       <td id="T_e9112_row1_col4" class="data row1 col4" >Research & Development</td>
#       <td id="T_e9112_row1_col5" class="data row1 col5" >8</td>
#       <td id="T_e9112_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_e9112_row1_col7" class="data row1 col7" >Life Sciences</td>
#       <td id="T_e9112_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_e9112_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_e9112_row1_col10" class="data row1 col10" >3</td>
#       <td id="T_e9112_row1_col11" class="data row1 col11" >Male</td>
#       <td id="T_e9112_row1_col12" class="data row1 col12" >61</td>
#       <td id="T_e9112_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_e9112_row1_col14" class="data row1 col14" >2</td>
#       <td id="T_e9112_row1_col15" class="data row1 col15" >Research Scientist</td>
#       <td id="T_e9112_row1_col16" class="data row1 col16" >2</td>
#       <td id="T_e9112_row1_col17" class="data row1 col17" >Married</td>
#       <td id="T_e9112_row1_col18" class="data row1 col18" >5130</td>
#       <td id="T_e9112_row1_col19" class="data row1 col19" >24907</td>
#       <td id="T_e9112_row1_col20" class="data row1 col20" >1</td>
#       <td id="T_e9112_row1_col21" class="data row1 col21" >Y</td>
#       <td id="T_e9112_row1_col22" class="data row1 col22" >No</td>
#       <td id="T_e9112_row1_col23" class="data row1 col23" >23</

# %%
data.iloc[3]
# Out:
# Age                                             33
# Attrition                                       No
# BusinessTravel                   Travel_Frequently
# DailyRate                                     1392
# Department                  Research & Development
# DistanceFromHome                                 3
# Education                                        4
# EducationField                       Life Sciences
# EmployeeCount                                    1
# EmployeeNumber                                   5
# EnvironmentSatisfaction                          4
# Gender                                      Female
# HourlyRate                                      56
# JobInvolvement                                   3
# JobLevel                                         1
# JobRole                         Research Scientist
# JobSatisfaction                                  3
# MaritalStatus                              Married
# MonthlyIncome                                 2909
# MonthlyRate                                  23159
# NumCompaniesWorked                               1
# Over18                                           Y
# OverTime                                       Yes
# PercentSalaryHike                               11
# PerformanceRating                                3
# RelationshipSatisfaction                         3
# StandardHours                                   80
# StockOptionLevel                                 0
# TotalWorkingYears                                8
# TrainingTimesLastYear                            3
# WorkLifeBalance                                  3
# YearsAtCompany                                   8
# YearsInCurrentRole                               7
# YearsSinceLastPromotion                          3
# YearsWithCurrManager                             0
# Name: 3, dtype: object

# %%
data.iloc[5:7]
# data.iloc[5:7,0:2]
# data.iloc[:1000:-1]
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 5                 2          2  Life Sciences              1               8
# 6                 3          3        Medical              1              10
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 5  ...                         3            80                 0
# 6  ...                         1            80                 3
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 5                  8                      2               2               7
# 6                 12                      3               2               1
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 5                  7                        3                     6
# 6                  0                        0                     0
#
# [2 rows x 35 columns]

# %%
#Defining the function for binning the age variable.

def age_cat(x):
    if x>20 and x<30:
        return '20-30'
    elif x>30 and x<40:
        return '30-40'
    elif x>40 and x<50:
        return '40-50'
    else:
        return '50-60'
    
data['Age'].apply(age_cat).value_counts()
# Out:
# 30-40    562
# 50-60    318
# 20-30    298
# 40-50    292
# Name: Age, dtype: int64

# %%
#Defining the function which will bin the numerical DistanceFromHome variable into Categories

def distance_from_home(x):
    if x <= 2:
        return 'Near'
    elif x > 2 and x <=5:
        return 'Far'
    elif x >5:
        return 'Extremely Far'

data['DistanceFromHome'].apply(distance_from_home).value_counts()
# Out:
# Extremely Far    838
# Near             419
# Far              213
# Name: DistanceFromHome, dtype: int64

# %%
#Defining function

def experience_categorization(x):
    if x <= 2:
        return 'novice'
    elif x > 2 and x <= 5:
        return 'intermediate'
    elif x > 5:
        return 'experienced'
    
data['TotalWorkingYears'].apply(experience_categorization).value_counts()
# Out:
# experienced     1154
# intermediate     193
# novice           123
# Name: TotalWorkingYears, dtype: int64

# %% [markdown]
# ## Groupby

# %%
#Grouping the employee details by Department
data.groupby(data['Department']).agg('mean')
# Out:
#                               Age   DailyRate  DistanceFromHome  Education  \
# Department
# Human Resources         37.809524  751.539683          8.698413   2.968254
# Research & Development  37.042664  806.851197          9.144641   2.899063
# Sales                   36.542601  800.275785          9.365471   2.934978
#
#                         EmployeeCount  EmployeeNumber  \
# Department
# Human Resources                   1.0     1205.269841
# Research & Development            1.0     1006.503642
# Sales                             1.0     1038.946188
#
#                         EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Department
# Human Resources                        2.682540   64.301587        2.746032
# Research & Development                 2.744017   66.167534        2.741935
# Sales                                  2.679372   65.520179        2.701794
#
#                         JobLevel  ...  RelationshipSatisfaction  \
# Department                        ...
# Human Resources         2.031746  ...                  2.888889
# Research & Development  1.977107  ...                  2.708637
# Sales                   2.255605  ...                  2.695067
#
#                         StandardHours  StockOptionLevel  TotalWorkingYears  \
# Department
# Human Resources                  80.0          0.777778          11.555556
# Research & Development           80.0          0.804370          11.342352
# Sales                            80.0          0.773543          11.105381
#
#                         TrainingTimesLastYear  WorkLifeBalance  \
# Department
# Human Resources                      2.555556         2.920635
# Research & Development               2.792924         2.725286
# Sales                                2.847534         2.816143
#
#                         YearsAtCompany  YearsInCurrentRole  \
# Department
# Human Resources               7.238095            3.539683
# Research & Development        6.864724            4.155047
# Sales                         7.284753            4.486547
#
#                         YearsSinceLastPromotion  YearsWithCurrManager
# Department
# Human Resources                        1.777778              3.666667
# Research & Development                 2.137357              4.084287
# Sales                                  2.354260              4.271300
#
# [3 rows x 26 columns]

# %%
data[['Age','MonthlyIncome','Department']].groupby(data['Department']).agg('mean')
# Out:
#                               Age  MonthlyIncome
# Department
# Human Resources         37.809524    6654.507937
# Research & Development  37.042664    6281.252862
# Sales                   36.542601    6959.172646

# %%
data[['Age','Department']].groupby(data['Department']).agg('median')
# data[['Age','Department']].groupby(data['Department']).agg('mean')
# data[['Age','Department']].groupby(data['Department']).agg('sum')
# data[['Age','Department']].groupby(data['Department']).agg('min')
# data[['Age','Department']].groupby(data['Department']).agg('max')
# data[['Age','Department']].groupby(data['Department']).agg('var')
# data[['Age','Department']].groupby(data['Department']).agg('std')
# data[['Age','Department']].groupby(data['Department']).agg('count')
# data[['Age','Department']].groupby(data['Department']).agg('nunique')
# Out:
#                          Age
# Department
# Human Resources         37.0
# Research & Development  36.0
# Sales                   35.0

# %%
# data[['Age','Department']].groupby(data['Department']).agg('mean')
data[['Age','Department']].groupby(data['Department']).agg('mean').style.background_gradient(cmap = 'copper')
# data[['Age','Department']].groupby(data['Department']).agg('mean').style.background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_49171_row0_col0 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_49171_row1_col0 {
#   background-color: #7d4f32;
#   color: #f1f1f1;
# }
# #T_49171_row2_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_49171_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49171_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_49171_row0_col0" class="data row0 col0" >37.809524</td>
#     </tr>
#     <tr>
#       <th id="T_49171_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_49171_row1_col0" class="data row1 col0" >37.042664</td>
#     </tr>
#     <tr>
#       <th id="T_49171_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_49171_row2_col0" class="data row2 col0" >36.542601</td>
#     </tr>
#   </tbody>
# </table>

# %%
data[['Age','Department']].groupby(data['Department']).agg(['min','max'])
# Out:
#                        Age                  Department
#                        min max                     min                     max
# Department
# Human Resources         19  59         Human Resources         Human Resources
# Research & Development  18  60  Research & Development  Research & Development
# Sales                   18  60                   Sales                   Sales

# %%
data.pivot_table(values ='Age', index = 'Department', aggfunc = ['min','max'])
# Out:
#                        min max
#                        Age Age
# Department
# Human Resources         19  59
# Research & Development  18  60
# Sales                   18  60

# %%
data2 = data.loc[data.groupby(data['Department'])['MonthlyIncome'].idxmax()][['EmployeeNumber','Department','MonthlyIncome']]
data2
# Out:
#      EmployeeNumber              Department  MonthlyIncome
# 956            1338         Human Resources          19717
# 190             259  Research & Development          19999
# 918            1282                   Sales          19847

# %%
data2 = data[['Attrition','Department','MonthlyIncome','Age']].groupby([data['Attrition'],data['Department']]).agg('mean')
data2
# Out:
#                                   MonthlyIncome        Age
# Attrition Department
# No        Human Resources           7345.980392  39.627451
#           Research & Development    6630.326087  37.615942
#           Sales                     7232.240113  37.135593
# Yes       Human Resources           3715.750000  30.083333
#           Research & Development    4108.075188  33.473684
#           Sales                     5908.456522  34.260870

# %%
for index, row in data2.iterrows():
    print("Index: {} Rows: {}".format(index, row.values))
# Out:
# Index: ('No', 'Human Resources') Rows: [7345.98039216   39.62745098]
# Index: ('No', 'Research & Development') Rows: [6630.32608696   37.61594203]
# Index: ('No', 'Sales') Rows: [7232.24011299   37.13559322]
# Index: ('Yes', 'Human Resources') Rows: [3715.75         30.08333333]
# Index: ('Yes', 'Research & Development') Rows: [4108.07518797   33.47368421]
# Index: ('Yes', 'Sales') Rows: [5908.45652174   34.26086957]

# %%
for row in data2.itertuples():
    print(row)
# Out:
# Pandas(Index=('No', 'Human Resources'), MonthlyIncome=7345.980392156863, Age=39.627450980392155)
# Pandas(Index=('No', 'Research & Development'), MonthlyIncome=6630.326086956522, Age=37.61594202898551)
# Pandas(Index=('No', 'Sales'), MonthlyIncome=7232.24011299435, Age=37.13559322033898)
# Pandas(Index=('Yes', 'Human Resources'), MonthlyIncome=3715.75, Age=30.083333333333332)
# Pandas(Index=('Yes', 'Research & Development'), MonthlyIncome=4108.075187969925, Age=33.473684210526315)
# Pandas(Index=('Yes', 'Sales'), MonthlyIncome=5908.45652173913, Age=34.26086956521739)

# %%
# lets define a function to divide the Daily Rate by 100
def function(x):
    return x/10

data['DailyRate'] = data['DailyRate'].map(function)
data['DailyRate']
# Out:
# 0       110.2
# 1        27.9
# 2       137.3
# 3       139.2
# 4        59.1
#         ...
# 1465     88.4
# 1466     61.3
# 1467     15.5
# 1468    102.3
# 1469     62.8
# Name: DailyRate, Length: 1470, dtype: float64

# %%
data[['DailyRate','MonthlyRate']].apply(function).head()
# Out:
#    DailyRate  MonthlyRate
# 0      11.02       1947.9
# 1       2.79       2490.7
# 2      13.73        239.6
# 3      13.92       2315.9
# 4       5.91       1663.2

# %%
data['MonthlyRate'] = data['MonthlyRate'].apply(lambda x: x/10)
data['MonthlyRate']
# Out:
# 0       1947.9
# 1       2490.7
# 2        239.6
# 3       2315.9
# 4       1663.2
#          ...
# 1465    1229.0
# 1466    2145.7
# 1467     517.4
# 1468    1324.3
# 1469    1022.8
# Name: MonthlyRate, Length: 1470, dtype: float64

# %%
data[['MonthlyIncome','Department']].groupby(data['Department']).agg('mean').plot(kind = 'bar')
# data[['MonthlyIncome','Department']].groupby(data['Department']).agg('mean').plot(kind = 'line')
# data[['MonthlyIncome','Department']].groupby(data['Department']).agg('mean').plot(kind = 'area')
# Out:
# <AxesSubplot:xlabel='Department'>

# %%
# let's make a pivot table for the department and their mean ages

data.pivot_table(values ='MonthlyIncome', index = 'Department', aggfunc = 'mean')
# Out:
#                         MonthlyIncome
# Department
# Human Resources           6654.507937
# Research & Development    6281.252862
# Sales                     6959.172646

# %%
# let's make a pivot table for the department and their mean ages

data.pivot_table(values ='MonthlyIncome', index = 'Department', aggfunc = 'mean').style.background_gradient(cmap ='copper')
# Out:
# <style type="text/css">
# #T_7c998_row0_col0 {
#   background-color: #ad6d46;
#   color: #f1f1f1;
# }
# #T_7c998_row1_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_7c998_row2_col0 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# </style>
# <table id="T_7c998_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MonthlyIncome</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c998_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_7c998_row0_col0" class="data row0 col0" >6654.507937</td>
#     </tr>
#     <tr>
#       <th id="T_7c998_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_7c998_row1_col0" class="data row1 col0" >6281.252862</td>
#     </tr>
#     <tr>
#       <th id="T_7c998_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_7c998_row2_col0" class="data row2 col0" >6959.172646</td>
#     </tr>
#   </tbody>
# </table>

# %%
# let's make a pivot table for the department and their mean ages

data.pivot_table(values ='MonthlyIncome', index = 'Department', aggfunc = 'mean').plot(kind = 'line')
# Out:
# <AxesSubplot:xlabel='Department'>

# %% [markdown]
# ## Simple Filtering Operations

# %%
# Employees who are working more than 35 years at the company
data[data['YearsAtCompany'] > 35]
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 98     58        No  Travel_Rarely       68.2                   Sales
# 126    58       Yes  Travel_Rarely       14.7  Research & Development
# 270    55        No  Travel_Rarely       45.2  Research & Development
# 1116   55        No  Travel_Rarely       68.5                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 98                  10          4        Medical              1
# 126                 23          4        Medical              1
# 270                  1          3        Medical              1
# 1116                26          5      Marketing              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 98               131  ...                         3            80
# 126              165  ...                         4            80
# 270              374  ...                         3            80
# 1116            1578  ...                         3            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 98                   0                 38                      1
# 126                  1                 40                      3
# 270                  0                 37                      2
# 1116                 1                 36                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 98                 2              37                 10
# 126                2              40                 10
# 270                3              36                 10
# 1116               3              36                  6
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 98                          1                     8
# 126                        15                     6
# 270                         4                    13
# 1116                        2                    13
#
# [4 rows x 35 columns]

# %%
# employees who get more than 19000 dollars
data[data['MonthlyIncome'] > 19000]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 25     53        No      Travel_Rarely      128.2  Research & Development
# 45     41       Yes      Travel_Rarely      136.0  Research & Development
# 123    51        No      Travel_Rarely       68.4  Research & Development
# 165    50        No      Travel_Rarely      145.2  Research & Development
# 186    40        No      Travel_Rarely       98.9  Research & Development
# 190    52        No      Travel_Rarely       69.9  Research & Development
# 231    42        No      Travel_Rarely       53.2  Research & Development
# 233    50        No      Travel_Rarely       85.4                   Sales
# 237    52        No         Non-Travel       77.1                   Sales
# 244    45        No      Travel_Rarely       25.2  Research & Development
# 257    40        No      Travel_Rarely      141.6  Research & Development
# 270    55        No      Travel_Rarely       45.2  Research & Development
# 279    50        No      Travel_Rarely       79.7  Research & Development
# 326    39        No  Travel_Frequently       67.2  Research & Development
# 392    54        No      Travel_Rarely       82.1  Research & Development
# 400    39        No  Travel_Frequently      121.8  Research & Development
# 411    60        No      Travel_Rarely       42.2  Research & Development
# 473    49        No      Travel_Rarely      124.5  Research & Development
# 497    44        No      Travel_Rarely      131.5  Research & Development
# 535    41        No      Travel_Rarely       42.7         Human Resources
# 538    41        No      Travel_Rarely       31.4         Human Resources
# 568    55       Yes      Travel_Rarely       72.5  Research & Development
      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 25                 2              14                 13
# 45                 3              22                 15
# 123                3              20                 18
# 165                3               5                  4
# 186                3              20                  8
# 190                3              33                 18
# 231                3              22                 17
# 233                2               7                  0
# 237                4              33                  7
# 244                3              24                  0
# 257                3              21                  7
# 270                3              36                 10
# 279                2              10                  4
# 326                3              21                  9
# 392                2               4                  2
# 400                3              21                  8
# 411                1              29                  8
# 473                3              31                  9
# 497                4               2                  2
# 535                2              21                  6
# 538                3              22                  7
# 568                3               5                  2
# 595                3              31                 15
# 716                4              18                 16
# 746                3              21                 16
# 749                3              32                 14
# 766                2               8                  1
# 770                3               2                  2
# 814                4              20                  7
# 851                3               5                  2
# 869                3               4                  2
# 898                3               8                  7
# 918                2              29                 10
# 922                2              25                  9
# 955                3              19                  9
# 956                3               7                  3
# 1009               3               9                  8
# 1116               3              36                  6
# 1126               3               1                  0
# 1129               3               1                  0
# 1140               2              22                  7
# 1154               3               5                  2
# 1242               2              21                  8
# 1264               3               1                  0
# 1277               3               2                  1
# 1330               3              16                 12
# 1331               3              22                 10
# 1377               3               5                  4
# 1401               3              10                  9
# 1437               2               6                  0
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 25                          4                     8
# 45                         15                     8
# 123                        15                    15
# 165                         4                     4
# 186                         9                     9
# 190                        11                     9
# 231                        11                    15
# 233                         0                     6
# 237                        15                    12
# 244                         1                     7
# 257                         3                     9
# 270                         4                    13
# 279                         1                     6
# 326                        13                     3
# 392                         1                     2
# 400                         1                     6
# 411                        11                    10
# 473                         0                     9
# 497                         0                     1
# 535                        12                     6
# 538                         2                    10
# 568                         1                     4
# 595                        13                     8
# 716                         0                    11
# 746                         5                    10
# 749                         6                     9
# 766                         7                     7
# 770                         2                     2
# 814                         4                     9
# 851                         4                     2
# 869                         0                     3
# 898                         0                     7
# 918                        11                    10
# 922                        14                    13
# 955                         9                    11
# 956                         7                     7
# 1009                        1                     5
# 1116                        2                    13
# 1126                        0                     0
# 1129                        0                     1
# 1140                        1                    10
# 1154                        1                     0
# 1242                       12                     8
# 1264                        0                     0
# 1277                        2                     2
# 1330                        6                    14
# 1331                       12                     9
# 1377                        4                     3
# 1401                        1                     4
# 1437                        1                     3
#
# [50 rows x 35 columns]

# %%
# Filter all the employees who are getting lesser than average salary even after working for more than 10 years in the same role.
avg=data['MonthlyIncome'].mean()
data[(data['YearsInCurrentRole']>10) & (data['MonthlyIncome']<avg)]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 76     35        No      Travel_Rarely       77.6                   Sales
# 83     38        No         Non-Travel       57.3  Research & Development
# 103    34        No      Travel_Rarely       66.5  Research & Development
# 137    39        No      Travel_Rarely      132.9                   Sales
# 220    36        No      Travel_Rarely      139.6  Research & Development
# 269    36        No      Travel_Rarely      140.3  Research & Development
# 281    42        No      Travel_Rarely       63.5                   Sales
# 285    37        No      Travel_Rarely      137.2  Research & Development
# 319    32        No      Travel_Rarely       58.8                   Sales
# 398    37        No         Non-Travel      106.3  Research & Development
# 600    32        No      Travel_Rarely       85.9  Research & Development
# 621    36        No      Travel_Rarely       92.8                   Sales
# 686    41        No      Travel_Rarely       26.3  Research & Development
# 752    36       Yes      Travel_Rarely       88.5  Research & Development
# 778    46        No      Travel_Rarely      100.3  Research & Development
# 875    44        No      Travel_Rarely       20.0  Research & Development
# 927    36        No      Travel_Rarely       42.9  Research & Development
# 978    40        No      Travel_Rarely      120.2  Research & Development
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 76                 3              15                 13
# 83                 3              13                 11
# 103                3              16                 13
# 137                4              15                 11
# 220                4              13                 11
# 269                3              15                 13
# 281                3              20                 16
# 285                3              17                 12
# 319                3              13                 12
# 398                3              13                 11
# 600                3              14                 13
# 621                2              18                 14
# 686                3              18                 13
# 752                3              17                 13
# 778                3              16                 13
# 875                3              20                 11
# 927                3              16                 14
# 978                3              12                 11
# 1095               3              15                 14
# 1150               3              16                 15
# 1157               3              14                 11
# 1187               4              13                 11
# 1210               3              14                 11
# 1267               3              15                 14
# 1373               3              20                 11
# 1416               3              15                 13
# 1441               2              13                 12
# 1447               2              15                 12
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 76                          2                     8
# 83                          1                     9
# 103                         2                    10
# 137                         5                     9
# 220                         3                     7
# 269                        10                    11
# 281                        11                     6
# 285                         5                     7
# 319                        11                     9
# 398                        10                     7
# 600                         6                     8
# 621                         4                    11
# 686                         2                    17
# 752                        15                    14
# 778                         1                     7
# 875                        13                    17
# 927                         5                    12
# 978                        11                     8
# 1095                        5                     7
# 1150                        1                    10
# 1157                        2                     9
# 1187                        2                     9
# 1210                        2                    13
# 1267                        0                     7
# 1373                        0                     7
# 1416                        5                     8
# 1441                        1                     9
# 1447                       11                    11
#
# [28 rows x 35 columns]

# %%
# lets find out employees who do not travel or travel frequently and get more than 15000 dollars monthly salary 
x = data[(data['BusinessTravel'] == 'Non-Travel') | (data['BusinessTravel'] == 'Travel_Frequently')]
x[data['MonthlyIncome'] > 15000][['BusinessTravel','MonthlyIncome']].head()
# Out:
# /var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/ipykernel_8339/3294906330.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x[data['MonthlyIncome'] > 15000][['BusinessTravel','MonthlyIncome']].head()
#         BusinessTravel  MonthlyIncome
# 105         Non-Travel          18844
# 106  Travel_Frequently          18172
# 112         Non-Travel          17328
# 119  Travel_Frequently          16959
# 147  Travel_Frequently          17181

# %%
# let's first filter all the employees from sales department having more than 15000 dollars monthly salary
data[(data['Department'] == 'Sales') & (data['MonthlyIncome'] > 15000)].head()
# Out:
#      Age Attrition     BusinessTravel  DailyRate Department  DistanceFromHome  \
# 18    53        No      Travel_Rarely      121.9      Sales                 2
# 29    46        No      Travel_Rarely       70.5      Sales                 2
# 119   43        No  Travel_Frequently       39.4      Sales                26
# 233   50        No      Travel_Rarely       85.4      Sales                 1
# 235   43        No      Travel_Rarely      103.4      Sales                16
#
#      Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 18           4  Life Sciences              1              23  ...
# 29           4      Marketing              1              38  ...
# 119          2  Life Sciences              1             158  ...
# 233          4        Medical              1             323  ...
# 235          3      Marketing              1             327  ...
#
#      RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 18                          3            80                 0
# 29                          4            80                 0
# 119                         4            80                 2
# 233                         3            80                 1
# 235                         3            80                 1
#
#      TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 18                  31                      3               3              25
# 29                  22                      2               2               2
# 119                 25                      3               4              25
# 233                 32                      3               2               7
# 235                 22                      3               3              17
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 18                   8                        3                     7
# 29                   2                        2                     1
# 119                 12                        4                    12
# 233                  0                        0                     6
# 235                 13                        1                     9
#
# [5 rows x 35 columns]

# %%
# now we want to aggregate this date based on their attrition
x = data[(data['Department'] == 'Sales') & (data['MonthlyIncome'] > 15000)]
x[['Attrition','MonthlyIncome']].groupby(['Attrition']).mean()
# Out:
#            MonthlyIncome
# Attrition
# No          17631.827586
# Yes         19334.500000

# %% [markdown]
# ### Univariate Analysis on Numerical Variables

# %%
#Distributiong of Age variable
sns.distplot(data['Age'])
# Out:
# /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### Univariate Analysis on Categorical Variables

# %%
sns.countplot(data['BusinessTravel'])
# Out:
# /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# ### Correlation Heatmap

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar plot with Extra Variable

# %%
sns.barplot(data['Department'], data['MonthlyIncome'], data['Attrition'])
# Out:
# /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Department', ylabel='MonthlyIncome'>

# %% [markdown]
# ## CrossTabulation

# %%
pd.crosstab(data['Attrition'], data['Department'])
# Out:
# Department  Human Resources  Research & Development  Sales
# Attrition
# No                       51                     828    354
# Yes                      12                     133     92

# %%
pd.crosstab(data['Attrition'], data['Department']).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Attrition'>

# %%
pd.crosstab(data['Attrition'], data['Department']).plot(kind = 'bar', stacked = True)
# Out:
# <AxesSubplot:xlabel='Attrition'>

# %%
pd.crosstab(data['EducationField'], data['Department'])
# Out:
# Department        Human Resources  Research & Development  Sales
# EducationField
# Human Resources                27                       0      0
# Life Sciences                  16                     440    150
# Marketing                       0                       0    159
# Medical                        13                     363     88
# Other                           3                      64     15
# Technical Degree                4                      94     34

# %%
pd.crosstab(data['EducationField'], data['Department']).style.bar(color=['gold'])
# Out:
# <style type="text/css">
# #T_7cfc4_row0_col0, #T_7cfc4_row1_col1, #T_7cfc4_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 100.0%, transparent 100.0%);
# }
# #T_7cfc4_row0_col1, #T_7cfc4_row0_col2, #T_7cfc4_row2_col0, #T_7cfc4_row2_col1 {
#   width: 10em;
#   height: 80%;
# }
# #T_7cfc4_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 59.3%, transparent 59.3%);
# }
# #T_7cfc4_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 94.3%, transparent 94.3%);
# }
# #T_7cfc4_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 48.1%, transparent 48.1%);
# }
# #T_7cfc4_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 82.5%, transparent 82.5%);
# }
# #T_7cfc4_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 55.3%, transparent 55.3%);
# }
# #T_7cfc4_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 11.1%, transparent 11.1%);
# }
# #T_7cfc4_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 14.5%, transparent 14.5%);
# }
# #T_7cfc4_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 9.4%, transparent 9.4%);
# }
# #T_7cfc4_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 14.8%, transparent 14.8%);
# }
# #T_7cfc4_row5_col1, #T_7cfc4_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 21.4%, transparent 21.4%);
# }
# </style>
# <table id="T_7cfc4_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="col_heading level0 col0" >Human Resources</th>
#       <th class="col_heading level0 col1" >Research & Development</th>
#       <th class="col_heading level0 col2" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >EducationField</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cfc4_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_7cfc4_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_7cfc4_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7cfc4_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7cfc4_level0_row1" class="row_heading level0 row1" >Life Sciences</th>
#       <td id="T_7cfc4_row1_col0" class="data row1 col0" >16</td>
#       <td id="T_7cfc4_row1_col1" class="data row1 col1" >440</td>
#       <td id="T_7cfc4_row1_col2" class="data row1 col2" >150</td>
#     </tr>
#     <tr>
#       <th id="T_7cfc4_level0_row2" class="row_heading level0 row2" >Marketing</th>
#       <td id="T_7cfc4_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_7cfc4_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_7cfc4_row2_col2" class="data row2 col2" >159</td>
#     </tr>
#     <tr>
#       <th id="T_7cfc4_level0_row3" class="row_heading level0 row3" >Medical</th>
#       <td id="T_7cfc4_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_7cfc4_row3_col1" class="data row3 col1" >363</td>
#       <td id="T_7cfc4_row3_col2" class="data row3 col2" >88</td>
#     </tr>
#     <tr>
#       <th id="T_7cfc4_level0_row4" class="row_heading level0 row4" >Other</th>
#       <td id="T_7cfc4_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_7cfc4_row4_col1" class="data row4 col1" >64</td>
#       <td id="T_7cfc4_row4_col2" class="data row4 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_7cfc4_level0_row5" class="row_heading level0 row5" >Technical Degree</th>
#       <td id="T_7cfc4_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_7cfc4_row5_col1" class="data row5 col1" >94</td>
#       <td id="T_7cfc4_row5_col2" class="data row5 col2" >34</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby(['Department','JobRole'])[['MonthlyIncome','MonthlyRate','HourlyRate']].agg(['max','min','mean'])
data.groupby(['Department','JobRole'])[['MonthlyIncome','MonthlyRate','HourlyRate']].agg(['max','min','mean']).style.background_gradient(cmap='copper')
# Out:
# <style type="text/css">
# #T_5448f_row0_col0 {
#   background-color: #603d27;
#   color: #f1f1f1;
# }
# #T_5448f_row0_col1, #T_5448f_row3_col2, #T_5448f_row7_col2 {
#   background-color: #0c0805;
#   color: #f1f1f1;
# }
# #T_5448f_row0_col2 {
#   background-color: #20140d;
#   color: #f1f1f1;
# }
# #T_5448f_row0_col3 {
#   background-color: #ffb674;
#   color: #000000;
# }
# #T_5448f_row0_col4, #T_5448f_row0_col5, #T_5448f_row1_col3, #T_5448f_row1_col7, #T_5448f_row2_col4, #T_5448f_row2_col7, #T_5448f_row3_col7, #T_5448f_row4_col7, #T_5448f_row5_col7, #T_5448f_row6_col7, #T_5448f_row6_col8, #T_5448f_row7_col1, #T_5448f_row7_col7, #T_5448f_row8_col6, #T_5448f_row9_col7, #T_5448f_row10_col0, #T_5448f_row10_col1, #T_5448f_row10_col2, #T_5448f_row10_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_5448f_row0_col6, #T_5448f_row0_col7, #T_5448f_row1_col1, #T_5448f_row1_col2, #T_5448f_row1_col4, #T_5448f_row2_col6, #T_5448f_row3_col6, #T_5448f_row4_col0, #T_5448f_row4_col5, #T_5448f_row5_col6, #T_5448f_row6_col0, #T_5448f_row7_col3, #T_5448f_row7_col6, #T_5448f_row8_col7, #T_5448f_row8_col8, #T_5448f_row9_col3, #T_5448f_row9_col6, #T_5448f_row10_col6 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_5448f_row0_col8 {
#   background-color: #19100a;
#   color: #f1f1f1;
# }
# #T_5448f_row1_col0 {
#   background-color: #ffc37c;
#   color: #000000;
# }
# #T_5448f_row1_col5, #T_5448f_row7_col8 {
#   background-color: #b67349;
#   color: #f1f1f1;
# }
# #T_5448f_row1_col6, #T_5448f_row4_col6, #T_5448f_row6_col6 {
#   background-color: #ffa66a;
#   color: #000000;
# }
# #T_5448f_row1_col8 {
#   background-color: #462d1c;
#   color: #f1f1f1;
# }
# #T_5448f_row2_col0, #T_5448f_row5_col0 {
#   background-color: #ad6d46;
#   color: #f1f1f1;
# }
# #T_5448f_row2_col1, #T_5448f_row9_col1 {
#   background-color: #482d1d;
#   color: #f1f1f1;
# }
# #T_5448f_row2_col2, #T_5448f_row7_col5 {
#   background-color: #643f28;
#   color: #f1f1f1;
# }
# #T_5448f_row2_col3 {
#   background-color: #c27b4e;
#   color: #f1f1f1;
# }
# #T_5448f_row2_col5 {
#   background-color: #af6f47;
#   color: #f1f1f1;
# }
# #T_5448f_row2_col8 {
#   background-color: #bd784c;
#   color: #f1f1f1;
# }
# #T_5448f_row3_col0 {
#   background-color: #110b07;
#   color: #f1f1f1;
# }
# #T_5448f_row3_col1, #T_5448f_row3_col4 {
#   background-color: #010100;
#   color: #f1f1f1;
# }
# #T_5448f_row3_col3, #T_5448f_row8_col2 {
#   background-color: #ffb976;
#   color: #000000;
# }
# #T_5448f_row3_col5 {
#   background-color: #7a4d31;
#   color: #f1f1f1;
# }
# #T_5448f_row3_col8 {
#   background-color: #b37148;
#   color: #f1f1f1;
# }
# #T_5448f_row4_col1 {
#   background-color: #f89d64;
#   color: #000000;
# }
# #T_5448f_row4_col2 {
#   background-color: #ffbb77;
#   color: #000000;
# }
# #T_5448f_row4_col3 {
#   background-color: #cd8253;
#   color: #f1f1f1;
# }
# #T_5448f_row4_col4 {
#   background-color: #382316;
#   color: #f1f1f1;
# }
# #T_5448f_row4_col8 {
#   background-color: #7e5033;
#   color: #f1f1f1;
# }
# #T_5448f_row5_col1, #T_5448f_row7_col0, #T_5448f_row10_col4 {
#   background-color: #492e1d;
#   color: #f1f1f1;
# }
# #T_5448f_row5_col2 {
#   background-color: #5f3c26;
#   color: #f1f1f1;
# }
# #T_5448f_row5_col3 {
#   background-color: #fea166;
#   color: #000000;
# }
# #T_5448f_row5_col4 {
#   background-color: #25170f;
#   color: #f1f1f1;
# }
# #T_5448f_row5_col5 {
#   background-color: #bc774c;
#   color: #f1f1f1;
# }
# #T_5448f_row5_col8 {
#   background-color: #4d301f;
#   color: #f1f1f1;
# }
# #T_5448f_row6_col1 {
#   background-color: #f39a62;
#   color: #000000;
# }
# #T_5448f_row6_col2 {
#   background-color: #ffad6e;
#   color: #000000;
# }
# #T_5448f_row6_col3 {
#   background-color: #ffb170;
#   color: #000000;
# }
# #T_5448f_row6_col4 {
#   background-color: #050302;
#   color: #f1f1f1;
# }
# #T_5448f_row6_col5 {
#   background-color: #ffb372;
#   color: #000000;
# }
# #T_5448f_row7_col4 {
#   background-color: #040201;
#   color: #f1f1f1;
# }
# #T_5448f_row8_col0 {
#   background-color: #ffc67e;
#   color: #000000;
# }
# #T_5448f_row8_col1 {
#   background-color: #ffa267;
#   color: #000000;
# }
# #T_5448f_row8_col3 {
#   background-color: #090503;
#   color: #f1f1f1;
# }
# #T_5448f_row8_col4 {
#   background-color: #40291a;
#   color: #f1f1f1;
# }
# #T_5448f_row8_col5 {
#   background-color: #ffb875;
#   color: #000000;
# }
# #T_5448f_row9_col0 {
#   background-color: #aa6c45;
#   color: #f1f1f1;
# }
# #T_5448f_row9_col2 {
#   background-color: #583723;
#   color: #f1f1f1;
# }
# #T_5448f_row9_col4 {
#   background-color: #060402;
#   color: #f1f1f1;
# }
# #T_5448f_row9_col5 {
#   background-color: #bb764b;
#   color: #f1f1f1;
# }
# #T_5448f_row9_col8 {
#   background-color: #674129;
#   color: #f1f1f1;
# }
# #T_5448f_row10_col3 {
#   background-color: #ffc07a;
#   color: #000000;
# }
# #T_5448f_row10_col5 {
#   background-color: #9c623f;
#   color: #f1f1f1;
# }
# #T_5448f_row10_col8 {
#   background-color: #23160e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5448f_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="3">MonthlyIncome</th>
#       <th class="col_heading level0 col3" colspan="3">MonthlyRate</th>
#       <th class="col_heading level0 col6" colspan="3">HourlyRate</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >max</th>
#       <th class="col_heading level1 col1" >min</th>
#       <th class="col_heading level1 col2" >mean</th>
#       <th class="col_heading level1 col3" >max</th>
#       <th class="col_heading level1 col4" >min</th>
#       <th class="col_heading level1 col5" >mean</th>
#       <th class="col_heading level1 col6" >max</th>
#       <th class="col_heading level1 col7" >min</th>
#       <th class="col_heading level1 col8" >mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="index_name level1" >JobRole</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5448f_level0_row0" class="row_heading level0 row0" rowspan="2">Human Resources</th>
#       <th id="T_5448f_level1_row0" class="row_heading level1 row0" >Human Resources</th>
#       <td id="T_5448f_row0_col0" class="data row0 col0" >10725</td>
#       <td id="T_5448f_row0_col1" class="data row0 col1" >1555</td>
#       <td id="T_5448f_row0_col2" class="data row0 col2" >4235.750000</td>
#       <td id="T_5448f_row0_col3" class="data row0 col3" >2689.400000</td>
#       <td id="T_5448f_row0_col4" class="data row0 col4" >209.700000</td>
#       <td id="T_5448f_row0_col5" class="data row0 col5" >1329.240385</td>
#       <td id="T_5448f_row0_col6" class="data row0 col6" >100</td>
#       <td id="T_5448f_row0_col7" class="data row0 col7" >31</td>
#       <td id="T_5448f_row0_col8" class="data row0 col8" >64.173077</td>
#     </tr>
#     <tr>
#       <th id="T_5448f_level1_row1" class="row_heading level1 row1" >Manager</th>
#       <td id="T_5448f_row1_col0" class="data row1 col0" >19717</td>
#       <td id="T_5448f_row1_col1" class="data row1 col1" >14026</td>
#       <td id="T_5448f_row1_col2" class="data row1 col2" >18088.636364</td>
#       <td id="T_5448f_row1_col3" class="data row1 col3" >2581.100000</td>
#       <td id="T_5448f_row1_col4" class="data row1 col4" >402.200000</td>
#       <td id="T_5448f_row1_col5" class="data row1 col5" >1444.118182</td>
#       <td id="T_5448f_row1_col6" class="data row1 col6" >99</td>
#       <td id="T_5448f_row1_col7" class="data row1 col7" >30</td>
#       <td id="T_5448f_row1_col8" class="data row1 col8" >64.909091</td>
#     </tr>
#     <tr>
#       <th id="T_5448f_level0_row2" class="row_heading level0 row2" rowspan="6">Research & Development</th>
#       <th id="T_5448f_level1_row2" class="row_heading level1 row2" >Healthcare Representative</th>
#       <td id="T_5448f_row2_col0" class="data row2 col0" >13966</td>
#       <td id="T_5448f_row2_col1" class="data row2 col1" >4000</td>
#       <td id="T

# %% [markdown]
# ## ipywidgets-employee

# %%
#importing libraries
import pandas as pd
from ipywidgets import interact

# %%
@interact
def groupby(column=list(data.select_dtypes('object').columns)):
    return data[['Age',column]].groupby([data[column]]).agg(['mean'])
# Out:
# interactive(children=(Dropdown(description='column', options=('Attrition', 'BusinessTravel', 'Department', 'Ed…

# %%
@interact
def groupby(column = list(data.select_dtypes('object').columns),
            index = list(data.select_dtypes('number').columns)):
    return data[[index, column]].groupby([data[column]]).agg(['mean'])
# Out:
# interactive(children=(Dropdown(description='column', options=('Attrition', 'BusinessTravel', 'Department', 'Ed…

# %%
@interact
def filter_emp(column='MonthlyIncome',salary=19900):
    return data[data[column]>salary]
# Out:
# interactive(children=(Text(value='MonthlyIncome', description='column'), IntSlider(value=19900, description='s…

# %%
@interact
def filter_emp(column='MonthlyIncome',salary=19900):
    return data[data[column]>salary][['EmployeeNumber','EducationField','Department','MonthlyIncome']]
# Out:
# interactive(children=(Text(value='MonthlyIncome', description='column'), IntSlider(value=19900, description='s…

# %%
@interact
def filter_emp(column='MonthlyIncome',salary=19900):
    return data[data[column]>salary][['EmployeeNumber',
                                      'EducationField',
                                      'Department',
                                      'MonthlyIncome']].sort_values(by='MonthlyIncome',ascending=False)
# Out:
# interactive(children=(Text(value='MonthlyIncome', description='column'), IntSlider(value=19900, description='s…

# %% [markdown]
# ## Remove unnecessary columns

# %%
#All the three columns has unique value for the whole dataset. So these columns won't make any difference to the
#target variable. Hence, we drop these three variables from our dataset.

data=data.drop(['StandardHours','EmployeeCount','Over18'],axis=1)
data['EmployeeNumber'].nunique()
# Out:
# 1470

# %%
#There are 1470 rows in the dataset and 1470 different values in the EmployeeNumber column. So, there is no point
#of keeping this variable as it has different values for different employess.

data=data.drop('EmployeeNumber',axis=1)

# %%
#variables Job Level and Monthly Income are highly correlated with a correlation of 0.95 and 
#the variable years in company is highly correlated with years in current role and years with current manager.

data=data.drop(['JobLevel','YearsInCurrentRole','YearsWithCurrManager'],axis=1)
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsSinceLastPromotion'],
#       dtype='object')

# %%
#Finding the correlation among all the variables 

plt.rcParams['figure.figsize']=(18,10)
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>
