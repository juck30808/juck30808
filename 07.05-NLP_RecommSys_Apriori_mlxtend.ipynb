# %% [markdown]
# ## Market Basket Analysis with Python

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("input/Market_Basket_Optimisation.csv", header=None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
# Create a list of transaction
df['Transactions']= df.values.tolist()
df['Transactions']
# Out:
# 0       [shrimp, almonds, avocado, vegetables mix, gre...
# 1       [burgers, meatballs, eggs, nan, nan, nan, nan,...
# 2       [chutney, nan, nan, nan, nan, nan, nan, nan, n...
# 3       [turkey, avocado, nan, nan, nan, nan, nan, nan...
# 4       [mineral water, milk, energy bar, whole wheat ...
#                               ...
# 7496    [butter, light mayo, fresh bread, nan, nan, na...
# 7497    [burgers, frozen vegetables, eggs, french frie...
# 7498    [chicken, nan, nan, nan, nan, nan, nan, nan, n...
# 7499    [escalope, green tea, nan, nan, nan, nan, nan,...
# 7500    [eggs, frozen smoothie, yogurt cake, low fat y...
# Name: Transactions, Length: 7501, dtype: object

# %%
# Delete NaN from the transaction list
df['Transactions'] = df['Transactions'].apply(lambda x: [i for i in x if str(i) != "nan"])
df['Transactions']
# Out:
# 0       [shrimp, almonds, avocado, vegetables mix, gre...
# 1                              [burgers, meatballs, eggs]
# 2                                               [chutney]
# 3                                       [turkey, avocado]
# 4       [mineral water, milk, energy bar, whole wheat ...
#                               ...
# 7496                    [butter, light mayo, fresh bread]
# 7497    [burgers, frozen vegetables, eggs, french frie...
# 7498                                            [chicken]
# 7499                                [escalope, green tea]
# 7500    [eggs, frozen smoothie, yogurt cake, low fat y...
# Name: Transactions, Length: 7501, dtype: object

# %%
# Convert the transaction list from a DataFrame column into a list of strings
transactions = list(df['Transactions'])
transactions.count(['burgers', 'meatballs', 'eggs'])
# Out:
# 1

# %% [markdown]
# ### 1.Count the number of rules

# %%
# Import library to count the number of permutations
from itertools import permutations

# Extract unique items.
unique_items = [item for transaction in transactions for item in transaction]

# Convert the unique item list from a string to a list
unique_item_list = list(set(unique_items))

# Compute and print rules.
rules = list(permutations(unique_item_list, 2))
print(len(rules))
print(rules)
# Out:
# 14280
# [('pepper', 'chicken'), ('pepper', 'bramble'), ('pepper', 'dessert wine'), ('pepper', 'champagne'), ('pepper', 'green grapes'), ('pepper', 'grated cheese'), ('pepper', 'oil'), ('pepper', 'vegetables mix'), ('pepper', 'black tea'), ('pepper', 'whole wheat pasta'), ('pepper', 'salad'), ('pepper', 'cider'), ('pepper', 'shallot'), ('pepper', 'milk'), ('pepper', 'red wine'), ('pepper', 'tomato sauce'), ('pepper', 'pancakes'), ('pepper', 'spinach'), ('pepper', 'burgers'), ('pepper', 'clothes accessories'), ('pepper', 'fresh bread'), ('pepper', 'meatballs'), ('pepper', 'ketchup'), ('pepper', 'herb & pepper'), ('pepper', 'fromage blanc'), ('pepper', 'energy bar'), ('pepper', 'water spray'), ('pepper', 'honey'), ('pepper', 'olive oil'), ('pepper', 'light mayo'), ('pepper', 'sandwich'), ('pepper', 'oatmeal'), ('pepper', 'yogurt cake'), ('pepper', 'cereals'), ('pepper', 'tomatoes'), ('pepper', 'cauliflower'), ('pepper', 'light cream'), ('pepper', 'mayonnaise'), ('pepper', 'turkey'), ('pepper', 'sparkling water'), ('pepper', 'flax seed'), ('pepper', 'soup'), ('pepper', 'parmesan cheese'), ('pepper', 'pet food'), ('pepper', 'magazines'), ('pepper', 'tomato juice'), ('pepper', 'cream'), ('pepper', 'chocolate bread'), ('pepper', 'salt'), ('pepper', 'corn'), ('pepper', 'yams'), ('pepper', 'hot dogs'), ('pepper', 'candy bars'), ('pepper', 'shrimp'), ('pepper', 'chili'), ('pepper', 'gums'), ('pepper', 'mint green tea'), ('pepper', 'eggplant'), ('pepper', 'escalope'), ('pepper', 'zucchini'), ('pepper', 'toothpaste'), ('pepper', 'babies food'), ('pepper', 'soda'), ('pepper', 'whole wheat rice'), ('pepper', 'green tea'), ('pepper', 'chutney'), ('pepper', 'pasta'), ('pepper', 'low fat yogurt'), ('pepper', 'green beans'), ('pepper', 'avocado'), ('pepper', 'carrots'), ('pepper', 'butter'), ('pepper', 'extra dark chocolate'), ('pepper', 'gluten free bar'), ('pepper', 'whole weat flour'), ('pepper', 'energy drink'), ('pepper', 'frozen vegetables'), ('pepper', 'brownies'), ('pepper', 'protein bar'), ('pepper', 'chocolate'), ('pepper', 'rice'), ('pepper', 'cake'), ('pepper', 'muffins'), ('pepper', 'mint'), ('pepper', 'mushroom cream sauce'), ('pepper', 'hand protein bar'), ('pepper', 'white wine'), ('pepper', 'cooking oil'), ('pepper', 'barbecue sauce'), ('pepper', 'spaghetti'), ('pepper', 'ham'), ('pepper', 'strong cheese'), ('pepper', 'pickles'), ('pepper', 'bug spray'), ('pepper', 'fresh tuna'), ('pepper', 'asparagus'), ('pepper', 'nonfat milk'), ('pepper', 'tea'), ('pepper', 'napkins'), ('pepper', 'almonds'), ('pepper', 'antioxydant juice'), ('pepper', 'melons'), ('pepper', ' asparagus'), ('pepper', 'bacon'), ('pepper', 'body spray'), ('pepper', 'cottage cheese'), ('pepper', 'mashed potato'), ('pepper', 'burger sauce'), ('pepper', 'frozen smoothie'), ('pepper', 'cookies'), ('pepper', 'salmon'), ('pepper', 'french wine'), ('pepper', 'strawberries'), ('pepper', 'eggs'), ('pepper', 'french fries'), ('pepper', 'ground beef'), ('pepper', 'blueberries'), ('pepper', 'shampoo'), ('pepper', 'mineral water'), ('chicken', 'pepper'), ('chicken', 'bramble'), ('chicken', 'dessert wine'), ('chicken', 'champagne'), ('chicken', 'green grapes'), ('chicken', 'grated cheese'), ('chicken', 'oil'), ('chicken', 'vegetables mix'), ('chicken', 'black tea'), ('chicken', 'whole wheat pasta'), ('chicken', 'salad'), ('chicken', 'cider'), ('chicken', 'shallot'), ('chicken', 'milk'), ('chicken', 'red wine'), ('chicken', 'tomato sauce'), ('chicken', 'pancakes'), ('chicken', 'spinach'), ('chicken', 'burgers'), ('chicken', 'clothes accessories'), ('chicken', 'fresh bread'), ('chicken', 'meatballs'), ('chicken', 'ketchup'), ('chicken', 'herb & pepper'), ('chicken', 'fromage blanc'), ('chicken', 'energy bar'), ('chicken', 'water spray'), ('chicken', 'honey'), ('chicken', 'olive oil'), ('chicken', 'light mayo'), ('chicken', 'sandwich'), ('chicken', 'oatmeal'), ('chicken', 'yogurt cake'), ('chicken', 'cereals'), ('chicken', 'tomatoes'), ('chicken', 'cauliflower'), ('chicken', 'light crea ...

# %% [markdown]
# ### 2.Support

# %%
#!pip install mlxtend

# %%
from mlxtend.preprocessing import TransactionEncoder

# Instantiate transaction encoder
encoder = TransactionEncoder().fit(transactions)

# One-hot encode itemsets by applying fit and transform
onehot = encoder.transform(transactions)

# Convert one-hot encoded data to DataFrame
onehot = pd.DataFrame(onehot, columns = encoder.columns_)

# Computing Support for Single Items
print(onehot.mean())
# Out:
#  asparagus           0.000133
# almonds              0.020397
# antioxydant juice    0.008932
# asparagus            0.004666
# avocado              0.033329
#                        ...
# whole wheat pasta    0.029463
# whole wheat rice     0.058526
# yams                 0.011465
# yogurt cake          0.027330
# zucchini             0.009465
# Length: 120, dtype: float64

# %%
# Define itemset that contains both eggs and ground beef
onehot['eggs_&_ground beef'] = np.logical_and(onehot['eggs'], onehot['ground beef'])

# Compute Support for itemset that contains both eggs and ground beef 
print(onehot['eggs_&_ground beef'].mean())
# Out:
# 0.019997333688841486

# %% [markdown]
# ### 3.Confidence

# %%
# Compute Support for the itemsets that contains eggs and ground beef
support_eggs_groundbeef = np.logical_and(onehot['eggs'], onehot['ground beef']).mean()
support_eggs = onehot['eggs'].mean()
support_groundbeef = onehot['ground beef'].mean()

# Compute and print Confidence {eggs -> ground beef}
confidence_eggs_to_groundbeef = support_eggs_groundbeef / support_eggs
print(confidence_eggs_to_groundbeef)
# Out:
# 0.11127596439169138

# %% [markdown]
# ### 4.Lift

# %%
# Compute and print Lift {eggs -> ground beef}
lift_eggs_to_groundbeef = support_eggs_groundbeef / (support_eggs * support_groundbeef)
print(lift_eggs_to_groundbeef)
# Out:
# 1.1325386823637411

# %%
lift2 = confidence_eggs_to_groundbeef / support_groundbeef
print(lift2)
# Out:
# 1.132538682363741

# %% [markdown]
# ### 5. Apriori Algorithm

# %%
from mlxtend.frequent_patterns import apriori

# Compute frequent itemsets
frequent_itemsets = apriori(onehot, min_support = 0.0005,max_len = 4, use_colnames = True)
print(frequent_itemsets.head())
# Out:
#     support             itemsets
# 0  0.020397            (almonds)
# 1  0.008932  (antioxydant juice)
# 2  0.004666          (asparagus)
# 3  0.033329            (avocado)
# 4  0.004533        (babies food)

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Compute association rules
Rules = association_rules(frequent_itemsets, metric = "support", min_threshold = 0.005)
Rules
# Out:
#                           antecedents  \
# 0                           (burgers)
# 1                           (almonds)
# 2                         (chocolate)
# 3                           (almonds)
# 4                           (almonds)
# ...                               ...
# 2057  (eggs_&_ground beef, spaghetti)
# 2058                           (eggs)
# 2059                    (ground beef)
# 2060             (eggs_&_ground beef)
# 2061                      (spaghetti)
#
#                                        consequents  antecedent support  \
# 0                                        (almonds)            0.087188
# 1                                        (burgers)            0.020397
# 2                                        (almonds)            0.163845
# 3                                      (chocolate)            0.020397
# 4                                           (eggs)            0.020397
# ...                                            ...                 ...
# 2057                           (eggs, ground beef)            0.008932
# 2058  (ground beef, eggs_&_ground beef, spaghetti)            0.179709
# 2059         (eggs, eggs_&_ground beef, spaghetti)            0.098254
# 2060                (eggs, ground beef, spaghetti)            0.019997
# 2061       (eggs, ground beef, eggs_&_ground beef)            0.174110
#
#       consequent support   support  confidence       lift  leverage  \
# 0               0.020397  0.005199    0.059633   2.923577  0.003421
# 1               0.087188  0.005199    0.254902   2.923577  0.003421
# 2               0.020397  0.005999    0.036615   1.795099  0.002657
# 3               0.163845  0.005999    0.294118   1.795099  0.002657
# 4               0.179709  0.006532    0.320261   1.782108  0.002867
# ...                  ...       ...         ...        ...       ...
# 2057            0.019997  0.008932    1.000000  50.006667  0.008754
# 2058            0.008932  0.008932    0.049703   5.564540  0.007327
# 2059            0.008932  0.008932    0.090909  10.177748  0.008055
# 2060            0.008932  0.008932    0.446667  50.006667  0.008754
# 2061            0.019997  0.008932    0.051302   2.565426  0.005450
#
#       conviction
# 0       1.041724
# 1       1.225089
# 2       1.016834
# 3       1.184553
# 4       1.206774
# ...          ...
# 2057         inf
# 2058    1.042904
# 2059    1.090175
# 2060    1.791086
# 2061    1.032997
#
# [2062 rows x 9 columns]

# %%
filtered_rules = Rules[(Rules['antecedent support'] > 0.01) & 
                       (Rules['support'] > 0.009) & 
                       (Rules['confidence'] > 0.5) & 
                       (Rules['lift'] > 1.00)]

filtered_rules
# Out:
#                                            antecedents  \
# 409                               (eggs_&_ground beef)
# 691                               (eggs_&_ground beef)
# 833                               (eggs_&_ground beef)
# 1432                               (eggs, ground beef)
# 1442                               (eggs, ground beef)
# 1443                        (eggs, eggs_&_ground beef)
# 1444                 (ground beef, eggs_&_ground beef)
# 1447                              (eggs_&_ground beef)
# 1515               (mineral water, eggs_&_ground beef)
# 1516                        (eggs, eggs_&_ground beef)
# 1519                              (eggs_&_ground beef)
# 1642                  (frozen vegetables, ground beef)
# 1786                               (milk, ground beef)
# 1839               (mineral water, eggs_&_ground beef)
# 1840                 (ground beef, eggs_&_ground beef)
# 1843                              (eggs_&_ground beef)
# 2034                (mineral water, eggs, ground beef)
# 2035         (mineral water, eggs, eggs_&_ground beef)
# 2036  (mineral water, ground beef, eggs_&_ground beef)
# 2037           (eggs, ground beef, eggs_&_ground beef)
# 2040               (mineral water, eggs_&_ground beef)
# 2041                               (eggs, ground beef)
# 2042                        (eggs, eggs_&_ground beef)
# 2043                 (ground beef, eggs_&_ground beef)
# 2047                              (eggs_&_ground beef)
#
#                               consequents  antecedent support  \
# 409                                (eggs)            0.019997
# 691                         (ground beef)            0.019997
# 833                       (mineral water)            0.019997
# 1432                      (mineral water)            0.019997
# 1442                 (eggs_&_ground beef)            0.019997
# 1443                        (ground beef)            0.019997
# 1444                               (eggs)            0.019997
# 1447                  (eggs, ground beef)            0.019997
# 1515                               (eggs)            0.010132
# 1516                      (mineral water)            0.019997
# 1519                (mineral water, eggs)            0.019997
# 1642                      (mineral water)            0.016931
# 1786                      (mineral water)            0.021997
# 1839                        (ground beef)            0.010132
# 1840                      (mineral water)            0.019997
# 1843         (mineral water, ground beef)            0.019997
# 2034                 (eggs_&_ground beef)            0.010132
# 2035                        (ground beef)            0.010132
# 2036                               (eggs)            0.010132
# 2037                      (mineral water)            0.019997
# 2040                  (eggs, ground beef)            0.010132
# 2041  (mineral water, eggs_&_ground beef)            0.019997
# 2042         (mineral water, ground beef)            0.019997
# 2043                (mineral water, eggs)            0.019997
# 2047   (mineral water, eggs, ground beef)            0.019997
#
#       consequent support   support  confidence       lift  leverage  \
# 409             0.179709  0.019997    1.000000   5.564540  0.016404
# 691             0.098254  0.019997    1.000000  10.177748  0.018033
# 833             0.238368  0.010132    0.506667   2.125563  0.005365
# 1432            0.238368  0.010132    0.506667   2.125563  0.005365
# 1442            0.019997  0.019997    1.000000  50.006667  0.019597
# 1443            0.098254  0.019997    1.000000  10.177748  0.018033
# 1444            0.179709  0.019997    1.000000   5.564540  0.016404
# 1447            0.019997  0.019997    1.000000  50.006667  0.019597
# 1515            0.179709  0.010132    1.000000   5.564540  0.008311
# 1516            0.238368  0.010132    0.506667   2.125563  0.005365
# 1519            0.050927  0.010132    0.506667   9.948970  0.009114
# 1642            0.238368  0.009199    0.543307   2.279277  0.005163
# 1786            0.238368  0.011065    0.503030   2.110308  0.005822
# 1839            0.098254  0.010132    1.000000  10.177748  0.009136
# 1840            0.238368  0.010132    0.506667   2.125563  0.005365
# 1843            0.040928  0.010132    0.506667  12.379501  0.009314
# 2034            0.019997  0.010132    1.000000  50.006667  0.009929
# 2035            0.098254  0.010132    1.000000  10.177748  0.009136
# 2036            0.179709  0.010132    1.000000   5.564540  0.008311
# 2037            0.238368  0.010132    0.506667   2.125563  0.005365
# 2040            0.019997  0.010132    1.000000  50.006667  0.009929
# 2041            0.010132  0.010132    0.506667  50.006667  0.009929
# 2042            0.040928  0.010132    0.506667  12.379501  0.009314
# 2043            0.050927  0.010132    0.506667   9.948970  0.009114
# 2047            0.010132  0.010132    0.506667  50.006667  0.009929
#
#       conviction
# 409          inf
# 691          inf
# 833     1.543848
# 1432    1.543848
# 1442         inf
# 1443         inf
# 1444         inf
# 1447         inf
# 1515         inf
# 1516    1.543848
# 1519    1.923798
# 1642    1.667711
# 1786    1.532552
# 1839         inf
# 1840    1.543848
# 1843    1.944065
# 2034         inf
# 2035         inf
# 2036         inf
# 2037    1.543848
# 2040         inf
# 2041    2.006489
# 2042    1.944065
# 2043    1.923798
# 2047    2.006489

# %%
# Computing support.
supportASAL = np.logical_and(onehot['asparagus'],onehot['almonds']).mean()
supportAS = onehot['asparagus'].mean()
supportAL = onehot['almonds'].mean()

# Compute and print confidence and lift.
confidence = supportASAL / supportAS
lift = supportASAL / (supportAS * supportAL)

# Print results.
print(supportAL, confidence, lift)
# Out:
# 0.020397280362618318 0.0 0.0
