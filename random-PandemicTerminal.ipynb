# %%
import random
class Simulation():
    def __init__(self):
        self.day_number = 1
        #Get simulation initial conditions from the user
        print("To simulate an epidemic outbreak, we must know the population size.")
        self.population_size = int(input("---Enter the population size: "))
        print("\nWe must first start by infecting a portion of the population.")
        self.infection_percent = float(input("---Enter the percentage (0-100) of the population to initially infect: "))
        self.infection_percent /= 100
        print("\nWe must know the risk a person has to contract the disease when exposed.")
        self.infection_probability = float(input("---Enter the probability (0-100) that a person gets infected when exposed to the disease: "))
        print("\nWe must know how long the infection will last when exposed.")
        self.infection_duration = int(input("---Enter the duration (in days) of the infection: "))
        print("\nWe must know the mortality rate of those infected.")
        self.mortality_rate = float(input("---Enter the mortality rate (0-100) of the infection: "))
        print("\nWe must know how long to run the simulation.")
        self.sim_days = int(input("---Enter the number of days to simulate: "))                                
                                     
                                     
                                     
class Person():
    def __init__(self):
        self.is_infected = False #Person starts healthy, not infected
        self.is_dead = False #Person starts ALIVE
        self.days_infected = 0 #Keeps track of days infected for individual person
    
    def infect(self, simulation):
        #random number generated must be less than infection_probability to infect
        if random.randint(0, 100) < simulation.infection_probability:
            self.is_infected = True
    
    def heal(self):
        self.is_infected = False
        self.days_infected = 0
    
    def die(self):
        self.is_dead = True
    
    def update(self, simulation):
        #Check if the person is not dead before updating
        if not self.is_dead:
            #Check if the person is infected
            if self.is_infected:
                self.days_infected += 1
                #Check to see if the person will die
                if random.randint(0, 100) < simulation.mortality_rate:
                    self.die()
                #Check if the infection is over, if it is, heal the person
                elif self.days_infected == simulation.infection_duration:
                    self.heal()
                                 

class Population():
    def __init__(self, simulation):
        self.population = [] #A list to hold all Person instances once created
        #Create the correct number of Person instances based on the sim conditions
        for i in range(simulation.population_size):
            person = Person()
            self.population.append(person)
    
    def initial_infection(self, simulation):
        #The number of people to infect is found by taking the pop size * infection percentage
        #We must round to 0 decimals and cast to an int so we can use infected_count in a for loop.
        infected_count = int(round(simulation.infection_percent*simulation.population_size, 0))
        
        #Infect the correct number of people
        for i in range(infected_count):
            #Infect the ith person in the population attribute
            self.population[i].is_infected = True
            self.population[i].days_infected = 1
        #Shuffle the population list so we spread the infection out randomly
        random.shuffle(self.population)
    
    def spread_infection(self, simulation):
        for i in range(len(self.population)):
            #ith person is ALIVE, see if they should be infected.
            #Don't bother infecting a dead person, they are infected and dead.
            #Check to see if adjacent Persons are infected
            if self.population[i].is_dead == False:
                #i is the first person in the list, can only check to the right [i+1].
                if i == 0:
                    if self.population[i+1].is_infected:
                        self.population[i].infect(simulation)
                #i is in the middle of the list, can check to the left [i-1] and right [i+1].
                elif i < len(self.population)-1:
                    if self.population[i-1].is_infected or self.population[i+1].is_infected:
                        self.population[i].infect(simulation) 
                #i is the last person in the list, can only check to the left [i-1].
                elif i == len(self.population)-1:
                    if self.population[i-1].is_infected:
                        self.population[i].infect(simulation)
    
    def update(self, simulation):
        simulation.day_number += 1
        #Call the update method for all person instances in the population
        for person in self.population:
            person.update(simulation)
    
    def display_statistics(self, simulation):
        total_infected_count = 0
        total_death_count = 0
        
        #Loop through whole population
        for person in self.population:
            #Person is infected
            if person.is_infected:
                total_infected_count += 1
                #Person is dead
                if person.is_dead:
                    total_death_count += 1
        
        #Calculate percentage of population that is infected and dead
        infected_percent = round(100*(total_infected_count/simulation.population_size), 4)
        death_percent = round(100*(total_death_count/simulation.population_size), 4)
        
        #Statistics summary
        print("\n-----Day # " + str(simulation.day_number) + "-----")
        print("Percentage of Population Infected: " + str(infected_percent) + "%")
        print("Percentage of Population Dead: " + str(death_percent) + "%")
        print("Total People Infected: " + str(total_infected_count) + " / " + str(simulation.population_size))
        print("Total Deaths: " + str(total_death_count) + " / " + str(simulation.population_size))
        
    def graphics(self):
        status = [] #A list to hold all X, I, and O to represent the status of each person
        for person in self.population:
            #Person is dead, X
            if person.is_dead:
                char = 'X'
            #Person is alive, are they infected or healthy?
            else:
                #Person is infected, I
                if person.is_infected:
                    char = 'I'
                #Person is healthy, O
                else:
                    char = 'O'
            status.append(char)
        
        #Print out all status characters separated by a -
        for letter in status:
            print(letter, end='-')
                                   
                                     
#The main code
sim = Simulation()
pop = Population(sim)

#Set the initial infection conditions of the population
pop.initial_infection(sim)
pop.display_statistics(sim)
pop.graphics()
input("\nPress enter to begin the simulation")

#Run the simulation
for i in range(1, sim.sim_days):
    #For a single day, spread the infection, update the population, display statistics and graphics
    pop.spread_infection(sim)
    pop.update(sim)
    pop.display_statistics(sim)
    pop.graphics()
    
    #If it is not the last day of the simulation, pause the program
    if i != sim.sim_days - 1:
        input("\nPress enter to advance to the next day.")
# Out:
# To simulate an epidemic outbreak, we must know the population size.
# ---Enter the population size: 100
#
# We must first start by infecting a portion of the population.
# ---Enter the percentage (0-100) of the population to initially infect: 12
#
# We must know the risk a person has to contract the disease when exposed.
# ---Enter the probability (0-100) that a person gets infected when exposed to the disease: 25
#
# We must know how long the infection will last when exposed.
# ---Enter the duration (in days) of the infection: 4
#
# We must know the mortality rate of those infected.
# ---Enter the mortality rate (0-100) of the infection: 35
#
# We must know how long to run the simulation.
# ---Enter the number of days to simulate: 10
#
# -----Day # 1-----
# Percentage of Population Infected: 12.0%
# Percentage of Population Dead: 0.0%
# Total People Infected: 12 / 100
# Total Deaths: 0 / 100
# I-O-O-O-O-O-O-O-O-O-O-O-I-O-O-O-O-I-O-O-I-O-I-O-O-O-O-O-O-I-O-O-O-O-O-O-I-O-O-O-I-O-O-O-O-O-O-O-O-O-O-O-O-O-I-O-O-O-O-I-O-O-O-O-O-O-O-O-O-O-O-O-O-O-O-I-O-O-O-O-O-O-O-O-O-I-O-O-O-O-O-O-O-O-O-O-O-O-O-O-
# Press enter to begin the simulation
#
# -----Day # 2-----
# Percentage of Population Infected: 23.0%
# Percentage of Population Dead: 5.0%
# Total People Infected: 23 / 100
# Total Deaths: 5 / 100
# I-X-O-O-O-O-O-O-O-O-O-O-I-O-O-O-O-X-O-X-I-O-I-O-O-O-O-O-I-I-I-I-O-O-O-O-I-O-O-O-I-I-O-O-O-O-O-O-O-O-O-O-O-O-I-O-O-O-I-I-O-O-O-O-O-O-O-O-O-O-O-O-O-O-O-I-I-O-O-O-O-O-O-O-O-X-I-X-I-O-O-O-O-O-O-O-O-O-O-O-
# X-X-X-X-X-X-O-O-O-O-O-O-O-O-O-I-X-X-I-X-X-X-X-O-X-O-X-X-X-X-X-I-X-X-X-O-X-X-X-O-I-O-O-O-O-O-O-O-O-O-O-O-O-O-O-O-O-O-X-X-X-X-I-X-O-O-O-O-O-O-O-O-O-O-I-X-X-X-O-O-O-O-X-X-X-X-X-X-O-O-O-O-O-O-O-O-O-O-O-O-
# Press enter to advance to the next day.
#
# -----Day # 9-----
# Percentage of Population Infected: 45.0%
# Percentage of Population Dead: 40.0%
# Total People Infected: 45 / 100
# Total Deaths: 40 / 100
# X-X-X-X-X-X-O-O-O-O-O-O-O-O-O-I-X-X-I-X-X-X-X-O-X-O-X-X-X-X-X-O-X-X-X-O-X-X-X-O-I-O-O-O-O-O-O-O-O-O-O-O-O-O-O-O-O-X-X-X-X-X-O-X-O-O-O-O-O-O-O-O-O-I-I-X-X-X-O-O-O-X-X-X-X-X-X-X-O-O-O-O-O-O-O-O-O-O-O-O-
# Press enter to advance to the next day.
#
# -----Day # 10-----
# Percentage of Population Infected: 49.0%
# Percentage of Population Dead: 42.0%
# Total People Infected: 49 / 100
# Total Deaths: 42 / 100
# X-X-X-X-X-X-O-O-O-O-O-O-O-O-O-I-X-X-I-X-X-X-X-O-X-O-X-X-X-X-X-I-X-X-X-O-X-X-X-I-I-O-O-O-O-O-O-O-O-O-O-O-O-O-O-O-O-X-X-X-X-X-O-X-X-I-O-O-O-O-O-O-X-I-O-X-X-X-O-O-O-X-X-X-X-X-X-X-O-O-O-O-O-O-O-O-O-O-O-O-

# %%
import math
import random
import tkinter 

class Simulation():
    def __init__(self):
        self.day_number = 1
        print("To simulate an epidemic outbreak, we must know the population size.")
        self.population_size = int(input("---Enter the population size: "))
        #Convert users population size to nearest perfect square for visual purposes
        root = math.sqrt(self.population_size) 
        
        #For example, if population_size is 79, root = 8.8881
        #User did not enter a perfect square for the population
        if int(root + .5)**2 != self.population_size:   # int(8.881 +.5)**2 = int(9.3881)**2 = 9**2 = 81 != 79
            root = round(root, 0) # round(8.881, 0) = 9.0
            self.grid_size = int(root) #grid_size = 9
            self.population_size = self.grid_size**2 #population_size = 9*9 = 81 the closest PERFECT SQUARE TO 79
            print("Rounding population size to " + str(self.population_size) + " for visual purposes.")
            
        #The user did enter a perfect square for the population
        else:
            self.grid_size = int(math.sqrt(self.population_size))
        
        print("\nWe must first start by infecting a portion of the population.")
        self.infection_percent = float(input("---Enter the percentage (0-100) of the population to initially infect: "))
        self.infection_percent /= 100
        print("\nWe must know the risk a person has to contract the disease when exposed.")
        self.infection_probability = float(input("---Enter the probability (0-100) that a person gets infected when exposed to the disease: "))
        print("\nWe must know how long the infection will last when exposed.")
        self.infection_duration = int(input("---Enter the duration (in days) of the infection: "))
        print("\nWe must know the mortality rate of those infected.")
        self.mortality_rate = float(input("---Enter the mortality rate (0-100) of the infection: "))
        print("\nWe must know how long to run the simulation.")
        self.sim_days = int(input("---Enter the number of days to simulate: "))

            
class Person():
    def __init__(self):
        self.is_infected = False #Person starts healthy, not infected
        self.is_dead = False #Person starts ALIVE
        self.days_infected = 0 #Keeps track of days infected for individual person
    
    def infect(self, simulation):
        #random number generated must be less than infection_probability to infect
        if random.randint(0, 100) < simulation.infection_probability:
            self.is_infected = True

    def heal(self):
        self.is_infected = False
        self.days_infected = 0
    
    def die(self):
        self.is_dead = True
    
    def update(self, simulation):
        #Check if the person is not dead before updating
        if not self.is_dead:
            if self.is_infected:
                self.days_infected += 1
                if random.randint(0, 100) < simulation.mortality_rate:
                    self.die()
                elif self.days_infected == simulation.infection_duration:
                    self.heal()

class Population():
    def __init__(self, simulation):
        self.population = [] #A list to hold all Persons in the population.
        for i in range(simulation.grid_size):
            row = []
            for j in range(simulation.grid_size):
                person = Person()
                row.append(person)
            #The entire row is complete, append it to the population
            self.population.append(row)
    
    def initial_infection(self, simulation):
        infected_count = int(round(simulation.infection_percent*simulation.population_size, 0))
        infections = 0
        
        while infections < infected_count:
            x = random.randint(0, simulation.grid_size - 1)
            y = random.randint(0, simulation.grid_size - 1)
            if not self.population[x][y].is_infected:
                self.population[x][y].is_infected = True
                self.population[x][y].days_infected = 1
                infections += 1
    
    def spread_infection(self, simulation):
        for i in range(simulation.grid_size):
            for j in range(simulation.grid_size):
                if self.population[i][j].is_dead == False:
                    if i == 0:
                        if j == 0:
                            if self.population[i][j+1].is_infected or self.population[i+1][j].is_infected:
                                self.population[i][j].infect(simulation)
                        elif j == simulation.grid_size-1:
                            if self.population[i][j-1].is_infected or self.population[i+1][j].is_infected:
                                self.population[i][j].infect(simulation)
                        else:
                            if self.population[i][j-1].is_infected or self.population[i][j+1].is_infected or self.population[i+1][j].is_infected:
                                self.population[i][j].infect(simulation)
                                
                    elif i == simulation.grid_size-1:
                        if j == 0:
                            if self.population[i][j+1].is_infected or self.population[i-1][j].is_infected:
                                self.population[i][j].infect(simulation)
                        elif j == simulation.grid_size-1:
                            if self.population[i][j-1].is_infected or self.population[i-1][j].is_infected:
                                self.population[i][j].infect(simulation)
                        else:
                            if self.population[i][j-1].is_infected or self.population[i][j+1].is_infected or self.population[i-1][j].is_infected:
                                self.population[i][j].infect(simulation)
                                
                    else:
                        if j == 0:
                            if self.population[i][j+1].is_infected or self.population[i+1][j].is_infected or self.population[i-1][j].is_infected:
                                self.population[i][j].infect(simulation)
                        elif j == simulation.grid_size-1:
                            if self.population[i][j-1].is_infected or self.population[i+1][j].is_infected or self.population[i-1][j].is_infected:
                                self.population[i][j].infect(simulation)
                        else:
                            if self.population[i][j-1].is_infected or self.population[i][j+1].is_infected or self.population[i+1][j].is_infected or self.population[i-1][j].is_infected:
                                self.population[i][j].infect(simulation)
    
    def update(self, simulation):
        simulation.day_number += 1
        for row in self.population:
            for person in row:
                person.update(simulation)
    
    def display_statistics(self, simulation):
        total_infected_count = 0
        total_death_count = 0
        for row in self.population:
            for person in row:
                if person.is_infected:
                    total_infected_count += 1
                    if person.is_dead:
                        total_death_count += 1

        #Calculate percentage of population that is infected and dead
        infected_percent = round(100*(total_infected_count/simulation.population_size), 4)
        death_percent = round(100*(total_death_count/simulation.population_size), 4)

        #Statistics summary
        print("\n-----Day # " + str(simulation.day_number) + "-----")
        print("Percentage of Population Infected: " + str(infected_percent) + "%")
        print("Percentage of Population Dead: " + str(death_percent) + "%")
        print("Total People Infected: " + str(total_infected_count) + " / " + str(simulation.population_size))
        print("Total Deaths: " + str(total_death_count) + " / " + str(simulation.population_size))
    
#A helper function to create graphics
def graphics(simulation, population, canvas):
    square_dimension = 600//simulation.grid_size
    for i in range(simulation.grid_size):
        y = i*square_dimension
        for j in range(simulation.grid_size):
            x = j*square_dimension
                
            if population.population[i][j].is_dead:
                canvas.create_rectangle(x, y, x+square_dimension, y+square_dimension, fill='red')
            else:
                if population.population[i][j].is_infected:
                    canvas.create_rectangle(x, y, x+square_dimension, y+square_dimension, fill='yellow')
                else:
                    canvas.create_rectangle(x, y, x+square_dimension, y+square_dimension, fill='green')

                        
#The main code
#Create a simulation object
sim = Simulation()

#Set constant variables for window size
WINDOW_WIDTH = 600
WINDOW_HEIGHT = 600

#Create the tkinter window and canvas
sim_window = tkinter.Tk()
sim_window.title("Epidemic Outbreak")
sim_canvas = tkinter.Canvas(sim_window, width=WINDOW_WIDTH, height=WINDOW_HEIGHT, bg='lightblue')
sim_canvas.pack(side=tkinter.LEFT)

#Create a population object
pop = Population(sim)
pop.initial_infection(sim)
pop.display_statistics(sim)
input("Press Enter to begin simulation.")

#Run the simulation
for i in range(1, sim.sim_days):
    pop.spread_infection(sim)
    pop.update(sim)
    pop.display_statistics(sim)
    graphics(sim, pop, sim_canvas)

    #Update the tkinter window to reflect the graphics change
    sim_window.update()

    #If we are currently not on the last day of the simulation, wipe the canvas clean
    if i != sim.sim_days-1:
        sim_canvas.delete('all')
# Out:
# To simulate an epidemic outbreak, we must know the population size.
# ---Enter the population size: 9700
# Rounding population size to 9604 for visual purposes.
#
# We must first start by infecting a portion of the population.
# ---Enter the percentage (0-100) of the population to initially infect: 3
#
# We must know the risk a person has to contract the disease when exposed.
# ---Enter the probability (0-100) that a person gets infected when exposed to the disease: 15
#
# We must know how long the infection will last when exposed.
# ---Enter the duration (in days) of the infection: 5
#
# We must know the mortality rate of those infected.
# ---Enter the mortality rate (0-100) of the infection: 10
#
# We must know how long to run the simulation.
# ---Enter the number of days to simulate: 365
#
# -----Day # 1-----
# Percentage of Population Infected: 2.9988%
# Percentage of Population Dead: 0.0%
# Total People Infected: 288 / 9604
# Total Deaths: 0 / 9604
# Press Enter to begin simulation.
#
# -----Day # 2-----
# Percentage of Population Infected: 5.0708%
# Percentage of Population Dead: 0.4061%
# Total People Infected: 487 / 9604
# Total Deaths: 39 / 9604
#
# -----Day # 3-----
# Percentage of Population Infected: 7.778%
# Percentage of Population Dead: 1.1245%
# Total People Infected: 747 / 9604
# Total Deaths: 108 / 9604
#
# -----Day # 4-----
# Percentage of Population Infected: 10.6622%
# Percentage of Population Dead: 1.9992%
# Total People Infected: 1024 / 9604
# Total Deaths: 192 / 9604
#
# -----Day # 5-----
# Percentage of Population Infected: 12.0679%
# Percentage of Population Dead: 3.1653%
# Total People Infected: 1159 / 9604
# Total Deaths: 304 / 9604
#
# -----Day # 6-----
# Percentage of Population Infected: 14.3274%
# Percentage of Population Dead: 4.4252%
# Total People Infected: 1376 / 9604
# Total Deaths: 425 / 9604
#
# -----Day # 7-----
# Percentage of Population Infected: 16.6597%
# Percentage of Population Dead: 6.0287%
# Total People Infected: 1600 / 9604
# Total Deaths: 579 / 9604
#
# -----Day # 8-----
# Percentage of Population Infected: 19.4502%
# Percentage of Population Dead: 7.4552%
# Total People Infected: 1868 / 9604
# Total Deaths: 716 / 9604
#
# -----Day # 9-----
# Percentage of Population Infected: 21.5119%
# Percentage of Population Dead: 9.2461%
# Total People Infected: 2066 / 9604
# Total Deaths: 888 / 9604
#
# -----Day # 10-----
# Percentage of Population Infected: 24.1358%
# Percentage of Population Dead: 10.8288%
# Total People Infected: 2318 / 9604
# Total Deaths: 1040 / 9604
#
# -----Day # 11-----
# Percentage of Population Infected: 26.5931%
# Percentage of Population Dead: 12.651%
# Total People Infected: 2554 / 9604
# Total Deaths: 1215 / 9604
#
# -----Day # 12-----
# Percentage of Population Infected: 29.2691%
# Percentage of Population Dead: 14.5148%
# Total People Infected: 2811 / 9604
# Total Deaths: 1394 / 9604
#
# -----Day # 13-----
# Percentage of Population Infected: 31.9658%
# Percentage of Population Dead: 16.4098%
# Total People Infected: 3070 / 9604
# Total Deaths: 1576 / 9604
#
# -----Day # 14-----
# Percentage of Population Infected: 34.7147%
# Percentage of Population Dead: 18.3778%
# Total People Infected: 3334 / 9604
# Total Deaths: 1765 / 9604
#
# -----Day # 15-----
# Percentage of Population Infected: 37.6093%
# Percentage of Population Dead: 20.7934%
# Total People Infected: 3612 / 9604
# Total Deaths: 1997 / 9604
#
# -----Day # 16-----
# Percentage of Population Infected: 40.3269%
# Percentage of Population Dead: 22.7822%
# Total People Infected: 3873 / 9604
# Total Deaths: 2188 / 9604
#
# -----Day # 17-----
# Percentage of Population Infected: 42.9613%
# Percentage of Population Dead: 25.1145%
# Total People Infected: 4126 / 9604
# Total Deaths: 2412 / 9604
#
# -----Day # 18-----
# Percentage of Population Infected: 45.6685%
# Percentage of Population Dead: 27.4052%
# Total People Infected: 4386 / 9604
# Total Deaths: 2632 / 9604
#
# -----Day # 19-----
# Percentage of Population Infected: 48.1466%
# Percentage of Population Dead: 29.6647%
# Total People Infected: 4624 / 9604
# Total Deaths: 2849 / 9604
#
# -----Day # 20-----
# Percentage of Population Infected: 50.5623%
# Percentage of Population Dead: 31.9554%
# Total People Infected: 4856 / 9604
# Total Deaths: 3069 / 9604
#
# -----Day # 21-----
# Percentage of Population Infected: 52.7176%
# Percentage of Population Dead: 34.3294%
# Total People Infected: 5063 / 9604
# Total Deaths: 3297 / 9604
#
# -----Day # 22-----
# Percentage of Population Infected: 54.6647%
# Percentage of Population Dead: 36.8388%
# Total People Infected: 5250 / 9604
# Total Deaths: 3538 / 9604
#
# -----Day # 23-----
# Percentage of Population Infected: 56.7784%
# Percentage of Population Dead: 39.2441%
# Total People Infected: 5453 / 9604
# Total Deaths: 3769 / 9604
#
# -----Day # 24-----
# Percentage of Population Infected: 58.8088%
# Percentage of Population Dead: 41.6285%
# Total People Infected: 5648 / 9604
# Total Deaths: 3998 / 9604
#
# -----Day # 25-----
# Total Deaths: 7170 / 9604
#
# -----Day # 44-----
# Percentage of Population Infected: 84.0691%
# Percentage of Population Dead: 75.833%
# Total People Infected: 8074 / 9604
# Total Deaths: 7283 / 9604
#
# -----Day # 45-----
# Percentage of Population Infected: 84.4856%
# Percentage of Population Dead: 76.895%
# Total People Infected: 8114 / 9604
# Total Deaths: 7385 / 9604
#
# -----Day # 46-----
# Percentage of Population Infected: 85.3707%
# Percentage of Population Dead: 77.9363%
# Total People Infected: 8199 / 9604
# Total Deaths: 7485 / 9604
# -----Day # 47-----
# Percentage of Population Infected: 85.9954%
# Percentage of Population Dead: 78.8942%
# Total People Infected: 8259 / 9604
# Total Deaths: 7577 / 9604
#
# -----Day # 48-----
# Percentage of Population Infected: 86.5473%
# Percentage of Population Dead: 79.696%
# Total People Infected: 8312 / 9604
# Total Deaths: 7654 / 9604
#
# -----Day # 49-----
# Percentage of Population Infected: 87.2241%
# Percentage of Population Dead: 80.5081%
# Total People Infected: 8377 / 9604
# Total Deaths: 7732 / 9604
#
# -----Day # 50-----
# Percentage of Population Infected: 87.4115%
# Percentage of Population Dead: 81.2786%
# Total People Infected: 8395 / 9604
# Total Deaths: 7806 / 9604
#
# -----Day # 51-----
# Percentage of Population Infected: 88.1716%
# Percentage of Population Dead: 82.0075%
# Total People Infected: 8468 / 9604
# Total Deaths: 7876 / 9604
#
# -----Day # 52-----
# Percentage of Population Infected: 88.8692%
# Percentage of Population Dead: 82.7988%
# Total People Infected: 8535 / 9604
# Total Deaths: 7952 / 9604
#
# -----Day # 53-----
# Percentage of Population Infected: 89.317%
# Percentage of Population Dead: 83.7151%
# Total People Infected: 8578 / 9604
# Total Deaths: 8040 / 9604
#
# -----Day # 54-----
# Percentage of Population Infected: 89.8584%
# Percentage of Population Dead: 84.4127%
# Total People Infected: 8630 / 9604
# Total Deaths: 8107 / 9604
#
# -----Day # 55-----
# Percentage of Population Infected: 90.2541%
# Percentage of Population Dead: 84.9646%
# Total People Infected: 8668 / 9604
# Total Deaths: 8160 / 9604
#
# -----Day # 56-----
# Percentage of Population Infected: 90.556%
# Percentage of Population Dead: 85.5581%
# Total People Infected: 8697 / 9604
# Total Deaths: 8217 / 9604
#
# -----Day # 57-----
# Percentage of Population Infected: 90.9309%
# Percentage of Population Dead: 86.3494%
# Total People Infected: 8733 / 9604
# Total Deaths: 8293 / 9604
#
# -----Day # 58-----
# Percentage of Population Infected: 91.3474%
# Percentage of Population Dead: 86.9013%
# Total People Infected: 8773 / 9604
# Total Deaths: 8346 / 9604
#
# -----Day # 59-----
# Percentage of Population Infected: 91.8576%
# Percentage of Population Dead: 87.4636%
# Total People Infected: 8822 / 9604
# Total Deaths: 8400 / 9604
#
# -----Day # 60-----
# Percentage of Population Infected: 92.1908%
# Percentage of Population Dead: 87.9425%
# Total People Infected: 8854 / 9604
# Total Deaths: 8446 / 9604
#
# -----Day # 61-----
# Percentage of Population Infected: 92.4927%
# Percentage of Population Dead: 88.5048%
# Total People Infected: 8883 / 9604
# Total Deaths: 8500 / 9604
#
# -----Day # 62-----
# Percentage of Population Infected: 92.8363%
# Percentage of Population Dead: 89.0879%
# Total People Infected: 8916 / 9604
# Total Deaths: 8556 / 9604
#
# -----Day # 63-----
# Percentage of Population Infected: 92.9717%
# Percentage of Population Dead: 89.5252%
# Total People Infected: 8929 / 9604
# Total Deaths: 8598 / 9604
#
# -----Day # 64-----
# Percentage of Population Infected: 93.284%
# Percentage of Population Dead: 90.0146%
# Total People Infected: 8959 / 9604
# Total Deaths: 8645 / 9604
#
# -----Day # 65-----
# Percentage of Population Infected: 93.5444%
# Percentage of Population Dead: 90.4102%
# Total People Infected: 8984 / 9604
# Total Deaths: 8683 / 9604
#
# -----Day # 66-----
# Percentage of Population Infected: 94.0129%
# Percentage of Population Dead: 90.8372%
# Total People Infected: 9029 / 9604
# Total Deaths: 8724 / 9604
#
# -----Day # 67-----
# Percentage of Population Infected: 94.3669%
# Percentage of Population Dead: 91.2224%
# Total People Infected: 9063 / 9604
# Total Deaths: 8761 / 9604
#
# -----Day # 68-----
# Percentage of Population Infected: 94.4086%
# Percentage of Population Dead: 91.5764%
# Total People Infected: 9067 / 9604
# Total Deaths: 8795 / 9604
#
# -----Day # 69-----
# Percentage of Population Infected: 94.6481%
# Percentage of Population Dead: 91.92%
# Total People Infected: 9090 / 9604
# Total Deaths: 8828 / 9604
#
# -----Day # 70-----
# Percentage of Population Infected: 94.7834%
# Percentage of Population Dead: 92.2324%
# Total People Infected: 9103 / 9604
# Total Deaths: 8858 / 9604
#
# -----Day # 71-----
# Percentage of Population Infected: 95.127%
# Percentage of Population Dead: 92.7114%
# Total People Infected: 9136 / 9604
# Total Deaths: 8904 / 9604
#
# -----Day # 72-----
# Percentage of Population Infected: 95.5331%
# Percentage of Population Dead: 93.0342%
# Total People Infected: 9175 / 9604
# Total Deaths: 8935 / 9604
#
# -----Day # 73-----
# Percentage of Population Infected: 95.7205%
# Percentage of Population Dead: 93.284%
# Total People Infected: 9193 / 9604
# Total Deaths: 8959 / 9604
#
# -----Day # 74-----
# Percentage of Population Infected: 95.8767%
# Percentage of Population Dead: 93.6589%
# Total People Infected: 9208 / 9604
# Total Deaths: 8995 / 9604
#
# -----Day # 75-----
# Percentage of Population Infected: 95.9288%
# Percentage of Population Dead: 93.9608%
# Total People Infected: 9213 / 9604
# Total Deaths: 9024 / 9604
#
# -----Day # 76-----
# Percentage of Population Infected: 96.1579%
# Percentage of Population Dead: 94.1691%
# Total People Infected: 9235 / 9604
# Total Deaths: 9044 / 9604
#
# -----Day # 77-----
# Percentage of Population Infected: 96.3244%
# Percentage of Population Dead: 94.4294%
# Total People Infected: 9251 / 9604
# Total Deaths: 9069 / 9604
#
# -----Day # 78-----
# Percentage of Population Infected: 96.5639%
# Percentage of Population Dead: 94.6793%
# Total People Infected: 9274 / 9604
# Total Deaths: 9093 / 9604
#
# -----Day # 79-----
# Percentage of Population Infected: 96.6576%
# Percentage of Population Dead: 94.9604%
# Total People Infected: 9283 / 9604
# Total Deaths: 9120 / 9604
#
# -----Day # 80-----
# Percentage of Population Infected: 96.7618%
# Percentage of Population Dead: 95.2728%
# Total People Infected: 9293 / 9604
# Total Deaths: 9150 / 9604
#
# -----Day # 81-----
# Percentage of Population Infected: 96.9596%
# Percentage of Population Dead: 95.481%
# Total People Infected: 9312 / 9604
# Total Deaths: 9170 / 9604
#
# -----Day # 82-----
# Percentage of Population Infected: 97.1678%
# Percentage of Population Dead: 95.7309%
# Total People Infected: 9332 / 9604
# Total Deaths: 9194 / 9604
#
# -----Day # 83-----
# Percentage of Population Infected: 97.3449%
# Percentage of Population Dead: 95.908%
# Total People Infected: 9349 / 9604
# Total Deaths: 9211 / 9604
#
# -----Day # 84-----
# Percentage of Population Infected: 97.4073%
# Percentage of Population Dead: 96.0954%
# Total People Infected: 9355 / 9604
# Total Deaths: 9229 / 9604
#
# -----Day # 85-----
# Percentage of Population Infected: 97.6468%
# Percentage of Population Dead: 96.2411%
# Total People Infected: 9378 / 9604
# Total Deaths: 9243 / 9604
#
# -----Day # 86-----
# Percentage of Population Infected: 97.7718%
# Percentage of Population Dead: 96.4598%
# Total People Infected: 9390 / 9604
# Total Deaths: 9264 / 9604
#
# -----Day # 87-----
# Percentage of Population Infected: 97.8759%
# Percentage of Population Dead: 96.6056%
# Total People Infected: 9400 / 9604
# Total Deaths: 9278 / 9604
#
# -----Day # 88-----
# Percentage of Population Infected: 97.8863%
# Percentage of Population Dead: 96.7826%
# Total People Infected: 9401 / 9604
# Total Deaths: 9295 / 9604
#
# -----Day # 89-----
# Percentage of Population Infected: 97.8342%
# Percentage of Population Dead: 96.9284%
# Total People Infected: 9396 / 9604
# Total Deaths: 9309 / 9604
#
# -----Day # 90-----
# Percentage of Population Infected: 98.0425%
# Percentage of Population Dead: 97.1366%
# Total People Infected: 9416 / 9604
# Total Deaths: 9329 / 9604
#
# -----Day # 91-----
# Percentage of Population Infected: 98.0841%
# Percentage of Population Dead: 97.2303%
# Total People Infected: 9420 / 9604
# Total Deaths: 9338 / 9604
#
# -----Day # 92-----
# Percentage of Population Infected: 98.3236%
# Percentage of Population Dead: 97.3344%
# Total People Infected: 9443 / 9604
# Total Deaths: 9348 / 9604
#
# -----Day # 93-----
# Percentage of Population Infected: 98.4069%
# Percentage of Population Dead: 97.4802%
# Total People Infected: 9451 / 9604
# Total Deaths: 9362 / 9604
#
# -----Day # 94-----
# Percentage of Population Infected: 98.4694%
# Percentage of Population Dead: 97.5635%
# Total People Infected: 9457 / 9604
# Total Deaths: 9370 / 9604
#
# -----Day # 95-----
# Percentage of Population Infected: 98.5319%
# Percentage of Population Dead: 97.6989%
# Total People Infected: 9463 / 9604
# Total Deaths: 9383 / 9604
#
# -----Day # 96-----
# Percentage of Population Infected: 98.636%
# Percentage of Population Dead: 97.803%
# Total People Infected: 9473 / 9604
# Total Deaths: 9393 / 9604
# -----Day # 97-----
# Percentage of Population Infected: 98.6568%
# Percentage of Population Dead: 97.8655%
# Total People Infected: 9475 / 9604
# Total Deaths: 9399 / 9604
#
# -----Day # 98-----
# Percentage of Population Infected: 98.6256%
# Percentage of Population Dead: 97.8967%
# Total People Infected: 9472 / 9604
# Total Deaths: 9402 / 9604
#
# -----Day # 99-----
# Percentage of Population Infected: 98.7193%
# Percentage of Population Dead: 97.9175%
# Total People Infected: 9481 / 9604
# Total Deaths: 9404 / 9604
#
# -----Day # 100-----
# Percentage of Population Infected: 98.7609%
# Percentage of Population Dead: 98.0217%
# Total People Infected: 9485 / 9604
# Total Deaths: 9414 / 9604
#
# -----Day # 101-----
# Percentage of Population Infected: 98.7609%
# Percentage of Population Dead: 98.1466%
# Total People Infected: 9485 / 9604
# Total Deaths: 9426 / 9604
#
# -----Day # 102-----
# Percentage of Population Infected: 98.8442%
# Percentage of Population Dead: 98.1883%
# Total People Infected: 9493 / 9604
# Total Deaths: 9430 / 9604
#
# -----Day # 103-----
# Percentage of Population Infected: 98.9275%
# Percentage of Population Dead: 98.2611%
# Total People Infected: 9501 / 9604
# Total Deaths: 9437 / 9604
#
# -----Day # 104-----
# Percentage of Population Infected: 98.8859%
# Percentage of Population Dead: 98.3653%
# Total People Infected: 9497 / 9604
# Total Deaths: 9447 / 9604
#
# -----Day # 105-----
# Percentage of Population Infected: 99.0733%
# Percentage of Population Dead: 98.459%
# Total People Infected: 9515 / 9604
# Total Deaths: 9456 / 9604
#
# -----Day # 106-----
# Percentage of Population Infected: 99.1462%
# Percentage of Population Dead: 98.5631%
# Total People Infected: 9522 / 9604
# Total Deaths: 9466 / 9604
#
# -----Day # 107-----
# Percentage of Population Infected: 99.1358%
# Percentage of Population Dead: 98.636%
# Total People Infected: 9521 / 9604
# Total Deaths: 9473 / 9604
#
# -----Day # 108-----
# Percentage of Population Infected: 99.1774%
# Percentage of Population Dead: 98.6985%
# Total People Infected: 9525 / 9604
# Total Deaths: 9479 / 9604
#
# -----Day # 109-----
# Percentage of Population Infected: 99.1878%
# Percentage of Population Dead: 98.7505%
# Total People Infected: 9526 / 9604
# Total Deaths: 9484 / 9604
#
# -----Day # 110-----
# Percentage of Population Infected: 99.1566%
# Percentage of Population Dead: 98.7713%
# Total People Infected: 9523 / 9604
# Total Deaths: 9486 / 9604
#
# -----Day # 111-----
# Percentage of Population Infected: 99.167%
# Percentage of Population Dead: 98.8442%
# Total People Infected: 9524 / 9604
# Total Deaths: 9493 / 9604
#
# -----Day # 112-----
# Percentage of Population Infected: 99.1462%
# Percentage of Population Dead: 98.8963%
# Total People Infected: 9522 / 9604
# Total Deaths: 9498 / 9604
#
# -----Day # 113-----
# Percentage of Population Infected: 99.1774%
# Percentage of Population Dead: 98.9171%
# Total People Infected: 9525 / 9604
# Total Deaths: 9500 / 9604
#
# -----Day # 114-----
# Percentage of Population Infected: 99.3024%
# Percentage of Population Dead: 98.9484%
# Total People Infected: 9537 / 9604
# Total Deaths: 9503 / 9604
#
# -----Day # 115-----
# Percentage of Population Infected: 99.3336%
# Percentage of Population Dead: 99.0317%
# Total People Infected: 9540 / 9604
# Total Deaths: 9511 / 9604
#
# -----Day # 116-----
# Percentage of Population Infected: 99.4065%
# Percentage of Population Dead: 99.0941%
# Total People Infected: 9547 / 9604
# Total Deaths: 9517 / 9604
#
# -----Day # 117-----
# Percentage of Population Infected: 99.4377%
# Percentage of Population Dead: 99.1462%
# Total People Infected: 9550 / 9604
# Total Deaths: 9522 / 9604
#
# -----Day # 118-----
# Percentage of Population Infected: 99.4377%
# Percentage of Population Dead: 99.1878%
# Total People Infected: 9550 / 9604
# Total Deaths: 9526 / 9604
#
# -----Day # 119-----
# Percentage of Population Infected: 99.4273%
# Percentage of Population Dead: 99.1983%
# Total People Infected: 9549 / 9604
# Total Deaths: 9527 / 9604
#
# -----Day # 120-----
# Percentage of Population Infected: 99.4377%
# Percentage of Population Dead: 99.2087%
# Total People Infected: 9550 / 9604
# Total Deaths: 9528 / 9604
#
# -----Day # 121-----
# Percentage of Population Infected: 99.5002%
# Percentage of Population Dead: 99.2295%
# Total People Infected: 9556 / 9604
# Total Deaths: 9530 / 9604
#
# -----Day # 122-----
# Percentage of Population Infected: 99.5731%
# Percentage of Population Dead: 99.2607%
# Total People Infected: 9563 / 9604
# Total Deaths: 9533 / 9604
#
# -----Day # 123-----
# Percentage of Population Infected: 99.6043%
# Percentage of Population Dead: 99.292%
# Total People Infected: 9566 / 9604
# Total Deaths: 9536 / 9604
#
# -----Day # 124-----
# Percentage of Population Infected: 99.5939%
# Percentage of Population Dead: 99.3336%
# Total People Infected: 9565 / 9604
# Total Deaths: 9540 / 9604
#
# -----Day # 125-----
# Percentage of Population Infected: 99.5835%
# Percentage of Population Dead: 99.3336%
# Total People Infected: 9564 / 9604
# Total Deaths: 9540 / 9604
#
# -----Day # 126-----
# Percentage of Population Infected: 99.6252%
# Percentage of Population Dead: 99.344%
# Total People Infected: 9568 / 9604
# Total Deaths: 9541 / 9604
#
# -----Day # 127-----
# Percentage of Population Infected: 99.6147%
# Percentage of Population Dead: 99.3857%
# Total People Infected: 9567 / 9604
# Total Deaths: 9545 / 9604
#
# -----Day # 128-----
# Percentage of Population Infected: 99.6668%
# Percentage of Population Dead: 99.3961%
# Total People Infected: 9572 / 9604
# Total Deaths: 9546 / 9604
#
# -----Day # 129-----
# Percentage of Population Infected: 99.6668%
# Percentage of Population Dead: 99.4273%
# Total People Infected: 9572 / 9604
# Total Deaths: 9549 / 9604
#
# -----Day # 130-----
# Percentage of Population Infected: 99.646%
# Percentage of Population Dead: 99.4794%
# Total People Infected: 9570 / 9604
# Total Deaths: 9554 / 9604
#
# -----Day # 131-----
# Percentage of Population Infected: 99.6252%
# Percentage of Population Dead: 99.4898%
# Total People Infected: 9568 / 9604
# Total Deaths: 9555 / 9604
#
# -----Day # 132-----
# Percentage of Population Infected: 99.6356%
# Percentage of Population Dead: 99.4898%
# Total People Infected: 9569 / 9604
# Total Deaths: 9555 / 9604
#
# -----Day # 133-----
# Percentage of Population Infected: 99.646%
# Percentage of Population Dead: 99.5002%
# Total People Infected: 9570 / 9604
# Total Deaths: 9556 / 9604
#
# -----Day # 134-----
# Percentage of Population Infected: 99.6356%
# Percentage of Population Dead: 99.521%
# Total People Infected: 9569 / 9604
# Total Deaths: 9558 / 9604
#
# -----Day # 135-----
# Percentage of Population Infected: 99.7085%
# Percentage of Population Dead: 99.5523%
# Total People Infected: 9576 / 9604
# Total Deaths: 9561 / 9604
#
# -----Day # 136-----
# Percentage of Population Infected: 99.7293%
# Percentage of Population Dead: 99.5835%
# Total People Infected: 9578 / 9604
# Total Deaths: 9564 / 9604
#
# -----Day # 137-----
# Percentage of Population Infected: 99.7189%
# Percentage of Population Dead: 99.5939%
# Total People Infected: 9577 / 9604
# Total Deaths: 9565 / 9604
#
# -----Day # 138-----
# Percentage of Population Infected: 99.8022%
# Percentage of Population Dead: 99.6147%
# Total People Infected: 9585 / 9604
# Total Deaths: 9567 / 9604
#
# -----Day # 139-----
# Percentage of Population Infected: 99.7813%
# Percentage of Population Dead: 99.646%
# Total People Infected: 9583 / 9604
# Total Deaths: 9570 / 9604
#
# -----Day # 140-----
# Percentage of Population Infected: 99.7709%
# Percentage of Population Dead: 99.6564%
# Total People Infected: 9582 / 9604
# Total Deaths: 9571 / 9604
#
# -----Day # 141-----
# Percentage of Population Infected: 99.7813%
# Percentage of Population Dead: 99.6564%
# Total People Infected: 9583 / 9604
# Total Deaths: 9571 / 9604
#
# -----Day # 142-----
# Percentage of Population Infected: 99.8022%
# Percentage of Population Dead: 99.6876%
# Total People Infected: 9585 / 9604
# Total Deaths: 9574 / 9604
#
# -----Day # 143-----
# Percentage of Population Infected: 99.8126%
# Percentage of Population Dead: 99.6876%
# Total People Infected: 9586 / 9604
# Total Deaths: 9574 / 9604
#
# -----Day # 144-----
# Percentage of Population Infected: 99.823%
# Percentage of Population Dead: 99.7085%
# Total People Infected: 9587 / 9604
# Total Deaths: 9576 / 9604
#
# -----Day # 145-----
# Percentage of Population Infected: 99.8334%
# Percentage of Population Dead: 99.7293%
# Total People Infected: 9588 / 9604
# Total Deaths: 9578 / 9604
#
# -----Day # 146-----
# Percentage of Population Infected: 99.8334%
# Percentage of Population Dead: 99.7605%
# Total People Infected: 9588 / 9604
# Total Deaths: 9581 / 9604
# -----Day # 147-----
# Percentage of Population Infected: 99.8126%
# Percentage of Population Dead: 99.7605%
# Total People Infected: 9586 / 9604
# Total Deaths: 9581 / 9604
#
# -----Day # 148-----
# Percentage of Population Infected: 99.8542%
# Percentage of Population Dead: 99.7709%
# Total People Infected: 9590 / 9604
# Total Deaths: 9582 / 9604
#
# -----Day # 149-----
# Percentage of Population Infected: 99.8751%
# Percentage of Population Dead: 99.7709%
# Total People Infected: 9592 / 9604
# Total Deaths: 9582 / 9604
#
# -----Day # 150-----
# Percentage of Population Infected: 99.8959%
# Percentage of Population Dead: 99.7709%
# Total People Infected: 9594 / 9604
# Total Deaths: 9582 / 9604
#
# -----Day # 151-----
# Percentage of Population Infected: 99.8959%
# Percentage of Population Dead: 99.7813%
# Total People Infected: 9594 / 9604
# Total Deaths: 9583 / 9604
#
# -----Day # 152-----
# Percentage of Population Infected: 99.8751%
# Percentage of Population Dead: 99.8126%
# Total People Infected: 9592 / 9604
# Total Deaths: 9586 / 9604
#
# -----Day # 153-----
# Percentage of Population Infected: 99.8646%
# Percentage of Population Dead: 99.823%
# Total People Infected: 9591 / 9604
# Total Deaths: 9587 / 9604
#
# -----Day # 154-----
# Percentage of Population Infected: 99.8646%
# Percentage of Population Dead: 99.823%
# Total People Infected: 9591 / 9604
# Total Deaths: 9587 / 9604
#
# -----Day # 155-----
# Percentage of Population Infected: 99.9063%
# Percentage of Population Dead: 99.8438%
# Total People Infected: 9595 / 9604
# Total Deaths: 9589 / 9604
#
# -----Day # 156-----
# Percentage of Population Infected: 99.9063%
# Percentage of Population Dead: 99.8646%
# Total People Infected: 9595 / 9604
# Total Deaths: 9591 / 9604
#
# -----Day # 157-----
# Percentage of Population Infected: 99.9271%
# Percentage of Population Dead: 99.8646%
# Total People Infected: 9597 / 9604
# Total Deaths: 9591 / 9604
#
# -----Day # 158-----
# Percentage of Population Infected: 99.9375%
# Percentage of Population Dead: 99.8751%
# Total People Infected: 9598 / 9604
# Total Deaths: 9592 / 9604
#
# -----Day # 159-----
# Percentage of Population Infected: 99.9479%
# Percentage of Population Dead: 99.8855%
# Total People Infected: 9599 / 9604
# Total Deaths: 9593 / 9604
#
# -----Day # 160-----
# Percentage of Population Infected: 99.9479%
# Percentage of Population Dead: 99.8855%
# Total People Infected: 9599 / 9604
# Total Deaths: 9593 / 9604
#
# -----Day # 161-----
# Percentage of Population Infected: 99.9375%
# Percentage of Population Dead: 99.8855%
# Total People Infected: 9598 / 9604
# Total Deaths: 9593 / 9604
#
# -----Day # 162-----
# Percentage of Population Infected: 99.9375%
# Percentage of Population Dead: 99.8959%
# Total People Infected: 9598 / 9604
# Total Deaths: 9594 / 9604
#
# -----Day # 163-----
# Percentage of Population Infected: 99.9271%
# Percentage of Population Dead: 99.8959%
# Total People Infected: 9597 / 9604
# Total Deaths: 9594 / 9604
#
# -----Day # 164-----
# Percentage of Population Infected: 99.9271%
# Percentage of Population Dead: 99.8959%
# Total People Infected: 9597 / 9604
# Total Deaths: 9594 / 9604
#
# -----Day # 165-----
# Percentage of Population Infected: 99.9271%
# Percentage of Population Dead: 99.8959%
# Total People Infected: 9597 / 9604
# Total Deaths: 9594 / 9604
#
# -----Day # 166-----
# Percentage of Population Infected: 99.9271%
# Percentage of Population Dead: 99.8959%
# Total People Infected: 9597 / 9604
# Total Deaths: 9594 / 9604
#
# -----Day # 167-----
# Percentage of Population Infected: 99.9271%
# Percentage of Population Dead: 99.8959%
# Total People Infected: 9597 / 9604
# Total Deaths: 9594 / 9604
#
# -----Day # 168-----
# Percentage of Population Infected: 99.9584%
# Percentage of Population Dead: 99.8959%
# Total People Infected: 9600 / 9604
# Total Deaths: 9594 / 9604
#
# -----Day # 169-----
# Percentage of Population Infected: 99.9375%
# Percentage of Population Dead: 99.8959%
# Total People Infected: 9598 / 9604
# Total Deaths: 9594 / 9604
#
# -----Day # 170-----
# Percentage of Population Infected: 99.9271%
# Percentage of Population Dead: 99.8959%
# Total People Infected: 9597 / 9604
# Total Deaths: 9594 / 9604
#
# -----Day # 171-----
# Percentage of Population Infected: 99.9479%
# Percentage of Population Dead: 99.9063%
# Total People Infected: 9599 / 9604
# Total Deaths: 9595 / 9604
#
# -----Day # 172-----
# Percentage of Population Infected: 99.9375%
# Percentage of Population Dead: 99.9167%
# Total People Infected: 9598 / 9604
# Total Deaths: 9596 / 9604
#
# -----Day # 173-----
# Percentage of Population Infected: 99.9375%
# Percentage of Population Dead: 99.9271%
# Total People Infected: 9598 / 9604
# Total Deaths: 9597 / 9604
#
# -----Day # 174-----
# Percentage of Population Infected: 99.9584%
# Percentage of Population Dead: 99.9271%
# Total People Infected: 9600 / 9604
# Total Deaths: 9597 / 9604
#
# -----Day # 175-----
# Percentage of Population Infected: 99.9688%
# Percentage of Population Dead: 99.9271%
# Total People Infected: 9601 / 9604
# Total Deaths: 9597 / 9604
#
# -----Day # 176-----
# Percentage of Population Infected: 99.9688%
# Percentage of Population Dead: 99.9479%
# Total People Infected: 9601 / 9604
# Total Deaths: 9599 / 9604
#
# -----Day # 177-----
# Percentage of Population Infected: 99.9688%
# Percentage of Population Dead: 99.9479%
# Total People Infected: 9601 / 9604
# Total Deaths: 9599 / 9604
#
# -----Day # 178-----
# Percentage of Population Infected: 99.9688%
# Percentage of Population Dead: 99.9479%
# Total People Infected: 9601 / 9604
# Total Deaths: 9599 / 9604
#
# -----Day # 179-----
# Percentage of Population Infected: 99.9584%
# Percentage of Population Dead: 99.9584%
# Total People Infected: 9600 / 9604
# Total Deaths: 9600 / 9604
#
# -----Day # 180-----
# Percentage of Population Infected: 99.9688%
# Percentage of Population Dead: 99.9584%
# Total People Infected: 9601 / 9604
# Total Deaths: 9600 / 9604
#
# -----Day # 181-----
# Percentage of Population Infected: 99.9688%
# Percentage of Population Dead: 99.9584%
# Total People Infected: 9601 / 9604
# Total Deaths: 9600 / 9604
#
# -----Day # 182-----
# Percentage of Population Infected: 99.9792%
# Percentage of Population Dead: 99.9584%
# Total People Infected: 9602 / 9604
# Total Deaths: 9600 / 9604
#
# -----Day # 183-----
# Percentage of Population Infected: 99.9792%
# Percentage of Population Dead: 99.9584%
# Total People Infected: 9602 / 9604
# Total Deaths: 9600 / 9604
#
# -----Day # 184-----
# Percentage of Population Infected: 99.9688%
# Percentage of Population Dead: 99.9584%
# Total People Infected: 9601 / 9604
# Total Deaths: 9600 / 9604
#
# -----Day # 185-----
# Percentage of Population Infected: 99.9688%
# Percentage of Population Dead: 99.9584%
# Total People Infected: 9601 / 9604
# Total Deaths: 9600 / 9604
#
# -----Day # 186-----
# Percentage of Population Infected: 99.9584%
# Percentage of Population Dead: 99.9584%
# Total People Infected: 9600 / 9604
# Total Deaths: 9600 / 9604
#
# -----Day # 187-----
# Percentage of Population Infected: 99.9584%
# Percentage of Population Dead: 99.9584%
# Total People Infected: 9600 / 9604
# Total Deaths: 9600 / 9604
#
# -----Day # 188-----
# Percentage of Population Infected: 99.9584%
# Percentage of Population Dead: 99.9584%
# Total People Infected: 9600 / 9604
# Total Deaths: 9600 / 9604
#
# -----Day # 189-----
# Percentage of Population Infected: 99.9792%
# Percentage of Population Dead: 99.9688%
# Total People Infected: 9602 / 9604
# Total Deaths: 9601 / 9604
#
# -----Day # 190-----
# Percentage of Population Infected: 99.9792%
# Percentage of Population Dead: 99.9792%
# Total People Infected: 9602 / 9604
# Total Deaths: 9602 / 9604
#
# -----Day # 191-----
# Percentage of Population Infected: 99.9792%
# Percentage of Population Dead: 99.9792%
# Total People Infected: 9602 / 9604
# Total Deaths: 9602 / 9604
#
# -----Day # 192-----
# Percentage of Population Infected: 100.0%
# Percentage of Population Dead: