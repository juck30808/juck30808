# %%
import numpy as np
import pandas as pd

# creating a data frame
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[3, 3] = np.nan
df.iloc[0, 2] = np.nan
df
# Out:
#       A         B         C         D         E
# 0   1.0 -1.279423       NaN -0.558171 -0.360454
# 1   2.0  0.935846 -0.096555 -2.626912  1.716705
# 2   3.0 -1.429502 -0.804281  0.810361 -1.184840
# 3   4.0 -0.209499 -2.742235       NaN -0.335115
# 4   5.0  1.619334  2.241632  0.794322 -1.662708
# 5   6.0 -0.359369  1.374087 -0.624550 -2.107398
# 6   7.0  1.238907  1.133841 -0.582262  0.101445
# 7   8.0 -1.824289 -0.593847  0.800469  0.574717
# 8   9.0  0.763211 -0.094847 -0.136748  1.016123
# 9  10.0  0.031169  0.308149 -0.257475  0.455049

# %%
# highligting null values
df.style.highlight_null(null_color = 'yellow')
# Out:
# <style  type="text/css" >
# #T_97235070_c9b7_11eb_9edd_30f7726bd5a8row0_col2,#T_97235070_c9b7_11eb_9edd_30f7726bd5a8row3_col3{
#             background-color:  yellow;
#         }</style><table id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row0_col1" class="data row0 col1" >-0.787392</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row0_col3" class="data row0 col3" >-0.370106</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row0_col4" class="data row0 col4" >-0.893461</td>
#             </tr>
#             <tr>
#                         <th id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row1_col0" class="data row1 col0" >2.000000</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row1_col1" class="data row1 col1" >0.311785</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row1_col2" class="data row1 col2" >0.251296</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row1_col3" class="data row1 col3" >-0.748748</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row1_col4" class="data row1 col4" >-0.775514</td>
#             </tr>
#             <tr>
#                         <th id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row2_col0" class="data row2 col0" >3.000000</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row2_col1" class="data row2 col1" >-1.958343</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row2_col2" class="data row2 col2" >0.364081</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row2_col3" class="data row2 col3" >0.044705</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row2_col4" class="data row2 col4" >0.519255</td>
#             </tr>
#             <tr>
#                         <th id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row3_col0" class="data row3 col0" >4.000000</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row3_col1" class="data row3 col1" >-0.804902</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row3_col2" class="data row3 col2" >-0.843576</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row3_col4" class="data row3 col4" >-0.633180</td>
#             </tr>
#             <tr>
#                         <th id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row4_col0" class="data row4 col0" >5.000000</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row4_col1" class="data row4 col1" >0.042322</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row4_col2" class="data row4 col2" >0.051558</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row4_col3" class="data row4 col3" >-1.737793</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row4_col4" class="data row4 col4" >0.187287</td>
#             </tr>
#             <tr>
#                         <th id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row5_col0" class="data row5 col0" >6.000000</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row5_col1" class="data row5 col1" >0.982141</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row5_col2" class="data row5 col2" >0.687523</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row5_col3" class="data row5 col3" >0.698913</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row5_col4" class="data row5 col4" >-0.660835</td>
#             </tr>
#             <tr>
#                         <th id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row6_col0" class="data row6 col0" >7.000000</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row6_col1" class="data row6 col1" >-0.211095</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row6_col2" class="data row6 col2" >0.127750</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row6_col3" class="data row6 col3" >1.209621</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row6_col4" class="data row6 col4" >0.371340</td>
#             </tr>
#             <tr>
#                         <th id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row7_col0" class="data row7 col0" >8.000000</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row7_col1" class="data row7 col1" >-0.639225</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row7_col2" class="data row7 col2" >-0.504991</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row7_col3" class="data row7 col3" >0.538978</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row7_col4" class="data row7 col4" >-0.070873</td>
#             </tr>
#             <tr>
#                         <th id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row8_col0" class="data row8 col0" >9.000000</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row8_col1" class="data row8 col1" >-1.545917</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row8_col2" class="data row8 col2" >0.658030</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row8_col3" class="data row8 col3" >-1.609224</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row8_col4" class="data row8 col4" >-1.578128</td>
#             </tr>
#             <tr>
#                         <th id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row9_col0" class="data row9 col0" >10.000000</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row9_col1" class="data row9 col1" >-0.998464</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row9_col2" class="data row9 col2" >-2.426835</td>
#                         <td id="T_97235070_c9b7_11eb_9edd_30f7726bd5a8row9_col3" class="data row9 col3" >1.027563</td>
#                         <

# %%
df.style.background_gradient(cmap = 'Greens')
# Out:
# <style  type="text/css" >
# #T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row0_col0,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row2_col1,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row4_col3,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row8_col4,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row9_col2{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row0_col1{
#             background-color:  #99d595;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row0_col2,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row3_col3{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row0_col3{
#             background-color:  #81ca81;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row0_col4{
#             background-color:  #bde5b6;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row1_col0{
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row1_col1,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row7_col3{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row1_col2{
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row1_col3,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row3_col0{
#             background-color:  #aedea7;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row1_col4{
#             background-color:  #afdfa8;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row2_col0{
#             background-color:  #ceecc8;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row2_col2{
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row2_col3{
#             background-color:  #4aaf61;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row2_col4{
#             background-color:  #026f2e;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row3_col1{
#             background-color:  #9bd696;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row3_col2{
#             background-color:  #70c274;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row3_col4{
#             background-color:  #9cd797;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row4_col0{
#             background-color:  #88ce87;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row4_col1{
#             background-color:  #339c52;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row4_col2{
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row4_col4{
#             background-color:  #289049;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row5_col0{
#             background-color:  #5db96b;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row5_col1,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row5_col2,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row6_col3,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row9_col0,#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row9_col4{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row5_col3{
#             background-color:  #0d7836;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row5_col4{
#             background-color:  #a0d99b;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row6_col0{
#             background-color:  #37a055;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row6_col1{
#             background-color:  #4db163;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row6_col2{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row6_col4{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row7_col0{
#             background-color:  #1a843f;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row7_col1{
#             background-color:  #87cd86;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row7_col2{
#             background-color:  #45ad5f;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row7_col4{
#             background-color:  #43ac5e;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row8_col0{
#             background-color:  #00682a;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row8_col1{
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row8_col2{
#             background-color:  #00471c;
#             color:  #f1f1f1;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row8_col3{
#             background-color:  #f1faee;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row9_col1{
#             background-color:  #b0dfaa;
#             color:  #000000;
#         }#T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row9_col3{
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }</style><table id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row0_col1" class="data row0 col1" >-0.787392</td>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row0_col3" class="data row0 col3" >-0.370106</td>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row0_col4" class="data row0 col4" >-0.893461</td>
#             </tr>
#             <tr>
#                         <th id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row1_col0" class="data row1 col0" >2.000000</td>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row1_col1" class="data row1 col1" >0.311785</td>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row1_col2" class="data row1 col2" >0.251296</td>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row1_col3" class="data row1 col3" >-0.748748</td>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row1_col4" class="data row1 col4" >-0.775514</td>
#             </tr>
#             <tr>
#                         <th id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row2_col0" class="data row2 col0" >3.000000</td>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row2_col1" class="data row2 col1" >-1.958343</td>
#                         <td id="T_1c7c65c8_c9b8_11eb_8a95_30f7726bd5a8row2_col2" class="data row2 col2" >0.364081</td>
#                         <td id="T_1c7c65c

# %%
df.style.bar(color = 'skyblue')
# Out:
# <style  type="text/css" >
# #T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row0_col0,#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row2_col1,#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row4_col3,#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row8_col4,#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row9_col2{
#             width:  10em;
#              height:  80%;
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 39.8%, transparent 39.8%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 46.4%, transparent 46.4%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 28.2%, transparent 28.2%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 11.1%, transparent 11.1%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row1_col1,#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row7_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 77.2%, transparent 77.2%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 86.0%, transparent 86.0%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 33.6%, transparent 33.6%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 33.0%, transparent 33.0%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 22.2%, transparent 22.2%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 89.6%, transparent 89.6%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 60.5%, transparent 60.5%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 86.3%, transparent 86.3%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 33.3%, transparent 33.3%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 39.2%, transparent 39.2%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 50.8%, transparent 50.8%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 38.9%, transparent 38.9%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 44.4%, transparent 44.4%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 68.0%, transparent 68.0%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 79.6%, transparent 79.6%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 72.7%, transparent 72.7%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 55.6%, transparent 55.6%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row5_col1,#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row5_col2,#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row6_col3,#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row9_col0,#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row9_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 82.7%, transparent 82.7%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 37.8%, transparent 37.8%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 66.7%, transparent 66.7%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 59.4%, transparent 59.4%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 82.0%, transparent 82.0%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 80.3%, transparent 80.3%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 77.8%, transparent 77.8%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 44.9%, transparent 44.9%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 61.7%, transparent 61.7%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row7_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 62.1%, transparent 62.1%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 88.9%, transparent 88.9%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 14.0%, transparent 14.0%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 99.1%, transparent 99.1%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row8_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 4.4%, transparent 4.4%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 32.6%, transparent 32.6%);
#         }#T_a32f0b8a_c9b9_11eb_822b_30f7726bd5a8row9_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 93.8%, transparent 93.8%);
#         }</style><table id="T_a32f0b8a_c9b9_11eb_822b_30f7
