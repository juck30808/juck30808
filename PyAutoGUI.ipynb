# %%
#pip install pyautogui

# %%
import pyautogui
print(pyautogui.position()) # mouse position
# Out:
# Point(x=1446, y=623)

# %%
pyautogui.size()  #解析度
# Out:
# Size(width=1920, height=1080)

# %%
pyautogui.moveTo(100, 100, duration = 0.5)   # move to x=100，y=100 絕對位置

# %%
pyautogui.moveRel(100, 100, duration = 0.5)  # move to x=100，y=100 相對位置

# %%
pyautogui.dragTo(100, 100, duration=0.5, button='left')  # hold

# %%
pyautogui.click(clicks=2, interval=0.1, button='left')   # double click

# %%
pyautogui.scroll(2) #roll

# %% [markdown]
# ## Keyboard

# %%
pyautogui.press('enter') #按下enter鍵
pyautogui.press('c') #按下c鍵
pyautogui.press('alt') #按下alt鍵

# %%
#way1
pyautogui.keyDown('ctrl')
pyautogui.press('a')
pyautogui.keyUp('ctrl') #全選的功能鍵效果

# %%
#way2
pyautogui.hotkey('ctrl', 'shift', 'esc') #開啟工作管理員的快捷鍵

# %%
# 截圖測試
pyautogui.screenshot('./output/screenshot1.png')
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x1F661A28CD0>

# %%
import pyautogui
print(pyautogui.position()) # mouse position

# %%
pyautogui.moveTo(1446, 623, duration = 0.1)   # move to x=100，y=100 絕對位置
pyautogui.click(clicks=9999, interval=0.1, button='left')   # double click
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-d91367408c60> in <module>
#       1 pyautogui.moveTo(1446, 623, duration = 0.1)   # move to x=100，y=100 絕對位置
# ----> 2 pyautogui.click(clicks=9999, interval=0.1, button='left')   # double click
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     584     def wrapper(*args, **kwargs):
#     585         failSafeCheck()
# --> 586         returnVal = wrappedFunction(*args, **kwargs)
#     587         _handlePause(kwargs.get("_pause", True))
#     588         return returnVal
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in click(x, y, clicks, interval, button, duration, tween, logScreenshot, _pause)
#     984                 platformModule._click(x, y, button)
#     985
# --> 986             time.sleep(interval)
#     987
#     988
#
# KeyboardInterrupt:

# %% [markdown]
# 話說我都拿這個套件幹嘛?恩...除了某些遊戲需要定期的截圖或是刷道具遊戲需要定期點以外...
# 我都拿去按popcat(((((
# 不過這套件的確是很方便就是了，利用上面這些函式就可以自由針對不同事件撰寫專門的自動化程式碼，就不需要人力慢慢點囉~
