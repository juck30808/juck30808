# %% [markdown]
# ## F12 -> Network -> Fetch/XHR -> open comment
#
# https://ithelp.ithome.com.tw/articles/10267131

# %%
import requests 
import json
import random

j = 0
lottery_pool = []

while 1:
    url = "https://www.google.com.tw/maps/preview/review/listentitiesreviews?authuser=0&hl=zh-TW&gl=tw&pb=!1m2!1y3765762734390772041!2y17055821615375049737!2m2!1i"+ str(j) +"!2i10!3e1!4m5!3b1!4b1!5b1!6b1!7b1!5m2!1siMZEYbemFIeymAWI2pko!7e81"
    j = j + 10 
        
    text = requests.get(url).text
    pretext = ')]}\'' 
    text = text.replace(pretext,' ')   # 把字串讀取成json 取代特殊字元
    soup = json.loads(text)            # 載入json檔
    review_list = soup[2]              # 留言的位置

    if review_list is None:
        break
        
    for i in review_list:
        print("正在抽獎...")
        # 姓名: str(i[0][1])
        # 時間: str(i[1])
        # 星星數: str(i[4])
        # 留言內容: str(i[3])     
        if i[4]==5 and i[3] != None: # 給五星加有留言的評價才可以抽獎喔
            dict = [str(i[0][1]),str(i[1]),str(i[4]),str(i[3])]
            lottery_pool.append(dict)       
            
winner_index = random.sample(range(0, len(lottery_pool)-1), 3) # 設定抽3人
print("-------中獎名單------")
for i in winner_index:
    print(lottery_pool[i])
# Out:
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# 正在抽獎...
# -------中獎名單------
# ['Ching Hao Wang', '3 個月前', '5', '(由 Google 提供翻譯) 好吃😋😋\n\n(原始評論)\n好吃😋😋']
# ['Kathryn Chang', '6 個月前', '5', '推薦牛小排便當\n便當搭配五行配色蔬菜 很養生']
# ['Firemanruby Chang (魯比)', '1 年前', '5', '內湖最好吃的便當，用料實在，品質穩定！']

# %%
# 咖啡廳測試
# https://www.google.com/maps/preview/review/listentitiesreviews?gl=tw&pb=!1m2!1y3765758514298713173!2y1068936344628133893!2m2!1i8!2i8!4m1!3b1!5m7!4m1!2i23934!7e140!9sKlW1YuuiNsyJmAWTq5rQDQ:424692678957!17sKlW1YuuiNsyJmAWTq5rQDQ:424692678958!24m1!2e1
# https://www.google.com/maps/preview/review/listentitiesreviews?gl=tw&pb=!1m2!1y3765758514298713173!2y1068936344628133893!2m2!1i16!2i8!4m1!3b1!5m7!4m1!2i23934!7e140!9sKlW1YuuiNsyJmAWTq5rQDQ:424692678958!17sKlW1YuuiNsyJmAWTq5rQDQ:424692678959!24m1!2e1

# %%
import requests 
import json
import random

j = 0
count = 0
lottery_pool = []

while 1:  
    url = "https://www.google.com/maps/preview/review/listentitiesreviews?gl=tw&pb=!1m2!1y3765758514298713173!2y1068936344628133893!2m2!1i"+ str(j) +"!2i8!4m1!3b1!5m7!4m1!2i23934!7e140!9sKlW1YuuiNsyJmAWTq5rQDQ:424692678957!17sKlW1YuuiNsyJmAWTq5rQDQ:424692678958!24m1!2e1"
    j = j + 10 
        
    text = requests.get(url).text
    pretext = ')]}\'' 
    text = text.replace(pretext,' ')   # 把字串讀取成json 取代特殊字元
    soup = json.loads(text)            # 載入json檔
    review_list = soup[2]              # 留言的位置

    if review_list is None:
        break
        
    for i in review_list:
        # 給五星加有留言的評價才可以抽獎喔
        if i[4]==5 and i[3] != None: 
            dict = [str(i[0][1]),str(i[1]),str(i[4]),str(i[3])]
            lottery_pool.append(dict) 
            count += 1
            print("合法名單")  
            
winner_index = random.sample(range(0, len(lottery_pool)-1), 3) # 設定抽3人
print("-------中獎名單------")
for i in winner_index:
    print(lottery_pool[i])
# Out:
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# 合法名單
# -------中獎名單------
# ['Yen Hua Chen', '1 年前', '5', '時隔半年再度來訪\n英俊還是一樣可愛(˶‾᷄ ⁻̫ ‾᷅˵)\n\n店內裝潢古色古香，飲料跟餐點也都相當有自己的特色\n特別推薦布朗尼可以點蜜橙和海鹽口味，甜而不膩配上烏龍茶形成絕妙的搭配\n乳酪蛋糕也很棒，跟外面的乳酪蛋糕很不一樣\n老闆娘人也很溫柔(///▽///)\n餐點、氣氛跟狗狗都100分♥️♥️♥️\n\nBy 男友：「我這個人很簡單，有狗狗就給讚👍」']
# ['jiunhau wang', '2 年前', '5', '餐點用心 很適合聊天\n\n英俊很可愛']
# ['Yung Lin Chien', '2 年前', '5', '英俊很可愛！']

# %% [markdown]
# ## 防爬蟲偽裝

# %%
pip install fake_useragent
# Out:
# Requirement already satisfied: fake_useragent in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (0.1.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
from fake_useragent import UserAgent

ua = UserAgent() # 產生一個 user agent
user_agent = ua.random # 隨機產生一個 user agent字串

# %%
headers = {'user-agent': user_agent}
text = requests.get(url, headers=headers).text
