# %% [markdown]
# # <font style="color:black">Getting Started with Images</font>
# This notebook will help you take your first steps in learning Image Processing and Computer Vision using OpenCV. You will learn some important lessons using some simple examples. In this notebook, you will learn the following:
#
# * Reading an image
# * Check image attributes like datatype and shape
# * Matrix representation of an image in Numpy
# * Color Images and splitting/merging image channels
# * Displaying images using matplotlib
# * Saving images

# %%
import PIL.Image as MyImage

img = MyImage.open("./input/Sample.png")
img.show()


print("Type: ",type(img))
img_size=img.size
print("Size: ",img_size)

w=img_size[0]
h=img_size[1]
print("Width , Height => ",w,",",h)
print("Width: ",img.width)
print("Height: ",img.height)
print("Format: ",img.format)
print("Color Mode:",img.mode)
# Out:
# Type:  <class 'PIL.PngImagePlugin.PngImageFile'>
# Size:  (558, 547)
# Width , Height =>  558 , 547
# Width:  558
# Height:  547
# Format:  PNG
# Color Mode: RGBA

# %% [markdown]
# ## 照片旋轉 (rotate & Flip)

# %%
from PIL import Image

img = Image.open("./input/Sample.png")
img.show()
newImg = img.rotate(90) 
newImg.show()
newImg.save("./input/Sample90.png")

# %%
img = MyImage.open("./input/Sample.png")

#img_transpose=img.transpose(MyImage.ROTATE_90)
#img_transpose=img_transpose.transpose(MyImage.ROTATE_90)
#----------flip-----------
img_transpose=img.transpose(MyImage.FLIP_TOP_BOTTOM)
img_transpose.show()
#--------- save image------------
img_transpose.save("./input/Sample_flip.png")
#img_transpose.save("Out/me_2021_rotate90.png")

# %% [markdown]
# ## 轉檔

# %%
from PIL import Image

img = Image.open("./input/Sample.png")
img.show()

newImg = img
newImg.save("./input/Sample.png","png")

# %% [markdown]
# ## 灰階轉換 (convert)

# %%
from PIL import Image

img = Image.open("./input/Sample.png")
img.show()

newImg = img.convert('1')  
newImg.show()
newImg.save("./input/Sample_convert.png")

# %% [markdown]
# ## 更改圖片尺寸 (resize)

# %%
from PIL import Image

img = Image.open("./input/Sample.png")
img.show()

newImg = img.resize((50,100),Image.LANCZOS)   #img.resize((int(img.width/4),int(img.height/4)))
newImg.show()
newImg.save("./input/Sample_size.png")

# %% [markdown]
# ## 裁切圖片 (crop)

# %%
import PIL.Image as MyImage

img= MyImage.open("./input/Sample.png")
img.show()
    
img_cropped=img.crop((180,100,290,145))    #( X,Y , X1,Y1) => ( X,Y , X+width,Y+height )
img_cropped.show()
img_cropped.save("./input/Sample_crop.png")

# %% [markdown]
# ## 嵌字 (Draw)

# %%
from PIL import Image, ImageDraw, ImageFont

img  = Image.open("./input/Sample.png")
img.show()

draw = ImageDraw.Draw(img)
font  = ImageFont.truetype("kaiu.ttf", 20)
color  = "purple"
text = "Test"
draw.text((10, 10), text, fill=color, font=font)

img.show()
img.save("./input/Sample_sign.png")

# %%
import PIL.Image as MyImage
import PIL.ImageDraw as MyImgDraw

img =MyImage.open("./input/Sample.png")
img.show()

ImgDraw=MyImgDraw.Draw(img)
ImgDraw.text((100,100),"Hi, I am juck30808!",fill=(200,0,0))    #RGB

img.show()
img.save("./input/Sample_draw.png")

# %%
import PIL.Image as MyImage
import PIL.ImageDraw as MyImgDraw
import PIL.ImageFont as MyImgFont

img = MyImage.open("./input/Sample.png")

#MyFont=MyImgFont.truetype("tt1034m_.ttf",28)
MyFont=MyImgFont.truetype("input/font1.ttf",50)
ImgDraw=MyImgDraw.Draw(img)
ImgDraw.text((10,50),"juck30808!",font=MyFont, fill=(200,0,0))#red,green,blue

img.show()
img.save("./input/Sample_draw.png")

# %% [markdown]
# ## 複製 (thumbnail)

# %%
import PIL.Image as MyImage

img = MyImage.open("./input/Sample.png")
img_copy=img.copy()
img_copy.thumbnail((100,100))
img_copy.show()

img_copy.save("./input/Sample_copy.png")

# %% [markdown]
# ## 調整濾鏡 (Filter)

# %%
import PIL.Image as MyImage
import PIL.ImageFilter as MyFilter

img = MyImage.open("./input/Sample.png")
img.show()

#Blur_Image=img.filter(MyFilter.BLUR)
#Blur_Image=img.filter(MyFilter.BoxBlur(1))
Blur_Image=img.filter(MyFilter.GaussianBlur(radius=20))

Blur_Image.show()
Blur_Image.save("./input/Sample_FilterBlur.png")

# %%
# Filter transformations
from PIL import ImageFilter
# Built-in filters:
# - ImageFilter.BLUR
# - ImageFilter.CONTOUR
# - ImageFilter.DETAIL
# - ImageFilter.EDGE_ENHANCE
# - ImageFilter.EMBOSS
# - ImageFilter.FIND_EDGES
# - ImageFilter.SHARPEN
# - ImageFilter.SMOOTH
# - ...and more!
out = img.filter(MyFilter.BLUR)
out.show()

# %% [markdown]
# ## ImageFilter

# %%
import PIL.Image as MyImage
import PIL.ImageFilter as MyFilter
img = MyImage.open("./input/Sample.png")
img.show()

# %%
Sharpen_Image=img.filter(MyFilter.SHARPEN)
Sharpen_Image.show()
Sharpen_Image.save("./input/Sample_FilterSharpen.png")

# %%
Smooth_Image=img.filter(MyFilter.SMOOTH_MORE)
Smooth_Image.show()
Smooth_Image.save("./input/Sample_FilterSmooth.png")

# %%
Contour_Image=img.filter(MyFilter.CONTOUR)
Contour_Image.show()
Contour_Image.save("./input/Sample_FilterCounter.png")

# %%
Detail_Image=img.filter(MyFilter.DETAIL)
Detail_Image.show()
Detail_Image.save("./input/Sample_FilterDETAIL.png")

# %%
EdgeEn_Image=img.filter(MyFilter.EDGE_ENHANCE_MORE)
EdgeEn_Image.show()
EdgeEn_Image.save("./input/Sample_FilterEdge.png")

# %%
Find_Edges_Image=img.filter(MyFilter.FIND_EDGES)
Find_Edges_Image.show()
Find_Edges_Image.save("./input/Sample_FilterFEdge.png")

# %%
Emboss_Image=img.filter(MyFilter.EMBOSS)
Emboss_Image.show()
Emboss_Image.save("./input/Sample_FilterEmboss.png")

# %%
from PIL import Image, ImageFilter
pil_g = Image.open('./input/Sample.png')
pil_g.show()  
pil_g_b = pil_g.filter(ImageFilter.BLUR()) 
pil_g_b.show()

# %%
pil_g.show() 
draw = ImageDraw.Draw(pil_g)
draw.rectangle((100, 200, 850, 950), outline=(255,0,255), width = 10)
draw.line((100, 200, 850, 950), fill=(0,0,255), width = 5)

pil_g.show()

# %%
from PIL import Image, ImageDraw, ImageFont 
draw = ImageDraw.Draw(pil_g)
draw.rectangle((100, 200, 550, 650), 
               outline=(0,0,0), width = 10)
draw.line((100, 200, 550, 650), width = 5)
draw.text((250,650), "This is a beautiful Garden",  fill=(255,0,255))
pil_g.show()

# %% [markdown]
# ## 合併圖片 combine (paste)

# %%
from PIL import Image

imageA = Image.open('./input/Sample.png')
imageB = Image.open('./input/Sample.png')
imageB = imageB.convert("RGBA")
widthB , heightB = imageB.size

newimageB  = imageB.resize((int(widthB*0.2),int(heightB*0.2)),Image.LANCZOS)

resultPicture = Image.new('RGBA', imageA.size, (0, 0, 0, 0))

resultPicture.paste(imageA,(0,0))
resultPicture.paste(newimageB, (0,0), newimageB)
resultPicture.show()
resultPicture.save("./input/result.png")

# %% [markdown]
# ## Resize and add Logo

# %%
import os
from PIL import Image

SQUARE_FIT_SIZE = 300
LOGO_FILENAME = './input/Sample.png'
logoIm = Image.open(LOGO_FILENAME)
logoWidth, logoHeight = logoIm.size
os.makedirs('withLogo', exist_ok=True)

# Loop over all files in the working directory.
for filename in os.listdir('.'):
    if not (filename.lower().endswith('.png') or filename.lower().endswith('.jpg')
            or filename.lower().endswith('.gif') or filename.lower().endswith('bmp')) \
        or filename == LOGO_FILENAME:
        continue # skip non-image files and the logo file itself

    im = Image.open(filename)
    width, height = im.size

    # Check if image needs to be resized.
    if width > SQUARE_FIT_SIZE and height > SQUARE_FIT_SIZE:
        # Calculate the new width and height to resize to.
        if width > height:
            height = int((SQUARE_FIT_SIZE / width) * height)
            width = SQUARE_FIT_SIZE
        else:
            width = int((SQUARE_FIT_SIZE / height) * width)
            height = SQUARE_FIT_SIZE

    # Resize the image.
    print('Resizing %s...' % (filename))
    im = im.resize((width, height))

    # Add the logo if it fits properly in image.
    imWidth, imHeight = im.size
    if imWidth < logoWidth * 2 and imHeight < logoHeight * 2:
        print("Logo taking up too much space in image so skipped..")
    else:
        print('Adding logo to %s...' % (filename))
        im.paste(logoIm, (width - logoWidth, height - logoHeight), logoIm)

    # Save changes.
    im.save(os.path.join('withLogo', filename))
# Out:
# Resizing New_Zealand_Lake_SAVED.png...
# Logo taking up too much space in image so skipped..
# Resizing qrcode-C.png...
# Logo taking up too much space in image so skipped..

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
# Display 18x18 pixel image.
Image(filename='input/Sample.png')

# %%
# Gray scale.
cb_img = cv2.imread('input/Sample.png',0)

print("Image size is ", cb_img.shape)
print("Data type of image is ", cb_img.dtype)

# Display image.
plt.imshow(cb_img)
plt.imshow(cb_img, cmap='gray')  #gray
# Out:
# Image size is  (547, 558)
# Data type of image is  uint8

# %%
# Split the image into the B,G,R components
img_NZ_bgr = cv2.imread("input/Sample.png",cv2.IMREAD_COLOR)
b,g,r = cv2.split(img_NZ_bgr)

# Show the channels
plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(r,cmap='gray');plt.title("Red Channel");
plt.subplot(142);plt.imshow(g,cmap='gray');plt.title("Green Channel");
plt.subplot(143);plt.imshow(b,cmap='gray');plt.title("Blue Channel");

# Merge the individual channels into a BGR image
imgMerged = cv2.merge((b,g,r))
# Show the merged output
plt.subplot(144);plt.imshow(imgMerged[:,:,::-1]);plt.title("Merged Output");

# %%
# OpenCV stores color channels in a differnet order than most other applications (BGR vs RGB).
img_NZ_rgb = cv2.cvtColor(img_NZ_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_NZ_rgb)

# %%
# Split the image into the B,G,R components
img_hsv = cv2.cvtColor(img_NZ_bgr, cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(img_hsv)

# Show the channels
plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(h,cmap='gray');plt.title("H Channel");
plt.subplot(142);plt.imshow(s,cmap='gray');plt.title("S Channel");
plt.subplot(143);plt.imshow(v,cmap='gray');plt.title("V Channel");
plt.subplot(144);plt.imshow(img_NZ_rgb);plt.title("Original");

# %%
# read the image as Color
img_NZ_bgr = cv2.imread("New_Zealand_Lake_SAVED.png", cv2.IMREAD_COLOR)
print("img_NZ_bgr shape is: ", img_NZ_bgr.shape)

# read the image as Grayscaled
img_NZ_gry = cv2.imread("New_Zealand_Lake_SAVED.png", cv2.IMREAD_GRAYSCALE)
print("img_NZ_gry shape is: ", img_NZ_gry.shape)
# Out:
# img_NZ_bgr shape is:  (512, 512, 3)
# img_NZ_gry shape is:  (512, 512)

# %% [markdown]
# ## ascii_char 點陣圖

# %%
ascii_char = list("01") # 可以自己改成想要標記的符號

imgs = r"input/Sample.png"
WIDTH = 30 # 寬
HEIGHT = 30 # 高

def get_char(gray_value):
    length = len(ascii_char) # 根據傳進來的灰階值判斷此位置要使用哪個字元
    unit = 256.0 / length    # 區分灰階範圍
    return ascii_char[int(gray_value / unit)]

if __name__ == '__main__':
    img = cv2.imread(imgs, cv2.IMREAD_GRAYSCALE) # 將圖片自動轉為灰階圖片
    img = cv2.resize(img, (WIDTH, HEIGHT))       # 將灰階圖縮小成指定大小
    txt = ""
    for i in range(HEIGHT):
        for j in range(WIDTH):
            txt += get_char(img[i][j])  # 轉為指定字符
        txt += '\n'
    print(txt)
# Out:
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111011111111111111
# 111111111111111011111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111
# 111111111111111111111111111111

# %% [markdown]
# ## Drawing

# %%
# Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from IPython.display import Image
from PIL import Image 
# %matplotlib inline

# %%
image = cv2.imread("input/Sample.png", cv2.IMREAD_COLOR)

imageLine = image.copy()
cv2.line(imageLine, (200, 100), (200, 100), (0, 255, 255), thickness=5, lineType=cv2.LINE_AA);

imageCircle = image.copy()
cv2.circle(imageCircle, (200,200), 100, (0, 0, 255), thickness=5, lineType=cv2.LINE_AA);

imageRectangle = image.copy()
cv2.rectangle(imageRectangle, (200, 100), (200,200), (255, 0, 255), thickness=5, lineType=cv2.LINE_8);

# Display the image
plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(imageLine[:,:,::-1])
plt.subplot(142);plt.imshow(imageCircle[:,:,::-1])
plt.subplot(143);plt.imshow(imageRectangle[:,:,::-1])

# %%
imageText = image.copy()
text = "Apollo 11 Saturn V Launch, July 16, 1969"
fontScale = 2.3
fontFace = cv2.FONT_HERSHEY_PLAIN
fontColor = (0, 255, 0)
fontThickness = 2

cv2.putText(imageText, text, (200, 200), fontFace, fontScale, fontColor, fontThickness, cv2.LINE_AA);

# Display the image
plt.imshow(imageText[:,:,::-1])

# %% [markdown]
# ## Image Alignment
#
# Think of keypoints as corner points that are stable under image transformations

# %%
# Read reference image
refFilename = "input/Sample.png"
print("Reading reference image : ", refFilename)
im1 = cv2.imread(refFilename, cv2.IMREAD_COLOR)
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)

# Read image to be aligned
imFilename = "input/Sample.png"
print("Reading image to align : ", imFilename)
im2 = cv2.imread(imFilename, cv2.IMREAD_COLOR)
im2 = cv2.cvtColor(im2, cv2.COLOR_BGR2RGB)

# Display Images
plt.figure(figsize=[20,10]); 
plt.subplot(121); plt.axis('off'); plt.imshow(im1); plt.title("Original Form")
plt.subplot(122); plt.axis('off'); plt.imshow(im2); plt.title("Scanned Form")
# Out:
# Reading reference image :  input/Sample.png
# Reading image to align :  input/Sample.png
# Text(0.5, 1.0, 'Scanned Form')

# %%
# Convert images to grayscale
im1_gray = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)
im2_gray = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)
  

# Detect ORB features and compute descriptors.
MAX_NUM_FEATURES = 500
orb = cv2.ORB_create(MAX_NUM_FEATURES)
keypoints1, descriptors1 = orb.detectAndCompute(im1_gray, None)
keypoints2, descriptors2 = orb.detectAndCompute(im2_gray, None)

# Display 
im1_display = cv2.drawKeypoints(im1, keypoints1, outImage=np.array([]), color=(255, 0, 0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
im2_display = cv2.drawKeypoints(im2, keypoints2, outImage=np.array([]), color=(255, 0, 0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.figure(figsize=[20,10])
plt.subplot(121); plt.axis('off'); plt.imshow(im1_display); plt.title("Original Form");
plt.subplot(122); plt.axis('off'); plt.imshow(im2_display); plt.title("Scanned Form");

# %%
import numpy as np
import cv2
img = cv2.imread("input/Sample.png")
img.shape
# Out:
# (547, 558, 3)

# %%
# pop-up
cv2.imshow('input/Sample.png', img)  
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 使用matplotlib顯示圖片
from matplotlib import pyplot as plt
plt.imshow(img[:,:,::-1]) # opencv是用BGR的順序，因此需要調換
plt.show()

# %%
# method1 .使用cv2轉換
img_gray = cv2.cvtColor(img, cv2.IMREAD_GRAYSCALE)

# %%
# method2 .使用 RGB 轉換 (R*0.299 + G*0.587 + B*0.114)
img_gray2 = np.array((img[:,:,0]*0.299 + img[:,:,0]*0.587 + img[:,:,0]*0.114), dtype="uint8")

# %%
# Gray scale
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Gray scale using cv2 vs. formula')
ax1.imshow(img_gray, cmap = 'gray')
ax2.imshow(img_gray2, cmap = 'gray')
plt.show()

# %%
hsv=cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # 轉換成HSV格式
h,s,v = cv2.split(hsv) # 分割成三個通道

fig, (ax1, ax2,ax3) = plt.subplots(1, 3)

fig.suptitle('HSV')
ax1.imshow(h)
ax1.set_title("H")
ax2.imshow(s)
ax2.set_title("S")
ax3.imshow(v,cmap="gray")
ax3.set_title("V")
plt.show()

# %%
np.ones((5,5))/25
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]])

# %%
import numpy as np
x, y = np.meshgrid(np.linspace(-1,1,7), np.linspace(-1,1,7)) # 建立二維
d = np.sqrt(x*x+y*y)
sigma, mu = 1.0, 0.0
kernel = np.exp(-( (d-mu)**2 / ( 2.0 * sigma**2 ) ) ) # 高斯分佈公式
kernel /= sum(sum(kernel)) #讓總和為1
plt.imshow(kernel)
plt.show()

# %% [markdown]
# ## rotate90

# %%
def rotate90(grid):
    """Rotates a grid 90 degrees
    Args:
        grid (list): a 2d list representing a grid
    Returns:
        grid (list): rotated copy of a 2d grid
    """
    return list(zip(*grid[::-1]))

def print2DGrid(grid):
    """Prints a 2D grid
    Args:
        grid (list): 2D grid
    Returns:
        None
    """
    for row in range(len(grid)):
        for col in range(len(grid[row])):
            print(grid[row][col], end='')

        print()

if __name__ == "__main__":
    grid = [['.', '.', '.', '.', '.', '.'],
            ['.', 'O', 'O', '.', '.', '.'],
            ['O', 'O', 'O', 'O', '.', '.'],
            ['O', 'O', 'O', 'O', 'O', '.'],
            ['.', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'O', 'O', '.'],
            ['O', 'O', 'O', 'O', '.', '.'],
            ['.', 'O', 'O', '.', '.', '.'],
            ['.', '.', '.', '.', '.', '.']]
    gridRotated = rotate90(grid)
    print2DGrid(gridRotated)
# Out:
# ..OO.OO..
# .OOOOOOO.
# .OOOOOOO.
# ..OOOOO..
# ...OOO...
# ....O....

# %% [markdown]
# ## <font style="color:black">Modifying Image Pixels</font>
# We can modify the intensity values of pixels in the same manner as described above.

# %%
cb_img_copy = cb_img.copy()
cb_img_copy[2,2] = 200
cb_img_copy[2,3] = 200
cb_img_copy[3,2] = 200
cb_img_copy[3,3] = 200

# Same as above
# cb_img_copy[2:3,2:3] = 200

plt.imshow(cb_img_copy, cmap='gray')
print(cb_img_copy)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 200 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
img_rec = cv2.imread("input/Sample.png", cv2.IMREAD_GRAYSCALE)
img_cir = cv2.imread("input/Sample.png", cv2.IMREAD_GRAYSCALE)

plt.figure(figsize=[20,5])
plt.subplot(121);plt.imshow(img_rec,cmap='gray')
plt.subplot(122);plt.imshow(img_cir,cmap='gray')
print(img_rec.shape)
# Out:
# (547, 558)

# %% [markdown]
# ### <font color="green">Bitwise Operator </font>

# %%
result = cv2.bitwise_and(img_rec, img_cir, mask = None)  #Bitwise AND Operator 
result = cv2.bitwise_or(img_rec, img_cir, mask = None)   #Bitwise OR Operator 
result = cv2.bitwise_xor(img_rec, img_cir, mask = None)  #Bitwise OR Operator 
plt.imshow(result,cmap='gray')

# %% [markdown]
# ## Application: Logo Manipulation
#
# In this section we will show you how to fill in the white lettering of the Coca-Cola logo below with a background image.

# %% [markdown]
# ### <font color="green">Read Foreground image</font>

# %%
img_bgr = cv2.imread("input/Sample.png")
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
print(img_rgb.shape)
logo_w = img_rgb.shape[0]
logo_h = img_rgb.shape[1]
# Out:
# (547, 558, 3)

# %% [markdown]
# ### <font color="green">Read Background image</font>

# %%
# Read in image of color cheackerboad background
img_background_bgr = cv2.imread("input/Sample.png")
img_background_rgb = cv2.cvtColor(img_background_bgr, cv2.COLOR_BGR2RGB)

# Set desired width (logo_w) and maintain image aspect ratio
aspect_ratio = logo_w / img_background_rgb.shape[1]
dim = (logo_w, int(img_background_rgb.shape[0] * aspect_ratio))

# Resize background image to sae size as logo image
img_background_rgb = cv2.resize(img_background_rgb, dim, interpolation=cv2.INTER_AREA)

plt.imshow(img_background_rgb) 
print(img_background_rgb.shape)
# Out:
# (536, 547, 3)

# %% [markdown]
# ### <font color="green">Create Mask for original Image</font>

# %%
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)

# Apply global thresholding to creat a binary mask of the logo
retval, img_mask = cv2.threshold(img_gray,127,255,cv2.THRESH_BINARY)

plt.imshow(img_mask,cmap="gray")
print(img_mask.shape)
# Out:
# (547, 558)

# %% [markdown]
# ### <font color="green">Invert the Mask </font>

# %%
# Create an inverse mask
img_mask_inv = cv2.bitwise_not(img_mask)
plt.imshow(img_mask_inv,cmap="gray")

# %% [markdown]
# ### <font color="green">Isolate foreground from image</font>

# %%
img_foreground = cv2.bitwise_and(img_rgb, img_rgb, mask=img_mask_inv)
plt.imshow(img_foreground)
