# %%
#!wget "https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip"

# %%
#!unzip -q "/content/kagglecatsanddogs_3367a.zip"

# %%
#!ls "PetImages/"

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pathlib 
import os
from tqdm import tqdm 

# Number of Dog images 
len(os.listdir("PetImages/Dog"))
# Out:
# 12501

# %%
# Number of Cat images 
len(os.listdir("PetImages/Cat"))
# Out:
# 12501

# %%
DataPath = pathlib.Path("PetImages")
all_paths = DataPath.glob("*/*.jpg")
all_paths
# Out:
# <generator object Path.glob at 0x00000268DE7C73C0>

# %%
all_paths = list(all_paths)
all_paths[:10]
# Out:
# [WindowsPath('PetImages/Cat/0.jpg'),
#  WindowsPath('PetImages/Cat/1.jpg'),
#  WindowsPath('PetImages/Cat/10.jpg'),
#  WindowsPath('PetImages/Cat/100.jpg'),
#  WindowsPath('PetImages/Cat/1000.jpg'),
#  WindowsPath('PetImages/Cat/10000.jpg'),
#  WindowsPath('PetImages/Cat/10001.jpg'),
#  WindowsPath('PetImages/Cat/10002.jpg'),
#  WindowsPath('PetImages/Cat/10003.jpg'),
#  WindowsPath('PetImages/Cat/10004.jpg')]

# %%
all_paths = list(map(lambda x : str(x) , all_paths))
all_paths[:10]
# Out:
# ['PetImages\\Cat\\0.jpg',
#  'PetImages\\Cat\\1.jpg',
#  'PetImages\\Cat\\10.jpg',
#  'PetImages\\Cat\\100.jpg',
#  'PetImages\\Cat\\1000.jpg',
#  'PetImages\\Cat\\10000.jpg',
#  'PetImages\\Cat\\10001.jpg',
#  'PetImages\\Cat\\10002.jpg',
#  'PetImages\\Cat\\10003.jpg',
#  'PetImages\\Cat\\10004.jpg']

# %%
from random import shuffle

shuffle(all_paths)
all_paths[:10]
# Out:
# ['PetImages\\Dog\\2585.jpg',
#  'PetImages\\Cat\\773.jpg',
#  'PetImages\\Dog\\3832.jpg',
#  'PetImages\\Dog\\10730.jpg',
#  'PetImages\\Cat\\10243.jpg',
#  'PetImages\\Dog\\1390.jpg',
#  'PetImages\\Dog\\4583.jpg',
#  'PetImages\\Dog\\8444.jpg',
#  'PetImages\\Cat\\3700.jpg',
#  'PetImages\\Cat\\7028.jpg']

# %%
def TestImageQuality(all_paths):
    new_all_paths = []
    for path in tqdm(all_paths):
        try :
            image = tf.io.read_file(path)
            image = tf.io.decode_jpeg(image , channels = 3)
        except :
            continue
        new_all_paths.append(path)
    return new_all_paths

all_paths = TestImageQuality(all_paths)
all_paths[:10]
# Out:
# 100%|██████████| 25000/25000 [00:45<00:00, 552.46it/s]
# ['PetImages\\Dog\\2585.jpg',
#  'PetImages\\Cat\\773.jpg',
#  'PetImages\\Dog\\3832.jpg',
#  'PetImages\\Dog\\10730.jpg',
#  'PetImages\\Cat\\10243.jpg',
#  'PetImages\\Dog\\1390.jpg',
#  'PetImages\\Dog\\4583.jpg',
#  'PetImages\\Dog\\8444.jpg',
#  'PetImages\\Cat\\3700.jpg',
#  'PetImages\\Cat\\7028.jpg']

# %%
# Getting their respective labels 
def get_label(image_path):
    return image_path.split("\\")[1]

all_labels = list(map(lambda x : get_label(x) , all_paths))
all_labels[:10]
# Out:
# ['Dog', 'Cat', 'Dog', 'Dog', 'Cat', 'Dog', 'Dog', 'Dog', 'Cat', 'Cat']

# %%
from sklearn.preprocessing import LabelEncoder 

Le = LabelEncoder()
all_labels = Le.fit_transform(all_labels)

all_labels[:10]
# Out:
# array([1, 0, 1, 1, 0, 1, 1, 1, 0, 0], dtype=int64)

# %%
from sklearn.model_selection import train_test_split 

Train_paths , Val_paths , Train_labels , Val_labels = train_test_split(all_paths , all_labels)

# %%
Train_paths[:10] , Train_labels[:10]
# Out:
# (['PetImages\\Dog\\2705.jpg',
#   'PetImages\\Cat\\5853.jpg',
#   'PetImages\\Dog\\4234.jpg',
#   'PetImages\\Cat\\6496.jpg',
#   'PetImages\\Dog\\2085.jpg',
#   'PetImages\\Cat\\1839.jpg',
#   'PetImages\\Cat\\9775.jpg',
#   'PetImages\\Cat\\2819.jpg',
#   'PetImages\\Dog\\1676.jpg',
#   'PetImages\\Cat\\11153.jpg'],
#  array([1, 0, 1, 0, 1, 0, 0, 0, 1, 0], dtype=int64))

# %%
# Function used to decode jpeg into Tensor
def load(image , label):
    image = tf.io.read_file(image)
    image = tf.io.decode_jpeg(image , channels = 3)
    return image , label

# %%
# Define IMAGE SIZE and BATCH SIZE 
IMG_SIZE = 224 
BATCH_SIZE = 128

# Basic Transformation
resize = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE)          
])

# Data Augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
    tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor = (-0.3, -0.2))
])

# %%
# Function used to Create a Tensorflow Data Object
AUTOTUNE = tf.data.experimental.AUTOTUNE
def get_dataset(paths , labels , train = True):
    image_paths = tf.convert_to_tensor(paths)
    labels = tf.convert_to_tensor(labels)

    image_dataset = tf.data.Dataset.from_tensor_slices(image_paths)
    label_dataset = tf.data.Dataset.from_tensor_slices(labels)

    dataset = tf.data.Dataset.zip((image_dataset , label_dataset))

    dataset = dataset.map(lambda image , label : load(image , label))
    dataset = dataset.map(lambda image, label: (resize(image), label) , num_parallel_calls=AUTOTUNE)
    dataset = dataset.shuffle(1000)
    dataset = dataset.batch(BATCH_SIZE)

    if train:
        dataset = dataset.map(lambda image, label: (data_augmentation(image), label) , num_parallel_calls=AUTOTUNE)
        dataset = dataset.repeat()
    return dataset

# %%
# Creating Train Dataset object and Verifying it
# %time train_dataset = get_dataset(Train_paths , Train_labels)

image , label = next(iter(train_dataset))
print(image.shape)
print(label.shape)
# Out:
# Wall time: 696 ms
# (128, 224, 224, 3)
# (128,)

# %%
# View a sample Training Image
print(Le.inverse_transform(label)[0])
plt.imshow((image[0].numpy()/255).reshape(224 , 224 , 3))
# Out:
# Dog

# %%
# %time val_dataset = get_dataset(Val_paths , Val_labels , train = False)

image , label = next(iter(val_dataset))
print(image.shape)
print(label.shape)
# Out:
# Wall time: 33 ms
# (128, 224, 224, 3)
# (128,)

# %%
# View a sample Training Image
print(Le.inverse_transform(label)[0])
plt.imshow((image[0].numpy()/255).reshape(224 , 224 , 3))
# Out:
# Dog

# %% [markdown]
# ## Keras Model

# %%
# Model part 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization , GlobalMaxPool2D

model = Sequential()

# Block 1 
model.add(Conv2D(input_shape=(224 , 224 , 3),  padding='same',filters=32, kernel_size=(7, 7)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# Block 2
model.add(Conv2D(filters=64,  padding='valid', kernel_size=(5, 5)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# Block 3 
model.add(Conv2D(filters=128, padding='valid', kernel_size=(3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.2))

# Block 4 
model.add(Conv2D(filters=256, padding='valid', kernel_size=(3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(filters=256 , kernel_size=(3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(GlobalMaxPool2D())

model.add(Dense(units=256))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(units=1))
model.add(Activation('sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 224, 224, 32)      4736
# _________________________________________________________________
# activation_7 (Activation)    (None, 224, 224, 32)      0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 224, 224, 32)      128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 112, 112, 32)      0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 108, 108, 64)      51264
# _________________________________________________________________
# activation_8 (Activation)    (None, 108, 108, 64)      0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 108, 108, 64)      256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# activation_9 (Activation)    (None, 52, 52, 128)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 52, 52, 128)       512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 24, 24, 256)       295168
# _________________________________________________________________
# activation_10 (Activation)   (None, 24, 24, 256)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 24, 24, 256)       1024
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 22, 22, 256)       590080
# _________________________________________________________________
# activation_11 (Activation)   (None, 22, 22, 256)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 22, 22, 256)       1024
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 11, 11, 256)       0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 11, 11, 256)       0
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_12 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# _________________________________________________________________
# activation_13 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 1,084,097
# Trainable params: 1,082,625
# Non-trainable params: 1,472
# _________________________________________________________________
# None

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# Train the model
history = model.fit(
    train_dataset,
    steps_per_epoch=len(Train_paths)//BATCH_SIZE,
    epochs=10,
    validation_data=val_dataset,
    validation_steps = len(Val_paths)//BATCH_SIZE,
)
# Out:
# Epoch 1/10
# 145/145 [==============================] - 3533s 24s/step - loss: 0.8624 - accuracy: 0.5896 - val_loss: 0.6731 - val_accuracy: 0.5537
# Epoch 2/10
#  10/145 [=>............................] - ETA: 55:15 - loss: 0.6044 - accuracy: 0.6802

# %%
# Evaluating the loaded model
loss, acc = model.evaluate(val_dataset)

print(" Testing Acc : " , acc)
print(" Testing Loss : " , loss)

# %% [markdown]
# ## keras Inception

# %%
# Building ResNet50 model
from tensorflow.keras.applications import InceptionV3

backbone = InceptionV3(
    input_shape=(224, 224, 3),
    include_top=False
)

model = tf.keras.Sequential([
    backbone,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
print(model.summary())

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# Train the model
history = model.fit(
    train_dataset,
    steps_per_epoch=len(Train_paths)//BATCH_SIZE,
    epochs=10,
    validation_data=val_dataset,
    validation_steps = len(Val_paths)//BATCH_SIZE,
)

# %%
# Evaluating the loaded model
loss, acc = model.evaluate(val_dataset)

print(" Testing Acc : " , acc)
print(" Testing Loss : " , loss)

# %% [markdown]
# ## Karas ResNet50 model

# %%
# Building ResNet50 model
from tensorflow.keras.applications import ResNet50V2

backbone = ResNet50V2(
    input_shape=(224, 224, 3),
    include_top=False
)

model = tf.keras.Sequential([
    backbone,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
print(model.summary())

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# Train the model
history = model.fit(
    train_dataset,
    steps_per_epoch=len(Train_paths)//BATCH_SIZE,
    epochs=10,
    validation_data=val_dataset,
    validation_steps = len(Val_paths)//BATCH_SIZE,
)

# %%
# Evaluating the loaded model
loss, acc = model.evaluate(val_dataset)

print(" Testing Acc : " , acc)
print(" Testing Loss : " , loss)
