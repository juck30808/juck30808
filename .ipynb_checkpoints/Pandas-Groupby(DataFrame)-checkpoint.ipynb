# %% [markdown]
# ## GroupBy
# SQL語法中的Group by 是欄位內的資料若有不只一筆名稱相同的資料的話，就會把它們作為群組 (Group)。然後通過使用GROUP BY,可以搭配聚合函數 (aggregation function) AVG()、COUNT()、MAX()、MIN()、SUM() 等這些內建函數對資料起作用，每一個群組都會傳回一個資料列。若沒有使用 GROUP BY，聚合函數針對一個 SELECT 查詢，只會返回一個彙總值。
#
# groupby() function
# Pandas DataFrame groupby() function is used to group rows that have the same values. It's mostly used with aggregate functions (count, sum, min, max, mean) to get the statistics based on one or more column values. Pandas gropuby() function is very similar to the SQL group by statement.

# %%
#pd.DataFrame.groupby?

# %%
import numpy as np
import pandas as pd
data = pd.DataFrame({'Name':['A','A','A','B','B','B'],
                    'F1':[11,12,13,14,15,16],
                    'F2':[21,22,23,24,25,26],})
data
# Out:
#   Name  F1  F2
# 0    A  11  21
# 1    A  12  22
# 2    A  13  23
# 3    B  14  24
# 4    B  15  25
# 5    B  16  26

# %%
data.groupby('Name')['F1'].aggregate([np.sum])  #aggregate #apply #filter #transform .....
# Out:
#       sum
# Name
# A      36
# B      45

# %%
marks = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a', 'a'],
                      'key2' : ['one', 'two', 'one', 'two', 'one', 'one'],
                     'data1' : np.arange(10, 16),
                     'data2' : np.arange(16, 22)})
marks
# Out:
#   key1 key2  data1  data2
# 0    a  one     10     16
# 1    a  two     11     17
# 2    b  one     12     18
# 3    b  two     13     19
# 4    a  one     14     20
# 5    a  one     15     21

# %%
grouped = marks['data1'].groupby(by=marks['key1']).mean()
grouped
# Out:
# key1
# a    12.5
# b    12.5
# Name: data1, dtype: float64

# %%
print('a mean:', (10 + 11 + 14 + 15) / 4)
print('b mean:', (12 + 13)/2)
# Out:
# a mean: 12.5
# b mean: 12.5

# %%
group_tk = marks['data1'].groupby(by=[marks['key1'], marks['key2']])
print(marks)
print()
print('result:', group_tk.mean())
# Out:
#   key1 key2  data1  data2
# 0    a  one     10     16
# 1    a  two     11     17
# 2    b  one     12     18
# 3    b  two     13     19
# 4    a  one     14     20
# 5    a  one     15     21
#
# result: key1  key2
# a     one     13.0
#       two     11.0
# b     one     12.0
#       two     13.0
# Name: data1, dtype: float64

# %%
group_tk.mean().unstack()
# Out:
# key2   one   two
# key1
# a     13.0  11.0
# b     12.0  13.0

# %%
feedb = np.array(['good', 'avg', 'good', 'avg', 'good', 'avg'])
actual = np.array(['good', 'med', 'good', 'med', 'good', 'med'])
mean1 = marks['data1'].groupby(by=[feedb, actual]).mean()
mean1
# Out:
# avg   med     13.0
# good  good    12.0
# Name: data1, dtype: float64

# %%
mean_df = marks.groupby(by=['key1']).mean()
mean_df
# Out:
#       data1  data2
# key1
# a      12.5   18.5
# b      12.5   18.5

# %%
print(marks)
print()
marks.groupby(by=['key1', 'key2']).size()
# Out:
#   key1 key2  data1  data2
# 0    a  one     10     16
# 1    a  two     11     17
# 2    b  one     12     18
# 3    b  two     13     19
# 4    a  one     14     20
# 5    a  one     15     21
# key1  key2
# a     one     3
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %% [markdown]
# ## Iterate

# %%
for key_name, group_name in marks.groupby(by='key1'):
    print(key_name)
    print(group_name)
    print(type(key_name))
    print(type(group_name))
# Out:
# a
#   key1 key2  data1  data2
# 0    a  one     10     16
# 1    a  two     11     17
# 4    a  one     14     20
# 5    a  one     15     21
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# b
#   key1 key2  data1  data2
# 2    b  one     12     18
# 3    b  two     13     19
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>

# %%
grouped = marks.groupby(marks.dtypes, axis=1)
for datatype, group in grouped:
    print(datatype)
    print(group)
# Out:
# int64
#    data1  data2
# 0     10     16
# 1     11     17
# 2     12     18
# 3     13     19
# 4     14     20
# 5     15     21
# object
#   key1 key2
# 0    a  one
# 1    a  two
# 2    b  one
# 3    b  two
# 4    a  one
# 5    a  one

# %%
print(marks['data1'])
print(marks[['data1', 'data2']])
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# Name: data1, dtype: int64
#    data1  data2
# 0     10     16
# 1     11     17
# 2     12     18
# 3     13     19
# 4     14     20
# 5     15     21

# %%
marks['data1'].groupby(by=marks['key1']).sum()
# Out:
# key1
# a    50
# b    25
# Name: data1, dtype: int64

# %%
marks[['data1', 'data2']].groupby(by=marks['key2']).sum()
# Out:
#       data1  data2
# key2
# one      51     75
# two      24     36

# %% [markdown]
# ## Project - vgsales

# %%
import numpy as np
import pandas as pd
data = pd.read_excel("input/vgsales.xlsx")
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0   1.0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1   2.0         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2   3.0            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3   4.0         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4   5.0  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.groupby('Genre').size()                 #預設會忽略Nan
#data.groupby('Genre',dropna=False).size()   #加上 dropna=False 來強制不忽略
#data.groupby(['Year','Platform']).size()
# Out:
# Genre
# Action          3316
# Adventure       1286
# Fighting         848
# Misc            1739
# Platform         886
# Puzzle           582
# Racing          1249
# Role-Playing    1488
# Shooter         1310
# Simulation       867
# Sports          2346
# Strategy         681
# dtype: int64

# %%
#data.groupby(['Year','Platform']).sum().head()
data.groupby(['Year','Platform']).sum().reset_index() #表頭索引
# Out:
#        Year Platform      Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0    1980.0   2600.0   29826.0     10.59      0.67      0.00         0.12
# 1    1981.0   2600.0  190488.0     33.40      1.96      0.00         0.32
# 2    1982.0   2600.0  149186.0     26.92      1.65      0.00         0.31
# 3    1983.0   2600.0   49355.0      5.44      0.34      0.00         0.06
# 4    1983.0      NES    7404.0      2.32      0.46      8.10         0.08
# ..      ...      ...       ...       ...       ...       ...          ...
# 236  2016.0     X360   93657.0      0.36      0.40      0.00         0.07
# 237  2016.0     XOne  584548.0      6.69      4.63      0.01         1.05
# 238  2017.0      PS4   14393.0      0.00      0.00      0.03         0.00
# 239  2017.0      PSV   32685.0      0.00      0.00      0.02         0.00
# 240  2020.0       DS    5959.0      0.27      0.00      0.00         0.02
#
#      Global_Sales
# 0           11.38
# 1           35.77
# 2           28.86
# 3            5.83
# 4           10.96
# ..            ...
# 236          0.83
# 237         12.37
# 238          0.03
# 239          0.02
# 240          0.29
#
# [241 rows x 8 columns]

# %%
lists = ['NA_Sales','EU_Sales','JP_Sales','Other_Sales']   #獨立設立 metrics
data.groupby(['Year','Platform'])[lists].sum().head()
# Out:
#                  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Year   Platform
# 1980.0 2600.0       10.59      0.67       0.0         0.12
# 1981.0 2600.0       33.40      1.96       0.0         0.32
# 1982.0 2600.0       26.92      1.65       0.0         0.31
# 1983.0 2600.0        5.44      0.34       0.0         0.06
#        NES           2.32      0.46       8.1         0.08

# %%
data.groupby('Platform').get_group('Wii')
#data[data['Platform'] == 'Wii']
# Out:
#           Rank                                               Name Platform  \
# 0          1.0                                         Wii Sports      Wii
# 2          3.0                                     Mario Kart Wii      Wii
# 3          4.0                                  Wii Sports Resort      Wii
# 7          8.0                                           Wii Play      Wii
# 8          9.0                          New Super Mario Bros. Wii      Wii
# ...        ...                                                ...      ...
# 16517  16520.0                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555.0           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576.0                                Mini Desktop Racing      Wii
# 16574  16577.0  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584.0                                          Fit & Fun      Wii
#
#          Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# 0      2006.0    Sports                      Nintendo     41.49     29.02
# 2      2008.0    Racing                      Nintendo     15.85     12.88
# 3      2009.0    Sports                      Nintendo     15.75     11.01
# 7      2006.0      Misc                      Nintendo     14.03      9.20
# 8      2009.0  Platform                      Nintendo     14.59      7.06
# ...       ...       ...                           ...       ...       ...
# 16517  2007.0    Action  Konami Digital Entertainment      0.00      0.01
# 16552  2007.0  Fighting         Marvelous Interactive      0.00      0.00
# 16573  2007.0    Racing                Popcorn Arcade      0.01      0.00
# 16574  2008.0    Racing                   Takara Tomy      0.00      0.00
# 16581  2011.0    Sports                       Unknown      0.00      0.01
#
#        JP_Sales  Other_Sales  Global_Sales
# 0          3.77         8.46         82.74
# 2          3.79         3.31         35.82
# 3          3.28         2.96         33.00
# 7          2.93         2.85         29.02
# 8          4.70         2.26         28.62
# ...         ...          ...           ...
# 16517      0.00         0.00          0.01
# 16552      0.01         0.00          0.01
# 16573      0.00         0.00          0.01
# 16574      0.01         0.00          0.01
# 16581      0.00         0.00          0.01
#
# [1325 rows x 11 columns]

# %% [markdown]
# ## iloc

# %%
data.groupby('Year').size().head()   #1980年有 9個資料
# Out:
# Year
# 1980.0     9
# 1981.0    46
# 1982.0    36
# 1983.0    17
# 1984.0    14
# dtype: int64

# %%
x = data.groupby('Year').groups  # 1980: [258, 544, 1766, 1969, 2669, 4025, 5366, 6317, 6896]
x
# Out:
# {1980.0: [258, 544, 1766, 1969, 2669, 4025, 5366, 6317, 6896], 1981.0: [239, 734, 766, 864, 1106, 1153, 1306, 1429, 1556, 1848, 1965, 2143, 2232, 2516, 2596, 2664, 2806, 2940, 3044, 3403, 3408, 4015, 4139, 4346, 4402, 4517, 4784, 4908, 4967, 5127, 5246, 5389, 5400, 5564, 5800, 6021, 6537, 6866, 6940, 7148, 7150, 7184, 7371, 7904, 8459, 9495], 1982.0: [89, 1115, 1163, 1705, 1817, 1851, 1905, 2406, 2629, 2660, 2843, 3079, 3215, 3248, 3266, 3447, 3643, 3716, 3748, 3966, 4013, 4016, 4801, 4894, 5064, 5381, 5395, 5658, 5773, 6145, 6265, 6728, 7149, 8458, 8758, 9106], 1983.0: [421, 700, 763, 1508, 1809, 1839, 1861, 2652, 2672, 3953, 4096, 4267, 4780, 5382, 5559, 6007, 8457], 1984.0: [9, 277, 298, 754, 938, 1233, 1234, 1324, 1560, 1638, 1857, 2513, 2955, 6296], 1985.0: [1, 374, 868, 1260, 1490, 1973, 2020, 2059, 2259, 3907, 4337, 4727, 14335, 15867], 1986.0: [127, 452, 548, 573, 611, 737, 867, 992, 1117, 1262, 1427, 1623, 1675, 1676, 1772, 1791, 1971, 2158, 3532, 5082, 5956], 1987.0: [251, 465, 602, 647, 759, 1361, 1588, 2234, 2466, 2547, 3118, 4194, 4393, 6583, 11716, 11749], 1988.0: [22, 96, 155, 312, 638, 764, 1187, 1246, 1350, 1587, 1708, 2704, 3940, 6939, 14507], 1989.0: [5, 21, 170, 276, 775, 852, 880, 1089, 1142, 1542, 1678, 1858, 1859, 2439, 4147, 8757, 12636], 1990.0: [18, 215, 391, 446, 509, 588, 722, 1190, 1278, 1385, 1695, 1726, 1770, 1792, 5493, 5862], 1991.0: [231, 254, 855, 983, 987, 1008, 1108, 1394, 1716, 1794, 2061, 2233, 2727, 2798, 3204, 4097, 4451, 4583, 4944, 4981, 5033, 5517, 5541, 5651, 6053, 6155, 6161, 6164, 6165, 6623, 7094, 7688, 8037, 8085, 8575, 8834, 9958, 11330, 11980, 12670, 13018], 1992.0: [50, 76, 136, 143, 191, 285, 318, 531, 545, 564, 629, 743, 765, 827, 1076, 1099, 1608, 1657, 1827, 2142, 2610, 2633, 3481, 3544, 4240, 4952, 6088, 6198, 6226, 7065, 7185, 8529, 8617, 9442, 9561, 9796, 11985, 12062, 12526, 12700, 13525, 14599, 16073], 1993.0: [57, 472, 849, 887, 948, 1009, 1010, 1054, 1261, 1325, 1674, 1729, 1751, 1777, 2033, 2111, 2592, 2651, 2795, 2956, 3236, 3591, 3780, 3782, 3844, 4041, 4242, 4363, 5174, 5204, 5291, 5666, 5799, 6306, 7301, 7769, 7910, 7929, 8067, 8424, 8908, 9196, 9461, 9929, 10259, 10331, 11127, 11951, 12065, 12084, 12109, 12231, 12289, 12652, 12927, 12945, 12956, 13147, 13311, 16105], 1994.0: [71, 184, 305, 353, 389, 455, 521, 653, 806, 874, 952, 968, 991, 1221, 1360, 1372, 1393, 1458, 1567, 1841, 1923, 2289, 2379, 2534, 2537, 2550, 2601, 2634, 2906, 2938, 3435, 3505, 3609, 3636, 3781, 3812, 4293, 4388, 4522, 4767, 4815, 4960, 5014, 5101, 5115, 5142, 5147, 5166, 5173, 5217, 5252, 5494, 5533, 5672, 5817, 5868, 5881, 6002, 6117, 6229, 6308, 6368, 6473, 6631, 6641, 6681, 7045, 7535, 7553, 7647, 7947, 7962, 8100, 8124, 8639, 9004, 9014, 9717, 9844, 9899, 9919, 9985, 10036, 10089, 10309, 10354, 10672, 11087, 11281, 11439, 11541, 11640, 11670, 11738, 11751, 11835, 11882, 12078, 12263, 12351, ...], 1995.0: [187, 267, 282, 317, 415, 422, 426, 462, 670, 688, 888, 950, 1188, 1521, 1554, 1753, 1771, 1840, 1934, 2046, 2068, 2302, 2353, 2376, 2446, 2694, 2887, 2890, 3237, 3271, 3352, 3372, 3443, 3520, 3678, 3985, 4074, 4160, 4165, 4205, 4303, 4322, 4373, 4379, 4634, 4670, 4699, 4765, 4821, 4855, 4874, 5009, 5048, 5116, 5245, 5289, 5372, 5393, 5569, 5632, 5640, 5645, 5707, 5714, 5745, 5828, 5842, 5854, 5908, 5920, 5972, 6115, 6139, 6192, 6196, 6260, 6363, 6399, 6413, 6714, 6784, 6803, 6922, 7021, 7102, 7294, 7385, 7464, 7498, 7512, 7681, 7837, 7920, 7952, 8235, 8352, 8392, 8460, 8514, 8564, ...], 1996.0: [4, 46, 63, 116, 152, 194, 201, 229, 293, 325, 372, 484, 511, 532, 574, 631, 646, 672, 762, 900, 946, 1020, 1159, 1161, 1216, 1232, 1323, 1336, 1382, 1428, 1495, 1499, 1589, 1645, 1718, 1732, 1735, 1819, 1972, 1974, 1996, 2022, 2071, 2157, 2181, 2200, 2256, 2269, 2296, 2354, 2366, 2389, 2435, 2502, 2514, 2661, 2687, 2832, 3015, 3240, 3274, 3275, 3485, 3640, 3647, 3665, 3684, 3759, 3777, 3819, 3885, 3915, 4002, 4007, 4148, 4214, 4262, 4316, 4399, 4431, 4449, 4450, 4481, 4507, 4540, 4711, 471 ...

# %%
data.iloc[x[1980.0]]
# Out:
#         Rank             Name Platform    Year     Genre   Publisher  \
# 258    259.0        Asteroids   2600.0  1980.0   Shooter       Atari
# 544    545.0  Missile Command   2600.0  1980.0   Shooter       Atari
# 1766  1768.0          Kaboom!   2600.0  1980.0      Misc  Activision
# 1969  1971.0         Defender   2600.0  1980.0      Misc       Atari
# 2669  2671.0           Boxing   2600.0  1980.0  Fighting  Activision
# 4025  4027.0       Ice Hockey   2600.0  1980.0    Sports  Activision
# 5366  5368.0          Freeway   2600.0  1980.0    Action  Activision
# 6317  6319.0           Bridge   2600.0  1980.0      Misc  Activision
# 6896  6898.0         Checkers   2600.0  1980.0      Misc       Atari
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 258       4.00      0.26       0.0         0.05          4.31
# 544       2.56      0.17       0.0         0.03          2.76
# 1766      1.07      0.07       0.0         0.01          1.15
# 1969      0.99      0.05       0.0         0.01          1.05
# 2669      0.72      0.04       0.0         0.01          0.77
# 4025      0.46      0.03       0.0         0.01          0.49
# 5366      0.32      0.02       0.0         0.00          0.34
# 6317      0.25      0.02       0.0         0.00          0.27
# 6896      0.22      0.01       0.0         0.00          0.24

# %% [markdown]
# ## Aggregation : agg()
#
# 聚合函數 (aggregation function) 也就是 AVG()、COUNT()、MAX()、MIN()、SUM() 等這些內建函數對資料起作用 Aggregating functions are the ones that reduce the dimension of the returned objects.Some common aggregating functions are tabulated below:
# <table class="colwidths-given table">
# <colgroup>
# <col style="width: 20%">
# <col style="width: 80%">
# </colgroup>
# <thead>
# <tr class="row-odd"><th class="head"><p>Function</p></th>
# <th class="head"><p>Description</p></th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">mean()</span></code></p></td>
# <td><p>Compute mean of groups</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">sum()</span></code></p></td>
# <td><p>Compute sum of group values</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">size()</span></code></p></td>
# <td><p>Compute group sizes</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">count()</span></code></p></td>
# <td><p>Compute count of group</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">std()</span></code></p></td>
# <td><p>Standard deviation of groups</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">var()</span></code></p></td>
# <td><p>Compute variance of groups</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">sem()</span></code></p></td>
# <td><p>Standard error of the mean of groups</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">describe()</span></code></p></td>
# <td><p>Generates descriptive statistics</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">first()</span></code></p></td>
# <td><p>Compute first of group values</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">last()</span></code></p></td>
# <td><p>Compute last of group values</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">nth()</span></code></p></td>
# <td><p>Take nth value, or a subset if n is a list</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">min()</span></code></p></td>
# <td><p>Compute min of group values</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="xref py py-meth docutils literal notranslate"><span class="pre">max()</span></code></p></td>
# <td><p>Compute max of group values</p></td>
# </tr>
# </tbody>
# </table>

# %%
data.groupby('Platform').sum().head()
# Out:
#                 Rank       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Platform
# 2600.0      585665.0   229928.0     90.60      5.47      0.00         0.91
# 3DO          43118.0     5984.0      0.00      0.00      0.10         0.00
# 3DS        4662644.0  1006531.0     78.87     58.52     97.35        12.63
# DC          456114.0   103997.0      5.43      1.69      8.56         0.27
# DS        20845831.0  4283493.0    390.71    194.65    175.57        60.53
#
#           Global_Sales
# Platform
# 2600.0           97.08
# 3DO               0.10
# 3DS             247.46
# DC               15.97
# DS              822.49

# %%
## 寫法1
data.groupby('Platform')[['NA_Sales','Global_Sales']].aggregate([np.sum,
                                                                 np.max,
                                                                 np.min]).head()
# Out:
#          NA_Sales              Global_Sales
#               sum   amax  amin          sum   amax  amin
# Platform
# 2600.0      90.60   7.28  0.07        97.08   7.81  0.07
# 3DO          0.00   0.00  0.00         0.10   0.06  0.02
# 3DS         78.87   5.17  0.00       247.46  14.35  0.01
# DC           5.43   1.26  0.00        15.97   2.42  0.02
# DS         390.71  11.38  0.00       822.49  30.01  0.01

# %%
## 寫法2
def sum1(x): return np.sum(x)
def max1(x): return np.max(x)   
def min1(x): return np.min(x)   
data.groupby('Platform')[['NA_Sales','Global_Sales']].aggregate([sum1,
                                                                 max1,
                                                                 min1]).head()
#return np.max(x) - np.min(x)  #return np.median(x) - np.mean(x)
# Out:
#          NA_Sales              Global_Sales
#              sum1   max1  min1         sum1   max1  min1
# Platform
# 2600.0      90.60   7.28  0.07        97.08   7.81  0.07
# 3DO          0.00   0.00  0.00         0.10   0.06  0.02
# 3DS         78.87   5.17  0.00       247.46  14.35  0.01
# DC           5.43   1.26  0.00        15.97   2.42  0.02
# DS         390.71  11.38  0.00       822.49  30.01  0.01

# %%
# data.groupby('Platform')[['NA_Sales','Global_Sales']].aggregate(
#     [lambda x: x.max() - x.min(),
#     lambda x: x.median() - x.mean()]
# )

# %% [markdown]
# ## Transform ＆ Apply & Filter

# %%
data.groupby('Platform')['Global_Sales'].transform(sum)
# Out:
# 0         926.71
# 1         251.07
# 2         926.71
# 3         926.71
# 4         255.45
#           ...
# 16593     318.50
# 16594     199.36
# 16595    1255.64
# 16596     822.49
# 16597     318.50
# Name: Global_Sales, Length: 16598, dtype: float64

# %%
data2 = data.copy()

# %%
#方法 1
global_sum = data2.groupby('Platform')['Global_Sales'].transform(np.sum)  # cal Global_Sales.sum
data2['銷售佔比'] = data2['Global_Sales'] / global_sum 
data2.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0   1.0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1   2.0         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2   3.0            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3   4.0         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4   5.0  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales      銷售佔比
# 0     41.49     29.02      3.77         8.46         82.74  0.089284
# 1     29.08      3.58      6.81         0.77         40.24  0.160274
# 2     15.85     12.88      3.79         3.31         35.82  0.038653
# 3     15.75     11.01      3.28         2.96         33.00  0.035610
# 4     11.27      8.89     10.22         1.00         31.37  0.122803

# %%
data2 = data.copy()

# %%
#方法 2 使用apply來達成等同上面的功能
def rate(x):
    x['銷售佔比'] = x['Global_Sales'] / x['Global_Sales'].sum()
    return x
data2.groupby('Platform').apply(rate).head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0   1.0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1   2.0         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2   3.0            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3   4.0         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4   5.0  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales      銷售佔比
# 0     41.49     29.02      3.77         8.46         82.74  0.089284
# 1     29.08      3.58      6.81         0.77         40.24  0.160274
# 2     15.85     12.88      3.79         3.31         35.82  0.038653
# 3     15.75     11.01      3.28         2.96         33.00  0.035610
# 4     11.27      8.89     10.22         1.00         31.37  0.122803

# %%
# filter : 列出該平台總銷售額大於 1000 百萬的遊戲
index = data.groupby('Platform')['Global_Sales'].transform(sum) > 1000
data[index]
# Out:
#           Rank                                              Name Platform  \
# 17        18.0                     Grand Theft Auto: San Andreas      PS2
# 24        25.0                       Grand Theft Auto: Vice City      PS2
# 28        29.0                            Gran Turismo 3: A-Spec      PS2
# 38        39.0                              Grand Theft Auto III      PS2
# 47        48.0                                    Gran Turismo 4      PS2
# ...        ...                                               ...      ...
# 16559  16562.0      Sugar + Spice! Anoko no Suteki na Nanimokamo      PS2
# 16561  16564.0                                    Kanokon: Esuii      PS2
# 16572  16575.0                  Scarlett: Nichijou no Kyoukaisen      PS2
# 16580  16583.0                                         Real Rode      PS2
# 16595  16598.0  SCORE International Baja 1000: The Official Game      PS2
#
#          Year      Genre                    Publisher  NA_Sales  EU_Sales  \
# 17     2004.0     Action         Take-Two Interactive      9.43      0.40
# 24     2002.0     Action         Take-Two Interactive      8.41      5.49
# 28     2001.0     Racing  Sony Computer Entertainment      6.85      5.09
# 38     2001.0     Action         Take-Two Interactive      6.99      4.51
# 47     2004.0     Racing  Sony Computer Entertainment      3.01      0.01
# ...       ...        ...                          ...       ...       ...
# 16559  2008.0  Adventure                    Alchemist      0.00      0.00
# 16561  2008.0  Adventure                          5pb      0.00      0.00
# 16572  2008.0  Adventure              Kadokawa Shoten      0.00      0.00
# 16580  2008.0  Adventure              Kadokawa Shoten      0.00      0.00
# 16595  2008.0     Racing                   Activision      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 17         0.41        10.57         20.81
# 24         0.47         1.78         16.15
# 28         1.87         1.16         14.98
# 38         0.30         1.30         13.10
# 47         1.10         7.53         11.66
# ...         ...          ...           ...
# 16559      0.01         0.00          0.01
# 16561      0.01         0.00          0.01
# 16572      0.01         0.00          0.01
# 16580      0.01         0.00          0.01
# 16595      0.00         0.00          0.01
#
# [2161 rows x 11 columns]

# %% [markdown]
# ## Project - employee

# %%
import pandas as pd
data = pd.read_csv('input/employee.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
# grouping the data by department
data.groupby(['Department']).agg({'Age':'mean',
                                  'DailyRate':'max'})
# Out:
#                               Age  DailyRate
# Department
# Human Resources         37.809524       1444
# Research & Development  37.042664       1496
# Sales                   36.542601       1499

# %%
data[['Age','DailyRate','Department']].groupby([data['Department'],
                                                data['EducationField']]).agg(['mean',
                                                                              'median',
                                                                              'min',
                                                                              'max',
                                                                              'std',
                                                                              'var'])
# Out:
#                                                Age                            \
#                                               mean median min max        std
# Department             EducationField
# Human Resources        Human Resources   37.037037   36.0  24  59   8.604478
#                        Life Sciences     39.375000   41.0  26  56   9.076527
#                        Medical           39.846154   42.0  24  59  11.312575
#                        Other             34.666667   37.0  29  38   4.932883
#                        Technical Degree  32.500000   34.5  19  42   9.678154
# Research & Development Life Sciences     36.997727   36.0  18  60   8.937775
#                        Medical           37.242424   36.0  18  60   9.471776
#                        Other             36.187500   35.5  21  53   7.869723
#                        Technical Degree  37.063830   35.5  20  58  10.039501
# Sales                  Life Sciences     37.186667   36.0  20  59   8.683384
#                        Marketing         37.924528   36.0  18  60   9.153783
#                        Medical           34.727273   34.0  18  58   8.993902
#                        Other             32.000000   31.0  19  50   8.237545
#                        Technical Degree  33.941176   33.0  19  59   8.960997
#
#                                                        DailyRate               \
#                                                 var         mean  median  min
# Department             EducationField
# Human Resources        Human Resources    74.037037   675.259259   600.0  106
#                        Life Sciences      82.383333   753.062500   709.0  176
#                        Medical           127.974359   875.615385   898.0  179
#                        Other              24.333333  1005.000000  1239.0  332
#                        Technical Degree   93.666667   667.000000   536.0  489
# Research & Development Life Sciences      79.883822   789.195455   786.5  102
#                        Medical            89.714549   825.730028   878.0  109
#                        Other              61.932540   763.359375   669.0  116
#                        Technical Degree  100.791581   846.202128   945.5  128
# Sales                  Life Sciences      75.401163   854.580000   880.0  111
#                        Marketing          83.791736   727.836478   685.0  118
#                        Medical            80.890282   802.909091   750.0  120
#                        Other              67.857143   893.600000   959.0  141
#                        Technical Degree   80.299465   851.470588   924.5  107
#
#
#                                           max         std            var
# Department             EducationField
# Human Resources        Human Resources   1420  436.471657  190507.507123
#                        Life Sciences     1383  448.447465  201105.129167
#                        Medical           1398  382.294289  146148.923077
#                        Other             1444  591.779520  350203.000000
#                        Technical Degree  1107  294.241397   86578.000000
# Research & Development Life Sciences     1490  402.796260  162244.827314
#                        Medical           1495  398.918343  159135.844041
#                        Other             1474  398.990089  159193.091022
#                        Technical Degree  1496  416.608570  173562.700641
# Sales                  Life Sciences     1498  395.281096  156247.144564
#                        Marketing         1499  394.040573  155267.973091
#                        Medical           1476  384.866080  148121.899687
#                        Other             1474  468.130446  219146.114286
#                        Technical Degree  1496  458.406941  210136.923351

# %%
#pd.set_option('max_rows',1470)

def above_thousand(x):
    color = 'red' if x>1000 else 'green'
    return 'color: %s' % color

data[['DailyRate']].head().style.applymap(above_thousand)
# Out:
# <style type="text/css">
# #T_a8270_row0_col0, #T_a8270_row2_col0, #T_a8270_row3_col0 {
#   color: red;
# }
# #T_a8270_row1_col0, #T_a8270_row4_col0 {
#   color: green;
# }
# </style>
# <table id="T_a8270_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >DailyRate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8270_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8270_row0_col0" class="data row0 col0" >1102</td>
#     </tr>
#     <tr>
#       <th id="T_a8270_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8270_row1_col0" class="data row1 col0" >279</td>
#     </tr>
#     <tr>
#       <th id="T_a8270_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8270_row2_col0" class="data row2 col0" >1373</td>
#     </tr>
#     <tr>
#       <th id="T_a8270_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8270_row3_col0" class="data row3 col0" >1392</td>
#     </tr>
#     <tr>
#       <th id="T_a8270_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8270_row4_col0" class="data row4 col0" >591</td>
#     </tr>
#   </tbody>
# </table>

# %%
dt1 = data.groupby(['Department','EducationField'])[['Age','DailyRate','MonthlyIncome']].agg('mean')
dt1
# Out:
#                                                Age    DailyRate  MonthlyIncome
# Department             EducationField
# Human Resources        Human Resources   37.037037   675.259259    7241.148148
#                        Life Sciences     39.375000   753.062500    6914.062500
#                        Medical           39.846154   875.615385    6594.076923
#                        Other             34.666667  1005.000000    5016.666667
#                        Technical Degree  32.500000   667.000000    3081.250000
# Research & Development Life Sciences     36.997727   789.195455    6179.984091
#                        Medical           37.242424   825.730028    6539.223140
#                        Other             36.187500   763.359375    6278.687500
#                        Technical Degree  37.063830   846.202128    5760.819149
# Sales                  Life Sciences     37.186667   854.580000    7246.233333
#                        Marketing         37.924528   727.836478    7348.584906
#                        Medical           34.727273   802.909091    6377.227273
#                        Other             32.000000   893.600000    5398.733333
#                        Technical Degree  33.941176   851.470588    6066.294118

# %%
dt1.style.highlight_max(color = 'red').highlight_min(color='lightgreen')
# Out:
# <style type="text/css">
# #T_b7d39_row2_col0, #T_b7d39_row3_col1, #T_b7d39_row10_col2 {
#   background-color: red;
# }
# #T_b7d39_row4_col1, #T_b7d39_row4_col2, #T_b7d39_row12_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b7d39_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age</th>
#       <th class="col_heading level0 col1" >DailyRate</th>
#       <th class="col_heading level0 col2" >MonthlyIncome</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="index_name level1" >EducationField</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7d39_level0_row0" class="row_heading level0 row0" rowspan="5">Human Resources</th>
#       <th id="T_b7d39_level1_row0" class="row_heading level1 row0" >Human Resources</th>
#       <td id="T_b7d39_row0_col0" class="data row0 col0" >37.037037</td>
#       <td id="T_b7d39_row0_col1" class="data row0 col1" >675.259259</td>
#       <td id="T_b7d39_row0_col2" class="data row0 col2" >7241.148148</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row1" class="row_heading level1 row1" >Life Sciences</th>
#       <td id="T_b7d39_row1_col0" class="data row1 col0" >39.375000</td>
#       <td id="T_b7d39_row1_col1" class="data row1 col1" >753.062500</td>
#       <td id="T_b7d39_row1_col2" class="data row1 col2" >6914.062500</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row2" class="row_heading level1 row2" >Medical</th>
#       <td id="T_b7d39_row2_col0" class="data row2 col0" >39.846154</td>
#       <td id="T_b7d39_row2_col1" class="data row2 col1" >875.615385</td>
#       <td id="T_b7d39_row2_col2" class="data row2 col2" >6594.076923</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row3" class="row_heading level1 row3" >Other</th>
#       <td id="T_b7d39_row3_col0" class="data row3 col0" >34.666667</td>
#       <td id="T_b7d39_row3_col1" class="data row3 col1" >1005.000000</td>
#       <td id="T_b7d39_row3_col2" class="data row3 col2" >5016.666667</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row4" class="row_heading level1 row4" >Technical Degree</th>
#       <td id="T_b7d39_row4_col0" class="data row4 col0" >32.500000</td>
#       <td id="T_b7d39_row4_col1" class="data row4 col1" >667.000000</td>
#       <td id="T_b7d39_row4_col2" class="data row4 col2" >3081.250000</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level0_row5" class="row_heading level0 row5" rowspan="4">Research & Development</th>
#       <th id="T_b7d39_level1_row5" class="row_heading level1 row5" >Life Sciences</th>
#       <td id="T_b7d39_row5_col0" class="data row5 col0" >36.997727</td>
#       <td id="T_b7d39_row5_col1" class="data row5 col1" >789.195455</td>
#       <td id="T_b7d39_row5_col2" class="data row5 col2" >6179.984091</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row6" class="row_heading level1 row6" >Medical</th>
#       <td id="T_b7d39_row6_col0" class="data row6 col0" >37.242424</td>
#       <td id="T_b7d39_row6_col1" class="data row6 col1" >825.730028</td>
#       <td id="T_b7d39_row6_col2" class="data row6 col2" >6539.223140</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row7" class="row_heading level1 row7" >Other</th>
#       <td id="T_b7d39_row7_col0" class="data row7 col0" >36.187500</td>
#       <td id="T_b7d39_row7_col1" class="data row7 col1" >763.359375</td>
#       <td id="T_b7d39_row7_col2" class="data row7 col2" >6278.687500</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row8" class="row_heading level1 row8" >Technical Degree</th>
#       <td id="T_b7d39_row8_col0" class="data row8 col0" >37.063830</td>
#       <td id="T_b7d39_row8_col1" class="data row8 col1" >846.202128</td>
#       <td id="T_b7d39_row8_col2" class="data row8 col2" >5760.819149</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level0_row9" class="row_heading level0 row9" rowspan="5">Sales</th>
#       <th id="T_b7d39_level1_row9" class="row_heading level1 row9" >Life Sciences</th>
#       <td id="T_b7d39_row9_col0" class="data row9 col0" >37.186667</td>
#       <td id="T_b7d39_row9_col1" class="data row9 col1" >854.580000</td>
#       <td id="T_b7d39_row9_col2" class="data row9 col2" >7246.233333</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row10" class="row_heading level1 row10" >Marketing</th>
#       <td id="T_b7d39_row10_col0" class="data row10 col0" >37.924528</td>
#       <td id="T_b7d39_row10_col1" class="data row10 col1" >727.836478</td>
#       <td id="T_b7d39_row10_col2" class="data row10 col2" >7348.584906</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row11" class="row_heading level1 row11" >Medical</th>
#       <td id="T_b7d39_row11_col0" class="data row11 col0" >34.727273</td>
#       <td id="T_b7d39_row11_col1" class="data row11 col1" >802.909091</td>
#       <td id="T_b7d39_row11_col2" class="data row11 col2" >6377.227273</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row12" class="row_heading level1 row12" >Other</th>
#       <td id="T_b7d39_row12_col0" class="data row12 col0" >32.000000</td>
#       <td id="T_b7d39_row12_col1" class="data row12 col1" >893.600000</td>
#       <td id="T_b7d39_row12_col2" class="data row12 col2" >5398.733333</td>
#     </tr>
#     <tr>
#       <th id="T_b7d39_level1_row13" class="row_heading level1 row13" >Technical Degree</th>
#       <td id="T_b7d39_row13_col0" class="data row13 col0" >33.941176</td>
#       <td id="T_b7d39_row13_col1" class="data row13 col1" >851.470588</td>
#       <td id="T_b7d39_row13_col2" class="data row13 col2" >6066.294118</td>
#     </tr>
#   </tbody>
# </table>

# %%
# grouped the data by education field
dt2 = data.groupby(['EducationField'])[['Age','DailyRate','HourlyRate','MonthlyIncome']].agg('mean')
dt2
# Out:
#                         Age   DailyRate  HourlyRate  MonthlyIncome
# EducationField
# Human Resources   37.037037  675.259259   60.888889    7241.148148
# Life Sciences     37.107261  804.425743   66.831683    6463.288779
# Marketing         37.924528  727.836478   66.150943    7348.584906
# Medical           36.838362  822.799569   65.280172    6510.036638
# Other             35.365854  796.024390   62.365854    6071.548780
# Technical Degree  36.121212  842.128788   66.621212    5758.303030

# %%
dt2.style.highlight_max(color = 'darkgreen').highlight_min(color = 'yellow')
# Out:
# <style type="text/css">
# #T_8f2aa_row0_col1, #T_8f2aa_row0_col2, #T_8f2aa_row4_col0, #T_8f2aa_row5_col3 {
#   background-color: yellow;
# }
# #T_8f2aa_row1_col2, #T_8f2aa_row2_col0, #T_8f2aa_row2_col3, #T_8f2aa_row5_col1 {
#   background-color: darkgreen;
# }
# </style>
# <table id="T_8f2aa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age</th>
#       <th class="col_heading level0 col1" >DailyRate</th>
#       <th class="col_heading level0 col2" >HourlyRate</th>
#       <th class="col_heading level0 col3" >MonthlyIncome</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >EducationField</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f2aa_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_8f2aa_row0_col0" class="data row0 col0" >37.037037</td>
#       <td id="T_8f2aa_row0_col1" class="data row0 col1" >675.259259</td>
#       <td id="T_8f2aa_row0_col2" class="data row0 col2" >60.888889</td>
#       <td id="T_8f2aa_row0_col3" class="data row0 col3" >7241.148148</td>
#     </tr>
#     <tr>
#       <th id="T_8f2aa_level0_row1" class="row_heading level0 row1" >Life Sciences</th>
#       <td id="T_8f2aa_row1_col0" class="data row1 col0" >37.107261</td>
#       <td id="T_8f2aa_row1_col1" class="data row1 col1" >804.425743</td>
#       <td id="T_8f2aa_row1_col2" class="data row1 col2" >66.831683</td>
#       <td id="T_8f2aa_row1_col3" class="data row1 col3" >6463.288779</td>
#     </tr>
#     <tr>
#       <th id="T_8f2aa_level0_row2" class="row_heading level0 row2" >Marketing</th>
#       <td id="T_8f2aa_row2_col0" class="data row2 col0" >37.924528</td>
#       <td id="T_8f2aa_row2_col1" class="data row2 col1" >727.836478</td>
#       <td id="T_8f2aa_row2_col2" class="data row2 col2" >66.150943</td>
#       <td id="T_8f2aa_row2_col3" class="data row2 col3" >7348.584906</td>
#     </tr>
#     <tr>
#       <th id="T_8f2aa_level0_row3" class="row_heading level0 row3" >Medical</th>
#       <td id="T_8f2aa_row3_col0" class="data row3 col0" >36.838362</td>
#       <td id="T_8f2aa_row3_col1" class="data row3 col1" >822.799569</td>
#       <td id="T_8f2aa_row3_col2" class="data row3 col2" >65.280172</td>
#       <td id="T_8f2aa_row3_col3" class="data row3 col3" >6510.036638</td>
#     </tr>
#     <tr>
#       <th id="T_8f2aa_level0_row4" class="row_heading level0 row4" >Other</th>
#       <td id="T_8f2aa_row4_col0" class="data row4 col0" >35.365854</td>
#       <td id="T_8f2aa_row4_col1" class="data row4 col1" >796.024390</td>
#       <td id="T_8f2aa_row4_col2" class="data row4 col2" >62.365854</td>
#       <td id="T_8f2aa_row4_col3" class="data row4 col3" >6071.548780</td>
#     </tr>
#     <tr>
#       <th id="T_8f2aa_level0_row5" class="row_heading level0 row5" >Technical Degree</th>
#       <td id="T_8f2aa_row5_col0" class="data row5 col0" >36.121212</td>
#       <td id="T_8f2aa_row5_col1" class="data row5 col1" >842.128788</td>
#       <td id="T_8f2aa_row5_col2" class="data row5 col2" >66.621212</td>
#       <td id="T_8f2aa_row5_col3" class="data row5 col3" >5758.303030</td>
#     </tr>
#   </tbody>
# </table>

# %%
# highlighting the range of values using background_gradient
dt2.style.background_gradient(cmap = 'Greens')
# Out:
# <style type="text/css">
# #T_24e5b_row0_col0 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_24e5b_row0_col1, #T_24e5b_row0_col2, #T_24e5b_row4_col0, #T_24e5b_row5_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_24e5b_row0_col3 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_24e5b_row1_col0 {
#   background-color: #339c52;
#   color: #f1f1f1;
# }
# #T_24e5b_row1_col1 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_24e5b_row1_col2, #T_24e5b_row2_col0, #T_24e5b_row2_col3, #T_24e5b_row5_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_24e5b_row1_col3 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_24e5b_row2_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_24e5b_row2_col2, #T_24e5b_row3_col1 {
#   background-color: #00692a;
#   color: #f1f1f1;
# }
# #T_24e5b_row3_col0 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_24e5b_row3_col2 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_24e5b_row3_col3 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_24e5b_row4_col1 {
#   background-color: #29914a;
#   color: #f1f1f1;
# }
# #T_24e5b_row4_col2 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_24e5b_row4_col3 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_24e5b_row5_col0 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_24e5b_row5_col2 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_24e5b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age</th>
#       <th class="col_heading level0 col1" >DailyRate</th>
#       <th class="col_heading level0 col2" >HourlyRate</th>
#       <th class="col_heading level0 col3" >MonthlyIncome</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >EducationField</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24e5b_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_24e5b_row0_col0" class="data row0 col0" >37.037037</td>
#       <td id="T_24e5b_row0_col1" class="data row0 col1" >675.259259</td>
#       <td id="T_24e5b_row0_col2" class="data row0 col2" >60.888889</td>
#       <td id="T_24e5b_row0_col3" class="data row0 col3" >7241.148148</td>
#     </tr>
#     <tr>
#       <th id="T_24e5b_level0_row1" class="row_heading level0 row1" >Life Sciences</th>
#       <td id="T_24e5b_row1_col0" class="data row1 col0" >37.107261</td>
#       <td id="T_24e5b_row1_col1" class="data row1 col1" >804.425743</td>
#       <td id="T_24e5b_row1_col2" class="data row1 col2" >66.831683</td>
#       <td id="T_24e5b_row1_col3" class="data row1 col3" >6463.288779</td>
#     </tr>
#     <tr>
#       <th id="T_24e5b_level0_row2" class="row_heading level0 row2" >Marketing</th>
#       <td id="T_24e5b_row2_col0" class="data row2 col0" >37.924528</td>
#       <td id="T_24e5b_row2_col1" class="data row2 col1" >727.836478</td>
#       <td id="T_24e5b_row2_col2" class="data row2 col2" >66.150943</td>
#       <td id="T_24e5b_row2_col3" class="data row2 col3" >7348.584906</td>
#     </tr>
#     <tr>
#       <th id="T_24e5b_level0_row3" class="row_heading level0 row3" >Medical</th>
#       <td id="T_24e5b_row3_col0" class="data row3 col0" >36.838362</td>
#       <td id="T_24e5b_row3_col1" class="data row3 col1" >822.799569</td>
#       <td id="T_24e5b_row3_col2" class="data row3 col2" >65.280172</td>
#       <td id="T_24e5b_row3_col3" class="data row3 col3" >6510.036638</td>
#     </tr>
#     <tr>
#       <th id="T_24e5b_level0_row4" class="row_heading level0 row4" >Other</th>
#       <td id="T_24e5b_row4_col0" class="data row4 col0" >35.365854</td>
#       <td id="T_24e5b_row4_col1" class="data row4 col1" >796.024390</td>
#       <td id="T_24e5b_row4_col2" class="data row4 col2" >62.365854</td>
#       <td id="T_24e5b_row4_col3" class="data row4 col3" >6071.548780</td>
#     </tr>
#     <tr>
#       <th id="T_24e5b_level0_row5" class="row_heading level0 row5" >Technical Degree</th>
#       <td id="T_24e5b_row5_col0" class="data row5 col0" >36.121212</td>
#       <td id="T_24e5b_row5_col1" class="data row5 col1" >842.128788</td>
#       <td id="T_24e5b_row5_col2" class="data row5 col2" >66.621212</td>
#       <td id="T_24e5b_row5_col3" class="data row5 col3" >5758.303030</td>
#     </tr>
#   </tbody>
# </table>

# %%
# method chains to hide the index as well
grp_data.style.background_gradient(cmap = 'Greens').hide_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/ipykernel_10713/3908576631.py in <module>
#       1 # method chains to hide the index as well
# ----> 2 grp_data.style.background_gradient(cmap = 'Greens').hide_index()
#
# NameError: name 'grp_data' is not defined
