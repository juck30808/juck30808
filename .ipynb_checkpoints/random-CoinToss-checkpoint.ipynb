# %%
import random 
flip_number = int(input("How many times would you like me to flip the coin: "))
choice = input("Would you like to see the result of each flip (y/n): ").lower()
print("\nFlipping!!!\n")

heads = 0
tails = 0

#The main loop
for flips in range(flip_number):
    coin = random.randint(0,1)
    if coin == 1:
        heads += 1
        if choice.startswith('y'):
            print("HEADS")
    else:
        tails += 1
        if choice.startswith('y'):
            print("TAILS")
    
    if heads == tails:
        print("At " + str(flips + 1) + " equal at " + str(heads) + " each.")

#Calculate percentages
heads_percentage = round(100*heads/flip_number, 2)
tails_percentage = round(100*tails/flip_number, 2)
print("\nResults of Flipping a Coin " + str(flip_number) + " Times: ")
print("\nSide\t\tCount\t\tPercentage")
print("Heads\t\t" + str(heads) + "/" + str(flip_number) + "\t\t" + str(heads_percentage) + "%")
print("Tails\t\t" + str(tails) + "/" + str(flip_number) + "\t\t" + str(tails_percentage) + "%")
# Out:
# Welcome to the Coin Toss App
#
# I will flip a coin a set number of times.
# How many times would you like me to flip the coin: 50
# Would you like to see the result of each flip (y/n): y
#
# Flipping!!!
#
# TAILS
# HEADS
# At 2 equal at 1 each.
# TAILS
# TAILS
# TAILS
# TAILS
# TAILS
# HEADS
# TAILS
# TAILS
# HEADS
# HEADS
# TAILS
# HEADS
# HEADS
# TAILS
# HEADS
# HEADS
# HEADS
# HEADS
# At 20 equal at 10 each.
# HEADS
# HEADS
# HEADS
# HEADS
# HEADS
# TAILS
# HEADS
# HEADS
# TAILS
# HEADS
# TAILS
# HEADS
# HEADS
# TAILS
# HEADS
# HEADS
# TAILS
# TAILS
# TAILS
# HEADS
# HEADS
# TAILS
# HEADS
# TAILS
# HEADS
# HEADS
# HEADS
# TAILS
# TAILS
# HEADS
#
# Results of Flipping a Coin 50 Times:
#
# Side		Count		Percentage
# Heads		29/50		58.0%
# Tails		21/50		42.0%
