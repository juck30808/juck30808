# %%
import requests
from bs4 import BeautifulSoup
url="https://www.ptt.cc/bbs/Food/index.html"
    
def get_all_href(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    results = soup.select("div.title")
    for item in results:
        a_item = item.select_one("a")
        title = item.text
        if a_item:
            #方法1 標題
            print(title, 'https://www.ptt.cc'+ a_item.get('href'))
            #方法2 內容
            #get_article_content(article_url='https://www.ptt.cc'+a_item.get('href'))
    print('------------------ next page ------------------')
    
    
def get_article_content(article_url):
    r = requests.get(article_url)
    soup = BeautifulSoup(r.text, "lxml")
    results = soup.select('span.article-meta-value')
    if results:
        print('作者:', results[0].text)
        print('看板:', results[1].text)
        print('標題:', results[2].text)
        print('時間:', results[3].text)
    
    
for page in range(1,4):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    btn = soup.select('div.btn-group > a')
    if btn:
        next_page_url = 'https://www.ptt.cc' + btn[3]['href']
        url = next_page_url
        print('page:', url)
        get_all_href(url = url)
# Out:
# page: https://www.ptt.cc/bbs/Food/index7000.html
#
# [食記] 桃園中壢區。串燒小棧
#  https://www.ptt.cc/bbs/Food/M.1656680346.A.4F8.html
#
# [食記] 苑裡臭豆腐 苗栗苑裡 香酥炸餛飩及臭豆腐
#  https://www.ptt.cc/bbs/Food/M.1656682952.A.75B.html
#
# [食記] 高雄 天廚川味 二訪
#  https://www.ptt.cc/bbs/Food/M.1656683085.A.0EA.html
#
# [食記] 台北 美國紐約牛排館 Smith & Wollensky
#  https://www.ptt.cc/bbs/Food/M.1656686312.A.F1B.html
#
# [食記] 台北-宋廚菜館/原全聚德/烤鴨二吃
#  https://www.ptt.cc/bbs/Food/M.1656686537.A.9AB.html
#
# [食記] 台北信義 越南小吃炸炸捲捲
#  https://www.ptt.cc/bbs/Food/M.1656689790.A.E43.html
#
# [食記] 淡水｜淡水老街到底有哪些經典淡水小吃？
#  https://www.ptt.cc/bbs/Food/M.1656723658.A.A06.html
#
# [食記] 花蓮 春天輕食 健康新素食彩虹套餐好吃
#  https://www.ptt.cc/bbs/Food/M.1656727070.A.ED4.html
#
# [食記] 台南 翻滾吧！蛋捲 成大附近全日早午餐
#  https://www.ptt.cc/bbs/Food/M.1656730185.A.3E1.html
#
# [食記] 新竹竹北 胡同燒肉 66折優惠
#  https://www.ptt.cc/bbs/Food/M.1656739951.A.F58.html
#
# [食記] 桃園內壢泰式料理 瑪琳泰國餐廳
#  https://www.ptt.cc/bbs/Food/M.1656742746.A.0CD.html
#
# [食記] 嘉義奮起湖｜百年檜木甜甜圈
#  https://www.ptt.cc/bbs/Food/M.1656747049.A.421.html
#
# [食記] 高雄 開動了 日本家庭料理 簡單樸實美味
#  https://www.ptt.cc/bbs/Food/M.1656758318.A.F00.html
#
# [食記] 文興路早午餐 桃園龜山 平價好吃台式早餐
#  https://www.ptt.cc/bbs/Food/M.1656759080.A.C89.html
#
# [食記] 桃園八德區。霄裡路_大腸麵線
#  https://www.ptt.cc/bbs/Food/M.1656764371.A.CA6.html
#
# [食記] 台北叁食穗Bistro 真的在這過30歲生日
#  https://www.ptt.cc/bbs/Food/M.1656773704.A.44A.html
#
# [食記] 台北內湖文德 劉老太老潼關肉夾饃
# page: https://www.ptt.cc/bbs/Food/index6998.html
#
# [食記] 台南東區 阿鴻臭豆腐  只賣臭豆腐生意好
#  https://www.ptt.cc/bbs/Food/M.1656510945.A.4E3.html
#
# [食記] 台南永康 瘋濟顛臭豆腐 料好又實在
#  https://www.ptt.cc/bbs/Food/M.1656511199.A.C90.html
#
# [食記] 新北 IKEA宜家家居新莊店原盅牛肉麵
#  https://www.ptt.cc/bbs/Food/M.1656511470.A.C72.html
#
# [食記] 台北信義永春 純發魯肉飯(新開雞湯滷大腸
#  https://www.ptt.cc/bbs/Food/M.1656512883.A.F33.html
#
# [食記] 友蓁豆花 台北中正 香濃好吃冰淇淋+豆花
#  https://www.ptt.cc/bbs/Food/M.1656514550.A.AC8.html
#
# [食記] 台北 熊ㄧ燒肉 西門店
#  https://www.ptt.cc/bbs/Food/M.1656517452.A.570.html
#
# [食記] 三重 英廚越式料理 夏日清爽開胃美食
#  https://www.ptt.cc/bbs/Food/M.1656529281.A.01F.html
#
# [食記] 台南 臺灣歐巴韓式小吃 平價韓式料理
#  https://www.ptt.cc/bbs/Food/M.1656554404.A.B98.html
#
# [食記] 高雄前鎮 小吃-阿明肉燥飯
#  https://www.ptt.cc/bbs/Food/M.1656557115.A.7F2.html
#
# [食記] 高雄 大社-木子雞蛋糕 淋醬&包餡雞蛋糕
#  https://www.ptt.cc/bbs/Food/M.1656557614.A.029.html
#
# [食記] 台北大同 Les Tables par RéeL 歐陸料理
#  https://www.ptt.cc/bbs/Food/M.1656564394.A.6B1.html
#
# [食記] 新竹竹北｜HOHO禾室 早午餐
#  https://www.ptt.cc/bbs/Food/M.1656566793.A.EEA.html
#
# [食記] 嘉義奮起湖｜鐵道山城懷舊鐵路便當
#  https://www.ptt.cc/bbs/Food/M.1656568172.A.847.html
#
# [食記] 桃園龜山區。嘉義粉條冰
#  https://www.ptt.cc/bbs/Food/M.1656568568.A.853.html
#
# [食記] 台中 東山棧甕仔雞，大坑美食有停車場
#  https://www.ptt.cc/bbs/Food/M.1656575436.A.9B9.html
#
# [食記] 台中 丹美隆，超好吃簡餐必點檸檬雞
#  https://www.ptt.cc/bbs/Food/M.1656575792.A.0D3.html
#
# [食記] 隱身巴洛克洋樓咖啡廳｜台中馨苑小料理
#  https://www.ptt.cc/bbs/Food/M.1656582345.A.871.html
#
# [食記] 麵屋敬太 新北淡水 極度香濃青森煮干拉麵
#  https://www.ptt.cc/bbs/Food/M.1656585840.A.AB3.html
#
# [食記] 新竹竹北 鮮稻火鍋 生食級海鮮吃到飽
#  https://www.ptt.cc/bbs/Food/M.1656593795.A.FE6.html
#
# [食記] 台北Mooo Burger 特別的山裡的牛排漢堡
#  https://www.ptt.cc/bbs/Food/M.1656594093.A.E60.html
# ------------------ next page ------------------

# %% [markdown]
# ## PTT 分解步驟

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
from bs4 import BeautifulSoup
article_href = []

# requests
r = requests.get("https://www.ptt.cc/bbs/Food/index.html")

# BeautifulSoup parser
soup = BeautifulSoup(r.text,"html.parser")

#<a>標籤在<div class="title">內
results = soup.select("div.title")
print(results)
# Out:
# [<div class="title">
# <a href="/bbs/Food/M.1656817360.A.6C2.html">[食記] 台北.中正 - 東一排骨  便當店</a>
# </div>, <div class="title">
#  '/bbs/Food/M.1656855930.A.7D2.html',
#  '/bbs/Food/M.1656855959.A.3B8.html',
#  '/bbs/Food/M.1656856267.A.7B9.html',
#  '/bbs/Food/M.1656857159.A.842.html',
#  '/bbs/Food/M.1656857874.A.BB6.html',
#  '/bbs/Food/M.1656859371.A.83E.html',
#  '/bbs/Food/M.1355673582.A.5F7.html',
#  '/bbs/Food/M.1190944426.A.E6C.html',
#  '/bbs/Food/M.1128132666.A.0FD.html',
#  '/bbs/Food/M.1496532469.A.C36.html']

# %% [markdown]
# ## 切換頁

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#取得 div 內 class btn-group的 a 標籤
btn = soup.select('div.btn-group > a')

up_page_href = btn[0]['href'] #看板
print(up_page_href)

up_page_href = btn[1]['href'] #精華區
print(up_page_href)

up_page_href = btn[2]['href'] #最舊
print(up_page_href)

up_page_href = btn[3]['href'] #上頁
print(up_page_href)

next_page_url = 'https://www.ptt.cc' + up_page_href
print(next_page_url)
# Out:
# /bbs/Food/index.html
# /man/Food/index.html
# /bbs/Food/index1.html
# /bbs/Food/index7000.html
# https://www.ptt.cc/bbs/Food/index7000.html

# %%
url="https://www.ptt.cc/bbs/Food/index.html"

# 抓取 3頁
for page in range(1,4):
    r = requests.get(url)
    soup = BeautifulSoup(r.text,"html.parser")
    btn = soup.select('div.btn-group > a')
    up_page_href = btn[3]['href']
    next_page_url = 'https://www.ptt.cc' + up_page_href
    url = next_page_url
    print(url)
# Out:
# https://www.ptt.cc/bbs/Food/index7000.html
# https://www.ptt.cc/bbs/Food/index6999.html
# https://www.ptt.cc/bbs/Food/index6998.html

# %% [markdown]
# ## 爬取文章內容
# get_article_content(article_url):

# %%
def get_article_content(article_url):
    r = requests.get(article_url)
    soup = BeautifulSoup(r.text, "lxml")
    results = soup.select('span.article-meta-value')
    if results:
        print('作者:', results[0].text)
        print('看板:', results[1].text)
        print('標題:', results[2].text)
        print('時間:', results[3].text)

# %%
import requests
from bs4 import BeautifulSoup
url="https://www.ptt.cc/bbs/Food/index.html"
    
def get_all_href(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    results = soup.select("div.title")
    for item in results:
        a_item = item.select_one("a")
        if a_item:
            get_article_content(article_url='https://www.ptt.cc'+a_item.get('href'))
    
for page in range(1,2):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    btn = soup.select('div.btn-group > a')
    if btn:
        next_page_url = 'https://www.ptt.cc' + btn[3]['href']
        url = next_page_url
        print('page:', url)
        get_all_href(url = url)
# Out:
# page: https://www.ptt.cc/bbs/Food/index7000.html
# 作者: larle (認命選擇保護自己)
# 看板: Food
# 標題: [食記] 桃園中壢區。串燒小棧
# 時間: Fri Jul  1 20:59:04 2022
# 作者: Geiwoyujie (https://reurl.cc/Rlnen?)
# 看板: Food
# 標題: [食記] 苑裡臭豆腐 苗栗苑裡 香酥炸餛飩及臭豆腐
# 時間: Fri Jul  1 21:42:29 2022
# 作者: thudadai (三高sir)
# 看板: Food
# 標題: [食記] 高雄 天廚川味 二訪
# 時間: Fri Jul  1 21:44:41 2022
# 作者: jhws (wsjh)
# 看板: Food
# 標題: [食記] 台北 美國紐約牛排館 Smith & Wollensky
# 時間: Fri Jul  1 22:38:28 2022
# 作者: jasmine1112 (茉茉)
# 看板: Food
# 標題: [食記] 台北-宋廚菜館/原全聚德/烤鴨二吃
# 時間: Fri Jul  1 22:42:15 2022
# 作者: elisa48 (詠夜月舞)
# 看板: Food
# 標題: [食記] 台北信義 越南小吃炸炸捲捲
# 時間: Fri Jul  1 23:36:27 2022
# 作者: mystic0412 (　　　)
# 看板: Food
# 標題: [食記] 淡水｜淡水老街到底有哪些經典淡水小吃？
# 時間: Sat Jul  2 09:00:55 2022
# 作者: lovecala (cala)
# 看板: Food
# 標題: [食記] 花蓮 春天輕食 健康新素食彩虹套餐好吃
# 時間: Sat Jul  2 09:57:48 2022
# 作者: hibabino (黛西)
# 看板: Food
# 標題: [食記] 台南 翻滾吧！蛋捲 成大附近全日早午餐
# 時間: Sat Jul  2 10:49:42 2022
# 作者: ice80712 (打臉腦粉)
# 看板: Food
# 標題: [食記] 新竹竹北 胡同燒肉 66折優惠
# 時間: Sat Jul  2 13:32:29 2022
# 作者: dong1104 (東蛙)
# 看板: Food
# 標題: [食記] 桃園內壢泰式料理 瑪琳泰國餐廳
# 時間: Sat Jul  2 14:19:04 2022
# 作者: syuanfeng (睡飽再說)
# 看板: Food
# 標題: [食記] 嘉義奮起湖｜百年檜木甜甜圈
# 時間: Sat Jul  2 15:30:46 2022
# 作者: katrina0120 (Katrina)
# 看板: Food
# 標題: [食記] 高雄 開動了 日本家庭料理 簡單樸實美味
# 時間: Sat Jul  2 18:38:36 2022
# 作者: Geiwoyujie (https://reurl.cc/Rlnen?)
# 看板: Food
# 標題: [食記] 文興路早午餐 桃園龜山 平價好吃台式早餐
# 時間: Sat Jul  2 18:51:16 2022
# 作者: larle (認命選擇保護自己)
# 看板: Food
# 標題: [食記] 桃園八德區。霄裡路_大腸麵線
# 時間: Sat Jul  2 20:19:28 2022
# 作者: aner ()
# 看板: Food
# 標題: [食記] 台北叁食穗Bistro 真的在這過30歲生日
# 時間: Sat Jul  2 22:55:00 2022
# 作者: TW00500203 (Ming)
# 看板: Food
# 標題: [食記] 台北內湖文德 劉老太老潼關肉夾饃
# 時間: Sat Jul  2 23:31:16 2022
# 作者: elisa48 (詠夜月舞)
# 看板: Food
# 標題: [食記] 台中火車站附近 與魚咖啡Yu's Cafe金鯱燒
# 時間: Sun Jul  3 00:31:37 2022
# 作者: mystic0412 (　　　)
# 看板: Food
# 標題: [食記] 台北中山｜三禾小廚 朋友聚會合菜餐廳
# 時間: Sun Jul  3 08:53:50 2022
# 作者: b122771 (躺平的韭菜)
# 看板: Food
# 標題: [食記] 台北.內湖 - 金仙滷肉飯  便當店
# 時間: Sun Jul  3 10:59:30 2022

# %% [markdown]
# ## 下載圖片

# %%
import requests
import shutil
img_url = 'https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_272x92dp.png'
img_name = 'google'
r = requests.get(img_url, stream=True)
file_name = img_name
with open('./' + file_name + '.jpg', 'wb+') as out_file:
    shutil.copyfileobj(r.raw, out_file)

# %%
def download_img_from_article(img_url, img_name):
    r = requests.get(img_url, stream=True)
    file_name = str(img_name + 1)
    print( 'save img to  ./image/'+ file_name + '.jpg')
    try:
        with open('./image/' + file_name + '.jpg', 'wb') as out_file:
            shutil.copyfileobj(r.raw, out_file)
    except:
        print('can not save img', img_url)
