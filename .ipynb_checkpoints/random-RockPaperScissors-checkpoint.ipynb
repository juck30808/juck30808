# %%
import random
rounds = int(input("\nHow many rounds would you like to play: "))
moves = ['rock', 'paper', 'scissors']
p_score = 0
c_score = 0


for game_round in range(rounds):
    print("\nRound " + str(game_round + 1))
    print("Player: " + str(p_score) + "\tComputer: " + str(c_score))
    
    #Get the computers move
    c_index = random.randint(0,2)
    c_choice = moves[c_index]
    
    #Get the players move
    p_choice = input("Time to pick...rock, paper, scissors: ").lower().strip()
    
    #If the player makes a valid move
    if p_choice in moves:
        print("\tComputer: " + c_choice)
        print("\tPlayer: " + p_choice)
        
        #Computer chooses rock
        if p_choice == 'rock' and c_choice == 'rock':
            winner = 'tie'
            phrase = 'It is a tie, how boring!'
        elif p_choice == 'paper' and c_choice == 'rock':
            winner = 'player'
            phrase = 'Paper covers rock!'
        elif p_choice == 'scissors' and c_choice == 'rock':
            winner = 'computer'
            phrase = 'Rock smashes scissors!'
        
        #Computer chooses paper
        elif p_choice == 'rock' and c_choice == 'paper':
            winner = 'computer'
            phrase = 'Paper covers rock!'
        
        elif p_choice == 'paper' and c_choice == 'paper':
            winner = 'tie'
            phrase = 'It is a tie, how boring!'
        
        elif p_choice == 'scissors' and c_choice == 'paper':
            winner = 'player'
            phrase = 'Scissors cut paper!'
        
        #Computer chooses scissors
        elif p_choice == 'rock' and c_choice == 'scissors':
            winner = 'player'
            phrase = 'Rock smashes scissors!'
        elif p_choice == 'paper' and c_choice == 'scissors':
            winner = 'computer'
            phrase = 'Scissors cut paper!'
        elif p_choice == 'scissors' and c_choice == 'scissors':
            winner = 'tie'
            phrase = 'It is a tie, how boring!'
        #Catch for any other conditions
        else:
            print("Round winner not calculated.")
            winner = 'tie'
            phrase = 'It is a tie, how boring!'
    
        #Display round results
        print("\t" + phrase)
        if winner == 'player':
            print("\tYou win round " + str(game_round + 1) + ".")
            p_score += 1
        elif winner == 'computer':
            print("\tComputer wins round " + str(game_round + 1) + ".")
            c_score += 1
        else:
            print("\tThis round was a tie.")

    #Else the player did not make a valid move
    else:
        print("That is not a valid game option!")
        print("Computer gets the point!")
        c_score += 1

#Game has ended, print results
print("\nFinal Game Results")
print("\tRounds Played: " + str(rounds))
print("\tPlayer Score: " + str(p_score))
print("\tComputer Score: " + str(c_score))

if p_score > c_score:
    print("\tWinner: PLAYER!!!")
elif c_score > p_score:
    print("\tWinner: Computer :-(")
else:
    print("\tThe game was a tie.")
# Out:
# Welcome to a game of Rock, Paper, Scissors
#
# How many rounds would you like to play: 10
#
# Round 1
# Player: 0	Computer: 0
# Time to pick...rock, paper, scissors: rock
# 	Computer: paper
# 	Player: rock
# 	Paper covers rock!
# 	Computer wins round 1.
#
# Round 2
# Player: 0	Computer: 1
# Time to pick...rock, paper, scissors: paper
# 	Computer: scissors
# 	Player: paper
# 	Scissors cut paper!
# 	Computer wins round 2.
#
# Round 3
# Player: 0	Computer: 2
# Time to pick...rock, paper, scissors: paper
# 	Computer: rock
# 	Player: paper
# 	Paper covers rock!
# 	You win round 3.
#
# Round 4
# Player: 1	Computer: 2
# Time to pick...rock, paper, scissors: rock
# 	Computer: paper
# 	Player: rock
# 	Paper covers rock!
# 	Computer wins round 4.
#
# Round 5
# Player: 1	Computer: 3
# Time to pick...rock, paper, scissors: rock
# 	Computer: rock
# 	Player: rock
# 	It is a tie, how boring!
# 	This round was a tie.
#
# Round 6
# Player: 1	Computer: 3
# Time to pick...rock, paper, scissors: rock
# 	Computer: scissors
# 	Player: rock
# 	Rock smashes scissors!
# 	You win round 6.
#
# Round 7
# Player: 2	Computer: 3
# Time to pick...rock, paper, scissors: rock
# 	Computer: rock
# 	Player: rock
# 	It is a tie, how boring!
# 	This round was a tie.
#
# Round 8
# Player: 2	Computer: 3
# Time to pick...rock, paper, scissors: rock
# 	Computer: paper
# 	Player: rock
# 	Paper covers rock!
# 	Computer wins round 8.
#
# Round 9
# Player: 2	Computer: 4
# Time to pick...rock, paper, scissors: rock
# 	Computer: scissors
# 	Player: rock
# 	Rock smashes scissors!
# 	You win round 9.
#
# Round 10
# Player: 3	Computer: 4
# Time to pick...rock, paper, scissors: scissors
# 	Computer: paper
# 	Player: scissors
# 	Scissors cut paper!
# 	You win round 10.
#
# Final Game Results
# 	Rounds Played: 10
# 	Player Score: 4
# 	Computer Score: 4
# 	The game was a tie.

# %%
# Rock wins over the Scissors
# Scissors wins over the Paper
# Paper wins over the Rock
from random import randint

objects = ("rock", "scissors", "paper")

computer = objects[randint(0, 2)]

while True:
    user = input("rock, paper or scissors? ").lower().lstrip()
    if user == computer:
        print("Tie!")
    elif user == "rock":
        if computer == "paper":
            print ("You lose! - ", computer, " covers ", user)
        else:
            print ("You win! - ", user, " smashes ", computer)
    elif user == "scissors":
        if computer == "rock":
            print ("You lose! -  ", computer, " smashes ", user)
        else:
            print ("You win! - ", user, " cut ", computer)
    elif user == "paper":
        if computer == "scissors":
            print ("You lose! - ", computer, " cut ", user)
        else:
            print ("You win! - ", user, " covers ", computer)
    else:
        print ("Invalid input!")
    computer = objects[randint(0, 2)]

# %%
import random

def get_random_choice():
    tools = ["Rock", "Paper", "Scissors"]
    return random.choice(tools)

computer_wins = 0
human_wins = 0

while True:
    computer_choice = get_random_choice()
    human_choice = input("Please provide your input (Rock, Paper, Scissors): ")
    human_choice = human_choice.title()

    if human_choice != "Rock" and human_choice != "Paper" and human_choice != "Scissors":
        print("Invalid input. Terminating")
        break

    if human_choice == computer_choice:
        print(f"Tie. I also chose {computer_choice}.")
    elif human_choice == "Rock":
        if computer_choice == "Paper":
            print(f"I won: I chose {computer_choice}")
            computer_wins += 1
        elif computer_choice == "Scissors":
            print(f"You won: I chose {computer_choice}")
            human_wins += 1
    elif human_choice == "Paper":
        if computer_choice == "Rock":
            print(f"You won: I chose {computer_choice}")
            human_wins += 1
        elif computer_choice == "Scissors":
            print(f"I won: I chose {computer_choice}")
            computer_wins += 1
    elif human_choice == "Scissors":
        if computer_choice == "Rock":
            print(f"I won: I chose {computer_choice}")
            computer_wins += 1
        elif computer_choice == "Paper":
            print(f"You won: I chose {computer_choice}")
            human_wins += 1

    print(f"Score: Human {human_wins} vs Computer {computer_wins}")
    print()

if human_wins > computer_wins:
    print("Congrats! You won the game!")
elif computer_wins > human_wins:
    print("Sorry! I won the game!")
else:
    print("Tie! Let's do another one, if you are brave!")
# Out:
# Please provide your input (Rock, Paper, Scissors): Rock
# You won: I chose Scissors
# Score: Human 1 vs Computer 0
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# I won: I chose Rock
# Score: Human 1 vs Computer 1
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 2 vs Computer 1
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 3 vs Computer 1
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 4 vs Computer 1
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# Tie. I also chose Scissors.
# Score: Human 4 vs Computer 1
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# I won: I chose Rock
# Score: Human 4 vs Computer 2
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 5 vs Computer 2
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# Tie. I also chose Scissors.
# Score: Human 5 vs Computer 2
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 6 vs Computer 2
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 7 vs Computer 2
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# I won: I chose Rock
# Score: Human 7 vs Computer 3
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 8 vs Computer 3
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 9 vs Computer 3
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# I won: I chose Rock
# Score: Human 9 vs Computer 4
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 10 vs Computer 4
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# I won: I chose Rock
# Score: Human 10 vs Computer 5
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 11 vs Computer 5
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# Tie. I also chose Scissors.
# Score: Human 11 vs Computer 5
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# I won: I chose Rock
# Score: Human 11 vs Computer 6
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# You won: I chose Paper
# Score: Human 12 vs Computer 6
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# Tie. I also chose Scissors.
# Score: Human 12 vs Computer 6
#
# Please provide your input (Rock, Paper, Scissors): Scissors
# Tie. I also chose Scissors.
# Score: Human 12 vs Computer 6
#
# Please provide your input (Rock, Paper, Scissors): Rock
# Tie. I also chose Rock.
# Score: Human 12 vs Computer 6
#
# Please provide your input (Rock, Paper, Scissors): Rock
# Tie. I also chose Rock.
# Score: Human 12 vs Computer 6
#
# Please provide your input (Rock, Paper, Scissors): v
# Invalid input. Terminating
# Congrats! You won the game!
