# %%
pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (2.90)
# Requirement already satisfied: pyobjc>=2.4 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ClassKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-IOSurface==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Intents==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-OSLog==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-KernelManagement==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ReplayKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Accounts==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-FinderSync==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ModelIO==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MapKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MailKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-core==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Contacts==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Photos==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-NetFS==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Speech==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ShazamKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-OSAKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AVKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-EventKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CFNetwork==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-FileProvider==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AdSupport==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Virtualization==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Cocoa==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Automator==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-PushKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ColorSync==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreText==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreLocation==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-SyncServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MetalKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AdServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-FSEvents==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Quartz==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-IntentsUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-DataDetection==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ScreenTime==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-GameCenter==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Security==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreMotion==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Collaboration==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CloudKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-PencilKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-UserNotifications==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MLCompute==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AVFoundation==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreMedia==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CallKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreAudio==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-SafariServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-libdispatch==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-SearchKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Metal==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CalendarStore==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-DiscRecording==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Social==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AddressBook==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-StoreKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-GameplayKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-PassKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-GameController==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-LaunchServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Network==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-PhotosUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Accessibility==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreML==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-SpriteKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-Vision==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-BusinessChat==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-InstantMessage==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ContactsUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-WebKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreData==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-SceneKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-GameKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Requirement already satisfied: pyobjc-framework-MetricKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc>=2.4->pyttsx3) (8.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (3.8.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pywhatkit
# Out:
# Requirement already satisfied: pywhatkit in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (5.3)
# Requirement already satisfied: pyautogui in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pywhatkit) (0.9.53)
# Requirement already satisfied: requests in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pywhatkit) (2.26.0)
# Requirement already satisfied: wikipedia in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pywhatkit) (1.4.0)
# Requirement already satisfied: Pillow in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pywhatkit) (8.4.0)
# Requirement already satisfied: PyTweening>=1.0.1 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (1.0.4)
# Requirement already satisfied: pyscreeze>=0.1.21 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (0.1.28)
# Requirement already satisfied: pyobjc-core in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: mouseinfo in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (0.1.3)
# Requirement already satisfied: pymsgbox in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (1.0.9)
# Requirement already satisfied: pygetwindow>=0.0.5 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyautogui->pywhatkit) (0.0.9)
# Requirement already satisfied: pyrect in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pygetwindow>=0.0.5->pyautogui->pywhatkit) (0.1.4)
# Requirement already satisfied: rubicon-objc in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from mouseinfo->pyautogui->pywhatkit) (0.4.2)
# Requirement already satisfied: pyperclip in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from mouseinfo->pyautogui->pywhatkit) (1.8.2)
# Requirement already satisfied: pyobjc-framework-CoreServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-SearchKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-UserNotifications==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-StoreKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AVFoundation==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-IntentsUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Photos==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreAudio==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreML==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AVKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-PhotosUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Quartz==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-SafariServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-InstantMessage==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ShazamKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-OSAKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CallKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MetricKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CFNetwork==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CalendarStore==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Automator==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Contacts==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-FileProvider==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-GameKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-FinderSync==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Vision==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ClassKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-SyncServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-PushKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Security==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-WebKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MetalKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ReplayKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Network==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-LaunchServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Collaboration==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreLocation==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-IOSurface==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreMotion==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-FSEvents==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-GameController==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Accounts==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ModelIO==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Cocoa==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Intents==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-DataDetection==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-SceneKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-SpriteKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ColorSync==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AddressBook==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ScreenTime==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MailKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-EventKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Accessibility==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Virtualization==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ContactsUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AdSupport==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-OSLog==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-PencilKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Speech==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreData==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-GameplayKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreText==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Metal==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-BusinessChat==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-DiscRecording==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-AdServices==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-NetFS==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreMedia==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-libdispatch==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MapKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-KernelManagement==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-CloudKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-GameCenter==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-MLCompute==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-PassKit==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: pyobjc-framework-Social==8.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from pyobjc->pyautogui->pywhatkit) (8.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from requests->pywhatkit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from requests->pywhatkit) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from requests->pywhatkit) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from requests->pywhatkit) (3.2)
# Requirement already satisfied: beautifulsoup4 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from wikipedia->pywhatkit) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->wikipedia->pywhatkit) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyjokes
# Out:
# Requirement already satisfied: pyjokes in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio
# Out:
# Collecting pyaudio
#   Using cached PyAudio-0.2.11.tar.gz (37 kB)
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/jerrychien/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-install-g4ntfd1h/pyaudio_0d4be7b3fcc54e67882c7db413c2eebe/setup.py'"'"'; __file__='"'"'/private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-install-g4ntfd1h/pyaudio_0d4be7b3fcc54e67882c7db413c2eebe/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-wheel-h_rom55l
#        cwd: /private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-install-g4ntfd1h/pyaudio_0d4be7b3fcc54e67882c7db413c2eebe/
#   Complete output (16 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.9
#   copying src/pyaudio.py -> build/lib.macosx-10.9-x86_64-3.9
#   running build_ext
#   building '_portaudio' extension
#   creating build/temp.macosx-10.9-x86_64-3.9
#   creating build/temp.macosx-10.9-x86_64-3.9/src
#   clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/jerrychien/opt/anaconda3/include -arch x86_64 -I/Users/jerrychien/opt/anaconda3/include -fPIC -O2 -isystem /Users/jerrychien/opt/anaconda3/include -arch x86_64 -DMACOSX=1 -I/Users/jerrychien/opt/anaconda3/include/python3.9 -c src/_portaudiomodule.c -o build/temp.macosx-10.9-x86_64-3.9/src/_portaudiomodule.o
#   src/_portaudiomodule.c:29:10: fatal error: 'portaudio.h' file not found
#   #include "portaudio.h"
#            ^~~~~~~~~~~~~
#   1 error generated.
#   error: command '/usr/bin/clang' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for pyaudio
#   Running setup.py clean for pyaudio
# Failed to build pyaudio
# Installing collected packages: pyaudio
#     Running setup.py install for pyaudio ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Users/jerrychien/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-install-g4ntfd1h/pyaudio_0d4be7b3fcc54e67882c7db413c2eebe/setup.py'"'"'; __file__='"'"'/private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-install-g4ntfd1h/pyaudio_0d4be7b3fcc54e67882c7db413c2eebe/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-record-6p_8zyje/install-record.txt --single-version-externally-managed --compile --install-headers /Users/jerrychien/opt/anaconda3/include/python3.9/pyaudio
#          cwd: /private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-install-g4ntfd1h/pyaudio_0d4be7b3fcc54e67882c7db413c2eebe/
#     Complete output (16 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-x86_64-3.9
#     copying src/pyaudio.py -> build/lib.macosx-10.9-x86_64-3.9
#     running build_ext
#     building '_portaudio' extension
#     creating build/temp.macosx-10.9-x86_64-3.9
#     creating build/temp.macosx-10.9-x86_64-3.9/src
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/jerrychien/opt/anaconda3/include -arch x86_64 -I/Users/jerrychien/opt/anaconda3/include -fPIC -O2 -isystem /Users/jerrychien/opt/anaconda3/include -arch x86_64 -DMACOSX=1 -I/Users/jerrychien/opt/anaconda3/include/python3.9 -c src/_portaudiomodule.c -o build/temp.macosx-10.9-x86_64-3.9/src/_portaudiomodule.o
#     src/_portaudiomodule.c:29:10: fatal error: 'portaudio.h' file not found
#     #include "portaudio.h"
#              ^~~~~~~~~~~~~
#     1 error generated.
#     error: command '/usr/bin/clang' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/jerrychien/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-install-g4ntfd1h/pyaudio_0d4be7b3fcc54e67882c7db413c2eebe/setup.py'"'"'; __file__='"'"'/private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-install-g4ntfd1h/pyaudio_0d4be7b3fcc54e67882c7db413c2eebe/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/pip-record-6p_8zyje/install-record.txt --single-version-externally-managed --compile --install-headers /Users/jerrychien/opt/anaconda3/include/python3.9/pyaudio Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from wikipedia) (4.10.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from wikipedia) (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/jerrychien/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->wikipedia) (2.2.1)

# %%
import wikipedia
query=wikipedia.page("Virat Kohli")
print(query.summary)
# Out:
# Virat Kohli (Hindi: [ʋɪˈɾɑːʈ ˈkoːɦliː] (listen); born 5 November 1988) is an Indian international cricketer and former captain of the India national cricket team. He plays for Delhi in domestic cricket and Royal Challengers Bangalore in the Indian Premier League as a right-handed batsman. He is often considered one of the best batsmen of his era and some critics believe him to be one of the best limited-overs batsmen in history. Between 2013 and 2022, he captained the India cricket team in 213 matches across all three formats. With 40 wins out of 68 matches, Kohli is one of the most successful Indian Test captains.Kohli made his Test debut in 2011. He reached the number one spot in the ICC rankings for ODI batsmen for the first time in 2013.  He has won Man of the Tournament twice at the ICC World Twenty20 (in 2014 and 2016). He also holds the world record of being the fastest to 23,000 international runs.Kohli has been the recipient of many awards– most notably the Sir Garfield Sobers Trophy (ICC Men's Cricketer of the Decade): 2011–2020; Sir Garfield Sobers Trophy (ICC Cricketer of the Year) in 2017 and 2018; ICC Test Player of the Year (2018); ICC ODI Player of the Year (2012, 2017, 2018) and Wisden Leading Cricketer in the World (2016, 2017 and 2018). At the national level, he was awarded the Arjuna Award in 2013, the Padma Shri under the sports category in 2017 and the Rajiv Gandhi Khel Ratna award, the highest sporting honour in India, in 2018.In 2016, he was ranked as one of the world's most famous athletes by ESPN and one of the most valuable athlete brands by Forbes. In 2018, Time magazine named him one of the 100 most influential people in the world. In 2020, he was ranked 66th in Forbes list of the top 100 highest-paid athletes in the world for the year 2020 with estimated earnings of over $26 million.

# %%
import pyttsx3
import speech_recognition as sr
import webbrowser
import datetime
import pywhatkit
import os
import yfinance as yf
import pyjokes
import wikipedia


#listen to our microphone and return the audio as text using google
def transform():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        r.pause_threshold = 0.8
        said = r.listen(source)
        try:
            print('I am listening')
            q = r.recognize_google(said, language="en")
            return q
        except sr.UnknownValueError:
            print("Sorry I did not understand")
            return "I am waiting"
        except sr.RequestError:
            print('Sorry the service is down')
            return "I am waiting"
        except:
            return "I am waiting"
transform()


def speaking(message):
    engine = pyttsx3.init()
    engine.say(message)
    engine.runAndWait()
speaking('hello world')
# speaking('Hallo Welt')


engine = pyttsx3.init()
for voice in engine.getProperty('voices'):
    print(voice)


id ='HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0'
engine.setProperty('voice',id)
engine.say('Hello World')
engine.runAndWait()


#returns the weekday name
def query_day():
    day = datetime.date.today()
    #print(day)
    weekday = day.weekday()
    #print(weekday)
    mapping = {
        0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4:'Friday',5:'Saturday',6:'Sunday'
    }
    try:
        speaking(f'Today is {mapping[weekday]}')
    except:
        pass
query_day()


#returns the time
def query_time():
    time = datetime.datetime.now().strftime("%I:%M:%S")
    speaking(f"{time[0:2]} o'clock and {time[3:5]} minutes")
query_time()


#Intro greeting at startup
def whatsup():
    speaking('''Hi, I am David.How may I help you?''')
whatsup()


#the heart of our assistant. Takes queries and returns answers
def querying():
    whatsup()
    start = True
    while(start):
        q = transform().lower()
        
        if 'start youtube' in q:
            speaking('starting youtube. Just a second.')
            webbrowser.open('https://www.youtube.com')
            continue
            
        elif 'start webbrowser' in q:
            speaking('opening browser')
            webbrowser.open('https://www.google.com')
            continue
        
        elif 'what day is it' in q:
            query_day()
            continue
            
        elif 'what time is it' in q:
            query_time()
            continue
            
        elif "shut down" in q:
            speaking('ok I am shutting down')
            break
        
        elif "from wikipedia" in q:
            speaking('checking wikipedia')
            q = q.replace("wikipedia","")
            result = wikipedia.summary(q,sentences=2)
            speaking('found on wikipedia')
            speaking(result)
            continue
        
        elif "your name" in q:
            speaking('I am David. Your VA')
            continue
            
        elif "search web" in q:
            pywhatkit.search(q)
            speaking('that is what I found')
            continue
            
        elif "play" in q:
            speaking(f'playing {q}')
            pywhatkit.playonyt(q)
            continue
            
        elif "joke" in q:
            speaking(pyjokes.get_joke())
            continue
            
        elif "stock price" in q:
            search  = q.split("of")[-1].strip()
            lookup = {'apple':'AAPL',
                     'amazon':'AMZN',
                     'google':"GOOGL"}
            try:
                stock = lookup[search]
                stock = yf.Ticker(stock)
                currentprice = stock.info["regularMarketPrice"]
                speaking(f'found it, the price for {search} is {currentprice}')
                continue
            except:
                speaking(f'sorry I have no data for {search}')
                continue

querying()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/speech_recognition/__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/ipykernel_33344/111289165.py in <module>
#      28         except:
#      29             return "I am waiting"
# ---> 30 transform()
#      31
#      32
#
# /var/folders/9q/486czkcn7lv5v0hwbt71twdc0000gn/T/ipykernel_33344/111289165.py in transform()
#      13 def transform():
#      14     r = sr.Recognizer()
# ---> 15     with sr.Microphone() as source:
#      16         r.pause_threshold = 0.8
#      17         said = r.listen(source)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/speech_recognition/__init__.py in __init__(self, device_index, sample_rate, chunk_size)
#      77
#      78         # set up PyAudio
# ---> 79         self.pyaudio_module = self.get_pyaudio()
#      80         audio = self.pyaudio_module.PyAudio()
#      81         try:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/speech_recognition/__init__.py in get_pyaudio()
#     108             import pyaudio
#     109         except ImportError:
# --> 110             raise AttributeError("Could not find PyAudio; check installation")
#     111         from distutils.version import LooseVersion
#     112         if LooseVersion(pyaudio.__version__) < LooseVersion("0.2.11"):
#
# AttributeError: Could not find PyAudio; check installation
